# %% [markdown]
# ### Description
# This is set up to process the unfolding output.

# %%
import matplotlib.pyplot as plt
import numpy as np

import time

import sys
import os

from datetime import datetime
import subprocess

from os.path import exists

import read_config_utils as cu

import matplotlib as mpl

import pickle
from pathlib import Path
datadir = Path("/pscratch/sd/k/kdesai/unbinned-inference-paper")

# %%
samples_from_GenerateInput = False
input_unfolding_dir = datadir/'output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10'

# %%
os.makedirs('paper-plots', exist_ok = True)

# %%
if not samples_from_GenerateInput :
    config_file = input_unfolding_dir/'config.txt'
    if not exists(config_file) :
        print("\tInput file does not exist:", config_file)
        sys.exit()
    ndim = int(cu.get_par(config_file, "ndim"))
    print("Number of feature dimensions:", ndim)
else :
    ndim = 1
# Out:
# Number of feature dimensions: 1

# %%
if not samples_from_GenerateInput :
    with open( input_unfolding_dir/'config-pars.pkl', 'rb') as f :
        mc_mu = pickle.load(f)
        mc_rho = pickle.load(f)
        mc_sig = pickle.load(f)
        true_mu = pickle.load(f)
        true_rho = pickle.load(f)
        true_sig = pickle.load(f)
        resolution = pickle.load(f)
        mc_cov = pickle.load(f)
        true_cov = pickle.load(f)
    print(f'{true_mu[0] = }')
    print('true_cov[0,0] : %.3f' % true_cov[0,0])
else:
    sample_input_dir = cu.get_par(input_unfolding_dir/'config.txt', 'input_dir')
    print(f'{sample_input_dir = }')

    true_mu = np.zeros( shape=(ndim))
    true_cov = np.zeros( shape=(ndim,ndim) )
    true_sig = np.zeros( shape=(ndim))

    pv = cu.get_par( '%s/config.txt' % sample_input_dir,'mu_true')
    true_mu[0] = float(pv)

    print('true_mu : %.3f' % true_mu[0])

    pv = cu.get_par( '%s/config.txt' % sample_input_dir,'var_true')
    true_cov[0,0] = float(pv)
    true_sig[0] = np.sqrt(float(pv))

    print('true_cov[0,0] : %.3f' % true_cov[0,0])
# Out:
# true_mu[0] = 0.2
# true_cov[0,0] : 0.810

# %%
n_samples = 0


if not samples_from_GenerateInput :

    for fi in range(5000) :

        fname = '%s/bootstrap-weights-%03d.npy' % (input_unfolding_dir, fi)

        if exists(fname) :
            n_samples = n_samples + 1
            
else :
    
    for fi in range(5000) :
    
        fname = '%s/sample-%04d.npz' % (sample_input_dir, fi)
    
        if exists(fname) :
            n_samples = n_samples + 1
        
print("\n\n Found %d samples.\n\n" % n_samples )
# Out:
#  Found 1 samples.

# %%
def read_sample( input_dir, sample_index ) :
    
    with np.load( '%s/sample-%04d.npz' % (input_dir, sample_index) ) as f:
        read_true_det_pts = f['data']
        read_mc_pts = f['gen']
        read_mc_det_pts = f['sim']

    ngen_true = len(read_true_det_pts)
    ngen_mc = len(read_mc_pts)

    this_ngen_true = ngen_true

    #-- package these in the same format as what I was using.

    true_det_pts = np.zeros( shape=(ngen_true,1) )
    true_det_pts[:,0] = read_true_det_pts

    mc_pts = np.zeros( shape=(ngen_mc,1) )
    mc_pts[:,0] = read_mc_pts

    mc_det_pts = np.zeros( shape=(ngen_mc,1) )
    mc_det_pts[:,0] = read_mc_det_pts
    
    return_dict = {}
    

    return_dict['true_det_pts'] = true_det_pts
    return_dict['mc_pts'] = mc_pts
    return_dict['mc_det_pts'] = mc_det_pts
    return_dict['ngen_true'] = ngen_true
    return_dict['ngen_mc'] = ngen_mc
    
    return return_dict

# %%
if not samples_from_GenerateInput :

    with open( '%s/mc-and-true-samples.npy' % input_unfolding_dir, 'rb') as f :
        mc_pts = np.load(f)
        mc_det_pts = np.load(f)
        true_pts = np.load(f)
        true_det_pts = np.load(f)
        
    print()
    print('mc_pts     shape :  %s ' % str(mc_pts.shape))
    print('mc_det_pts shape :  %s' % str(mc_det_pts.shape))
    print('true_pts      shape :  %s' % str(true_pts.shape))
    print('true_det_pts  shape :  %s' % str(true_det_pts.shape))
    print()
# Out:
# mc_pts     shape :  (100000, 1)
# mc_det_pts shape :  (100000, 1)
# true_pts      shape :  (10000, 1)
# true_det_pts  shape :  (10000, 1)

# %%
n_ensembles = 0

try :
    with open( '%s/omnifold-output-ensemble-run-weights.npy' % input_unfolding_dir, 'rb' ) as f :
        ensemble_final_push_weights = np.load(f)
        n_ensembles = ensemble_final_push_weights.shape[0]
        print('\n\n Found %d ensembles.\n\n' % n_ensembles)
except :
    print('\n\n *** Output for each ensemble run was not saved!  exiting\n\n')
    sys.exit()
# Out:
#  Found 10 ensembles.

# %% [markdown]
# ## Calculate the model parameters from simple average and covariance from weighted events

# %%
def calc_mean_cov( weights, fi1, fi2 ) :

    return_dict = {}
    
    wsum = np.sum( weights )
    
    wx1 = np.sum( weights * mc_pts[:,fi1] )
    wx2 = np.sum( weights * mc_pts[:,fi2] )
    wx1x2 = np.sum( weights * mc_pts[:,fi1] * mc_pts[:,fi2] )

    x1 = wx1 / wsum
    x2 = wx2 / wsum

    x1x2 = wx1x2 / wsum
    
    cov12 = x1x2 - x1*x2

    
    return_dict["mean_x1"] = x1
    return_dict["mean_x2"] = x2
    return_dict["cov_x1x2"] = cov12    
    
    if fi1 != fi2 :
        wx1x1 = np.sum( weights * mc_pts[:,fi1] * mc_pts[:,fi1] )
        wx2x2 = np.sum( weights * mc_pts[:,fi2] * mc_pts[:,fi2] )
        cov11 = wx1x1 / wsum - x1*x1
        cov22 = wx2x2 / wsum - x2*x2

        rms1 = np.sqrt(cov11)
        rms2 = np.sqrt(cov22)
        rho12 = cov12 / (rms1*rms2)     
    
        return_dict["rho12"] = rho12
        return_dict["rms1"] = rms1
        return_dict["rms2"] = rms2
    else :
        rms1 = np.sqrt(cov12)
        return_dict["rms1"] = rms1
        
    return return_dict

# %%
# %%time

all_mean = np.zeros( shape=(n_ensembles, ndim, n_samples) )
all_rms  = np.zeros( shape=(n_ensembles, ndim, n_samples) )
all_cov  = np.zeros( shape=(n_ensembles, ndim, ndim, n_samples) )
all_rho  = np.zeros( shape=(n_ensembles, ndim, ndim, n_samples) )

all_weight_min = np.zeros( n_samples )
all_weight_max = np.zeros( n_samples )

all_weight_sum = np.zeros( n_samples )


si = 0

for fi in range(n_samples) :
    
    if samples_from_GenerateInput :
        
        rd = read_sample( sample_input_dir, fi )

        ngen_true = rd['ngen_true']
        ngen_mc = rd['ngen_mc']

        true_det_pts = rd['true_det_pts']
        mc_pts = rd['mc_pts']
        mc_det_pts = rd['mc_det_pts']
        
        if fi < 5 :
            print(' mc_pts for sample %d : %s' % (fi, str(mc_pts)))
    

    
    fname = '%s/bootstrap-ensemble-run-weights-%03d.npy' % (input_unfolding_dir, fi)
    
    if exists(fname) :
        
        print('\n----- %s exists' % fname )
        
        with open(fname,'rb') as f :
            
            ensemble_final_push_weights = np.load(f)
            
        print( 'Shape of ensemble_final_push_weights : %s' % str(ensemble_final_push_weights.shape) )
        print( len(ensemble_final_push_weights))
        print( ensemble_final_push_weights )


        all_weight_min[si] = np.min( ensemble_final_push_weights )
        all_weight_max[si] = np.max( ensemble_final_push_weights )

        all_weight_sum[si] = np.sum( ensemble_final_push_weights )
        
        for ri in range( n_ensembles ) :
            
            ensemble_average_weights = np.average( ensemble_final_push_weights[0:ri+1], axis=0 )

            for fi1 in range(ndim) :
                for fi2 in range(fi1,ndim) :
                    mean_cov = calc_mean_cov( ensemble_average_weights, fi1, fi2 )
                    all_cov[ri, fi1,fi2,si] = mean_cov["cov_x1x2"]
                    all_cov[ri, fi2,fi1,si] = mean_cov["cov_x1x2"]
                    if ( fi1 == fi2 ) :
                        print( "  %2d  %d %d  :  mean = %8.4f, RMS = %8.4f, cov = %8.4f" % 
                              (ri, fi1, fi2, mean_cov["mean_x1"], mean_cov["rms1"], mean_cov["cov_x1x2"]))
                        all_mean[ri, fi1,si] = mean_cov["mean_x1"]
                        all_rms[ri, fi1,si] = mean_cov["rms1"]
                    else :
                        print( "  %2d  %d %d  :  rho = %8.4f,  cov = %8.4f" %
                              (ri, fi1, fi2, mean_cov["rho12"], mean_cov["cov_x1x2"]) )
                        all_rho[ri, fi1,fi2,si] = mean_cov["rho12"]
                        all_rho[ri, fi2,fi1,si] = mean_cov["rho12"]
                        
        si = si + 1
# Out:
# CPU times: user 190 μs, sys: 0 ns, total: 190 μs
# Wall time: 139 μs
#    2  0 0  :  mean =   0.1904, RMS =   0.8891, cov =   0.7905
#    3  0 0  :  mean =   0.1914, RMS =   0.8877, cov =   0.7879
#    4  0 0  :  mean =   0.1931, RMS =   0.8891, cov =   0.7905
#    5  0 0  :  mean =   0.1925, RMS =   0.8904, cov =   0.7927
#    6  0 0  :  mean =   0.1929, RMS =   0.8919, cov =   0.7955
#    7  0 0  :  mean =   0.1913, RMS =   0.8924, cov =   0.7964
#    8  0 0  :  mean =   0.1905, RMS =   0.8929, cov =   0.7973
#    9  0 0  :  mean =   0.1911, RMS =   0.8929, cov =   0.7973
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-019.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18490079 0.89627725 0.92583355 ... 1.10698916 1.15331107 0.84857745]
#  [1.18036159 0.87768215 0.90616743 ... 1.0917084  1.15529335 0.831313  ]
#  [1.21966453 0.88155704 0.91191228 ... 1.09883542 1.15208043 0.83222881]
#  ...
#  [1.23277585 0.92532347 0.95584088 ... 1.11330751 1.13827355 0.87405237]
#  [1.17233775 0.89132222 0.91857576 ... 1.09255776 1.1445567  0.8473865 ]
#  [1.22294132 0.89284773 0.92278867 ... 1.11033373 1.16382891 0.84392766]]
#    0  0 0  :  mean =   0.1901, RMS =   0.8952, cov =   0.8014
#    1  0 0  :  mean =   0.1950, RMS =   0.8949, cov =   0.8008
#    2  0 0  :  mean =   0.1966, RMS =   0.8970, cov =   0.8045
#    3  0 0  :  mean =   0.1950, RMS =   0.8976, cov =   0.8056
#    4  0 0  :  mean =   0.1946, RMS =   0.8982, cov =   0.8068
#    5  0 0  :  mean =   0.1928, RMS =   0.8993, cov =   0.8087
#    6  0 0  :  mean =   0.1915, RMS =   0.8994, cov =   0.8089
#    7  0 0  :  mean =   0.1912, RMS =   0.9000, cov =   0.8099
#    8  0 0  :  mean =   0.1898, RMS =   0.9002, cov =   0.8103
#    9  0 0  :  mean =   0.1906, RMS =   0.8998, cov =   0.8096
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-020.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.23396492 0.91022592 0.94215081 ... 1.11882244 1.15876437 0.85626934]
#  [1.18627832 0.90715769 0.93702516 ... 1.08927686 1.12204025 0.85531435]
#  [1.19893887 0.91578225 0.94363472 ... 1.09472341 1.14344118 0.86627848]
#  ...
#  [1.24848256 0.88807652 0.91893905 ... 1.08917451 1.14151536 0.83471986]
#  [1.17701759 0.91163653 0.94074678 ... 1.11503992 1.16602832 0.86202603]
#  [1.20582201 0.90553524 0.93398016 ... 1.08216378 1.12042402 0.85578066]]
#    0  0 0  :  mean =   0.2024, RMS =   0.8921, cov =   0.7958
#    1  0 0  :  mean =   0.1989, RMS =   0.8932, cov =   0.7977
#    2  0 0  :  mean =   0.2008, RMS =   0.8935, cov =   0.7983
#    3  0 0  :  mean =   0.2030, RMS =   0.8935, cov =   0.7983
#    4  0 0  :  mean =   0.2037, RMS =   0.8940, cov =   0.7993
#    5  0 0  :  mean =   0.2029, RMS =   0.8925, cov =   0.7965
#    6  0 0  :  mean =   0.2019, RMS =   0.8929, cov =   0.7973
#    7  0 0  :  mean =   0.2045, RMS =   0.8929, cov =   0.7972
#    8  0 0  :  mean =   0.2031, RMS =   0.8929, cov =   0.7972
#    9  0 0  :  mean =   0.2027, RMS =   0.8934, cov =   0.7981
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-021.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.17701451 0.88586735 0.92129401 ... 1.12471501 1.16249266 0.82895449]
#  [1.18167718 0.91871436 0.9459387  ... 1.10479188 1.15687922 0.87182251]
#  [1.23968614 0.91289256 0.93924218 ... 1.08617511 1.13700119 0.86675554]
#  ...
#  [1.18328582 0.87930161 0.91569487 ... 1.13902944 1.18786412 0.82084232]
#  [1.17240429 0.88065249 0.91273699 ... 1.11661352 1.16313528 0.82946551]
#  [1.19857313 0.88557082 0.91503468 ... 1.11400136 1.18081218 0.83790739]]
#    0  0 0  :  mean =   0.1893, RMS =   0.8932, cov =   0.7978
#    1  0 0  :  mean =   0.1868, RMS =   0.8944, cov =   0.8000
#    2  0 0  :  mean =   0.1889, RMS =   0.8978, cov =   0.8060
#    3  0 0  :  mean =   0.1898, RMS =   0.8963, cov =   0.8034
#    4  0 0  :  mean =   0.1892, RMS =   0.8975, cov =   0.8056
#    5  0 0  :  mean =   0.1900, RMS =   0.8974, cov =   0.8052
#    6  0 0  :  mean =   0.1897, RMS =   0.8963, cov =   0.8034
#    7  0 0  :  mean =   0.1905, RMS =   0.8954, cov =   0.8017
#    8  0 0  :  mean =   0.1902, RMS =   0.8951, cov =   0.8012
#    9  0 0  :  mean =   0.1910, RMS =   0.8954, cov =   0.8017
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-022.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.17244401 0.91501544 0.9411805  ... 1.10213644 1.15598453 0.87072525]
#  [1.22114318 0.89768983 0.91946342 ... 1.09570194 1.15994881 0.86408726]
#  [1.14216921 0.88071238 0.90342212 ... 1.06080904 1.12479062 0.84256977]
#  ...
#  [1.16155567 0.88391992 0.90789636 ... 1.0873077  1.15575168 0.84515109]
#  [1.15263765 0.92415705 0.95126934 ... 1.12393898 1.18623785 0.87843667]
#  [1.15663724 0.91341195 0.93935721 ... 1.09914993 1.15279742 0.86932255]]
#    0  0 0  :  mean =   0.1858, RMS =   0.8957, cov =   0.8023
#    1  0 0  :  mean =   0.1898, RMS =   0.9011, cov =   0.8121
#    2  0 0  :  mean =   0.1894, RMS =   0.9003, cov =   0.8105
#    3  0 0  :  mean =   0.1883, RMS =   0.9017, cov =   0.8131
#    4  0 0  :  mean =   0.1889, RMS =   0.9015, cov =   0.8126
#    5  0 0  :  mean =   0.1892, RMS =   0.9017, cov =   0.8130
#    6  0 0  :  mean =   0.1906, RMS =   0.9009, cov =   0.8116
#    7  0 0  :  mean =   0.1906, RMS =   0.8999, cov =   0.8098
#    8  0 0  :  mean =   0.1897, RMS =   0.8993, cov =   0.8088
#    9  0 0  :  mean =   0.1893, RMS =   0.8991, cov =   0.8085
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-023.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18115156 0.87213041 0.89177187 ... 1.05459873 1.13750405 0.8385745 ]
#  [1.1996111  0.89667168 0.91981844 ... 1.07085381 1.14071924 0.85580816]
#  [1.15656114 0.90495053 0.92680198 ... 1.0744084  1.1446249  0.86587981]
#  ...
#  [1.25414575 0.86918854 0.89373199 ... 1.08197015 1.16184545 0.82933607]
#  [1.1298024  0.8631394  0.88995062 ... 1.08064779 1.16324017 0.81816396]
#  [1.19989148 0.86343358 0.8894467  ... 1.07769536 1.1652832  0.81887332]]
#    0  0 0  :  mean =   0.2133, RMS =   0.9073, cov =   0.8233
#    1  0 0  :  mean =   0.2109, RMS =   0.9080, cov =   0.8244
#    2  0 0  :  mean =   0.2077, RMS =   0.9048, cov =   0.8186
#    3  0 0  :  mean =   0.2111, RMS =   0.9033, cov =   0.8160
#    4  0 0  :  mean =   0.2094, RMS =   0.9027, cov =   0.8149
#    5  0 0  :  mean =   0.2127, RMS =   0.9027, cov =   0.8148
#    6  0 0  :  mean =   0.2128, RMS =   0.9039, cov =   0.8170
#    7  0 0  :  mean =   0.2147, RMS =   0.9038, cov =   0.8168
#    8  0 0  :  mean =   0.2148, RMS =   0.9027, cov =   0.8149
#    9  0 0  :  mean =   0.2165, RMS =   0.9020, cov =   0.8136
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-024.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.17274115 0.8447827  0.87389747 ... 1.09275178 1.17338588 0.79913662]
#  [1.10777838 0.88063672 0.90726126 ... 1.08894109 1.17383519 0.83600011]
#  [1.18208793 0.85380914 0.87861799 ... 1.12632829 1.21110694 0.81802373]
#  ...
#  [1.19747423 0.843572   0.87017924 ... 1.07615372 1.16345972 0.80106527]
#  [1.14098173 0.8364549  0.86388041 ... 1.10607565 1.19590753 0.79617394]
#  [1.13002891 0.85785815 0.88477612 ... 1.10723408 1.20056524 0.81580055]]
#    0  0 0  :  mean =   0.2154, RMS =   0.8955, cov =   0.8020
#    1  0 0  :  mean =   0.2061, RMS =   0.8911, cov =   0.7941
#    2  0 0  :  mean =   0.2080, RMS =   0.8919, cov =   0.7955
#    3  0 0  :  mean =   0.2039, RMS =   0.8905, cov =   0.7930
#    4  0 0  :  mean =   0.2041, RMS =   0.8913, cov =   0.7944
#    5  0 0  :  mean =   0.2057, RMS =   0.8919, cov =   0.7955
#    6  0 0  :  mean =   0.2050, RMS =   0.8930, cov =   0.7974
#    7  0 0  :  mean =   0.2073, RMS =   0.8936, cov =   0.7984
#    8  0 0  :  mean =   0.2070, RMS =   0.8946, cov =   0.8003
#    9  0 0  :  mean =   0.2067, RMS =   0.8942, cov =   0.7995
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-025.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.22218366 0.87916533 0.90609655 ... 1.07735566 1.1466375  0.833311  ]
#  [1.19720822 0.89695369 0.92692182 ... 1.12101777 1.18070879 0.84726786]
#  [1.20352224 0.86990216 0.89691731 ... 1.10699232 1.18629769 0.82695813]
#  ...
#  [1.24918121 0.86693279 0.89641039 ... 1.07786408 1.13353856 0.81816377]
#  [1.15364248 0.86817839 0.89458993 ... 1.08237016 1.15588632 0.82439555]
#  [1.23154657 0.89616625 0.92446217 ... 1.09866739 1.16107336 0.84807074]]
#    0  0 0  :  mean =   0.2205, RMS =   0.8979, cov =   0.8062
#    1  0 0  :  mean =   0.2146, RMS =   0.8946, cov =   0.8003
#    2  0 0  :  mean =   0.2144, RMS =   0.8947, cov =   0.8005
#    3  0 0  :  mean =   0.2153, RMS =   0.8936, cov =   0.7985
#    4  0 0  :  mean =   0.2165, RMS =   0.8938, cov =   0.7989
#    5  0 0  :  mean =   0.2175, RMS =   0.8946, cov =   0.8003
#    6  0 0  :  mean =   0.2150, RMS =   0.8953, cov =   0.8015
#    7  0 0  :  mean =   0.2159, RMS =   0.8959, cov =   0.8026
#    8  0 0  :  mean =   0.2150, RMS =   0.8956, cov =   0.8022
#    9  0 0  :  mean =   0.2149, RMS =   0.8962, cov =   0.8032
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-026.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.11551972 0.89423359 0.91017439 ... 1.06880421 1.17159433 0.86503616]
#  [1.07021152 0.88070935 0.89607502 ... 1.05634213 1.17185751 0.85254976]
#  [1.05076248 0.89873485 0.91481545 ... 1.04185853 1.12957077 0.86915662]
#  ...
#  [1.08723473 0.88404964 0.89620851 ... 1.01640355 1.11253426 0.86072459]
#  [1.0950168  0.88604441 0.90621007 ... 1.08322204 1.17248996 0.85333114]
#  [1.08402034 0.89390356 0.91135331 ... 1.05318069 1.14234444 0.86263722]]
#    0  0 0  :  mean =   0.1907, RMS =   0.9010, cov =   0.8117
#    1  0 0  :  mean =   0.1867, RMS =   0.9007, cov =   0.8113
#    2  0 0  :  mean =   0.1812, RMS =   0.9043, cov =   0.8178
#    3  0 0  :  mean =   0.1792, RMS =   0.9058, cov =   0.8205
#    4  0 0  :  mean =   0.1806, RMS =   0.9048, cov =   0.8186
#    5  0 0  :  mean =   0.1811, RMS =   0.9039, cov =   0.8170
#    6  0 0  :  mean =   0.1833, RMS =   0.9043, cov =   0.8177
#    7  0 0  :  mean =   0.1828, RMS =   0.9050, cov =   0.8191
#    8  0 0  :  mean =   0.1822, RMS =   0.9049, cov =   0.8188
#    9  0 0  :  mean =   0.1821, RMS =   0.9053, cov =   0.8196
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-027.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.13617468 0.89667467 0.92839778 ... 1.11153295 1.14774093 0.84526379]
#  [1.12209212 0.90858544 0.9393942  ... 1.1383783  1.17664056 0.86149468]
#  [1.10396985 0.89968071 0.93205909 ... 1.12357918 1.15984158 0.84802306]
#  ...
#  [1.08488226 0.89609017 0.92606265 ... 1.12173179 1.16807786 0.84783459]
#  [1.13024849 0.90703792 0.936022   ... 1.10665595 1.15373418 0.8583066 ]
#  [1.06671292 0.88923799 0.92358572 ... 1.12122349 1.15937083 0.83352673]]
#    0  0 0  :  mean =   0.1771, RMS =   0.9070, cov =   0.8227
#    1  0 0  :  mean =   0.1718, RMS =   0.9047, cov =   0.8184
#    2  0 0  :  mean =   0.1708, RMS =   0.9040, cov =   0.8172
#    3  0 0  :  mean =   0.1719, RMS =   0.9019, cov =   0.8134
#    4  0 0  :  mean =   0.1721, RMS =   0.9033, cov =   0.8160
#    5  0 0  :  mean =   0.1704, RMS =   0.9040, cov =   0.8171
#    6  0 0  :  mean =   0.1709, RMS =   0.9034, cov =   0.8161
#    7  0 0  :  mean =   0.1710, RMS =   0.9031, cov =   0.8155
#    8  0 0  :  mean =   0.1719, RMS =   0.9031, cov =   0.8156
#    9  0 0  :  mean =   0.1716, RMS =   0.9026, cov =   0.8147
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-028.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18697588 0.88102922 0.91087458 ... 1.10646353 1.16956503 0.83211945]
#  [1.18390852 0.85637296 0.88851253 ... 1.12034019 1.17319122 0.80712416]
#  [1.15596925 0.86087706 0.89470855 ... 1.10383697 1.15449077 0.80773619]
#  ...
#  [1.13869166 0.87033424 0.90371848 ... 1.12878077 1.19209843 0.8160177 ]
#  [1.15797264 0.842129   0.87452599 ... 1.09642361 1.15771789 0.79145105]
#  [1.19640319 0.88076937 0.91327696 ... 1.11840619 1.17842049 0.82749566]]
#    0  0 0  :  mean =   0.2044, RMS =   0.9029, cov =   0.8153
#    1  0 0  :  mean =   0.2027, RMS =   0.9036, cov =   0.8165
#    2  0 0  :  mean =   0.2027, RMS =   0.9000, cov =   0.8099
#    3  0 0  :  mean =   0.2011, RMS =   0.8985, cov =   0.8073
#    4  0 0  :  mean =   0.1999, RMS =   0.8970, cov =   0.8046
#    5  0 0  :  mean =   0.1979, RMS =   0.8965, cov =   0.8037
#    6  0 0  :  mean =   0.1972, RMS =   0.8958, cov =   0.8025
#    7  0 0  :  mean =   0.1978, RMS =   0.8949, cov =   0.8008
#    8  0 0  :  mean =   0.1983, RMS =   0.8971, cov =   0.8048
#    9  0 0  :  mean =   0.1997, RMS =   0.8971, cov =   0.8048
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-029.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18624108 0.88545408 0.92131891 ... 1.09178885 1.12170658 0.82562048]
#  [1.21781865 0.91505978 0.9456172  ... 1.11907295 1.17972958 0.86086147]
#  [1.14098293 0.87712681 0.91129176 ... 1.11844381 1.17291432 0.81946113]
#  ...
#  [1.21206698 0.89658476 0.93111147 ... 1.12430784 1.17798453 0.83762188]
#  [1.25611749 0.92221114 0.95799147 ... 1.10349702 1.13801773 0.85839883]
#  [1.16062375 0.90008866 0.93313548 ... 1.09586011 1.14154419 0.84189591]]
#    0  0 0  :  mean =   0.2046, RMS =   0.8887, cov =   0.7899
#    1  0 0  :  mean =   0.2131, RMS =   0.8896, cov =   0.7913
#    2  0 0  :  mean =   0.2119, RMS =   0.8871, cov =   0.7869
#    3  0 0  :  mean =   0.2116, RMS =   0.8857, cov =   0.7845
#    4  0 0  :  mean =   0.2122, RMS =   0.8842, cov =   0.7819
#    5  0 0  :  mean =   0.2126, RMS =   0.8868, cov =   0.7865
#    6  0 0  :  mean =   0.2106, RMS =   0.8864, cov =   0.7858
#    7  0 0  :  mean =   0.2117, RMS =   0.8861, cov =   0.7851
#    8  0 0  :  mean =   0.2127, RMS =   0.8866, cov =   0.7861
#    9  0 0  :  mean =   0.2120, RMS =   0.8863, cov =   0.7856
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-030.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.16272318 0.88870966 0.91638339 ... 1.09557816 1.15074516 0.84244371]
#  [1.11688835 0.92479342 0.95035894 ... 1.12536311 1.1857261  0.88142388]
#  [1.18037148 0.93759142 0.96210542 ... 1.11623214 1.17588287 0.89450041]
#  ...
#  [1.1650254  0.91835866 0.94798581 ... 1.12282528 1.17322366 0.86815547]
#  [1.15020224 0.92052469 0.94782052 ... 1.10788925 1.15854499 0.87317957]
#  [1.10391526 0.90328639 0.92911146 ... 1.11008016 1.15011058 0.86217184]]
#    0  0 0  :  mean =   0.2043, RMS =   0.8943, cov =   0.7998
#    1  0 0  :  mean =   0.1945, RMS =   0.8948, cov =   0.8006
#    2  0 0  :  mean =   0.1952, RMS =   0.8961, cov =   0.8029
#    3  0 0  :  mean =   0.1964, RMS =   0.8938, cov =   0.7989
#    4  0 0  :  mean =   0.1964, RMS =   0.8958, cov =   0.8024
#    5  0 0  :  mean =   0.1954, RMS =   0.8958, cov =   0.8025
#    6  0 0  :  mean =   0.1937, RMS =   0.8956, cov =   0.8022
#    7  0 0  :  mean =   0.1941, RMS =   0.8949, cov =   0.8009
#    8  0 0  :  mean =   0.1941, RMS =   0.8946, cov =   0.8003
#    9  0 0  :  mean =   0.1931, RMS =   0.8944, cov =   0.8000
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-031.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.22465852 0.91385822 0.95000464 ... 1.1497566  1.18949252 0.85381131]
#  [1.19712818 0.88795513 0.924834   ... 1.12790121 1.164916   0.82745511]
#  [1.21875959 0.88597911 0.919809   ... 1.11641986 1.16165312 0.83016959]
#  ...
#  [1.1716193  0.89697145 0.92940698 ... 1.12653342 1.18273867 0.8429225 ]
#  [1.19363271 0.88433598 0.92221667 ... 1.12109274 1.16261787 0.82193168]
#  [1.23190648 0.90581599 0.94280578 ... 1.13301773 1.17231816 0.84381823]]
#    0  0 0  :  mean =   0.2051, RMS =   0.8975, cov =   0.8055
#    1  0 0  :  mean =   0.2031, RMS =   0.8987, cov =   0.8077
#    2  0 0  :  mean =   0.2056, RMS =   0.8975, cov =   0.8056
#    3  0 0  :  mean =   0.2025, RMS =   0.8967, cov =   0.8040
#    4  0 0  :  mean =   0.2023, RMS =   0.8958, cov =   0.8024
#    5  0 0  :  mean =   0.2026, RMS =   0.8952, cov =   0.8014
#    6  0 0  :  mean =   0.2030, RMS =   0.8955, cov =   0.8019
#    7  0 0  :  mean =   0.2027, RMS =   0.8949, cov =   0.8008
#    8  0 0  :  mean =   0.2032, RMS =   0.8945, cov =   0.8001
#    9  0 0  :  mean =   0.2034, RMS =   0.8944, cov =   0.7999
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-032.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.24293065 0.95496125 0.98113955 ... 1.0916111  1.13351881 0.90631141]
#  [1.25088228 0.91093112 0.93449285 ... 1.07577095 1.1228582  0.87063356]
#  [1.22188187 0.88874985 0.91264088 ... 1.06904415 1.12997461 0.84858494]
#  ...
#  [1.20266941 0.94551585 0.97756461 ... 1.12919205 1.14714534 0.89123643]
#  [1.18095519 0.91451337 0.94290616 ... 1.07972275 1.11496739 0.86461458]
#  [1.23761046 0.90595475 0.92923355 ... 1.08160182 1.14002893 0.86696707]]
#    0  0 0  :  mean =   0.1970, RMS =   0.9042, cov =   0.8176
#    1  0 0  :  mean =   0.1960, RMS =   0.9082, cov =   0.8248
#    2  0 0  :  mean =   0.1972, RMS =   0.9101, cov =   0.8283
#    3  0 0  :  mean =   0.1950, RMS =   0.9106, cov =   0.8291
#    4  0 0  :  mean =   0.1941, RMS =   0.9088, cov =   0.8260
#    5  0 0  :  mean =   0.1946, RMS =   0.9083, cov =   0.8250
#    6  0 0  :  mean =   0.1927, RMS =   0.9079, cov =   0.8243
#    7  0 0  :  mean =   0.1917, RMS =   0.9073, cov =   0.8233
#    8  0 0  :  mean =   0.1915, RMS =   0.9069, cov =   0.8225
#    9  0 0  :  mean =   0.1920, RMS =   0.9079, cov =   0.8243
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-033.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.13003785 0.91555947 0.94787979 ... 1.14362576 1.20264353 0.86123998]
#  [1.10873782 0.92921023 0.96082183 ... 1.13578137 1.17880961 0.875122  ]
#  [1.11461923 0.87933371 0.91261967 ... 1.11611925 1.17525626 0.82406009]
#  ...
#  [1.12972565 0.89326138 0.92870757 ... 1.11642016 1.17492019 0.8323929 ]
#  [1.14373329 0.87676927 0.90707101 ... 1.10357399 1.1687216  0.8264189 ]
#  [1.14440514 0.91058141 0.94402084 ... 1.13788804 1.18143415 0.8542355 ]]
#    0  0 0  :  mean =   0.1892, RMS =   0.8732, cov =   0.7626
#    1  0 0  :  mean =   0.1836, RMS =   0.8765, cov =   0.7682
#    2  0 0  :  mean =   0.1864, RMS =   0.8785, cov =   0.7717
#    3  0 0  :  mean =   0.1859, RMS =   0.8757, cov =   0.7669
#    4  0 0  :  mean =   0.1872, RMS =   0.8744, cov =   0.7647
#    5  0 0  :  mean =   0.1875, RMS =   0.8762, cov =   0.7678
#    6  0 0  :  mean =   0.1876, RMS =   0.8758, cov =   0.7670
#    7  0 0  :  mean =   0.1892, RMS =   0.8755, cov =   0.7665
#    8  0 0  :  mean =   0.1908, RMS =   0.8758, cov =   0.7670
#    9  0 0  :  mean =   0.1909, RMS =   0.8762, cov =   0.7677
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-034.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.19079043 0.87840255 0.90041819 ... 1.04544774 1.10887784 0.84050011]
#  [1.17999655 0.87659456 0.89970891 ... 1.0740436  1.14813256 0.83871491]
#  [1.17610813 0.87406299 0.89841823 ... 1.06227967 1.12502468 0.83318735]
#  ...
#  [1.22965561 0.8921796  0.9187289  ... 1.07797421 1.12813083 0.84746672]
#  [1.21275682 0.88242947 0.90428066 ... 1.08354209 1.1705561  0.84643387]
#  [1.20484882 0.88659442 0.91020546 ... 1.06377346 1.120253   0.84669778]]
#    0  0 0  :  mean =   0.1982, RMS =   0.9136, cov =   0.8347
#    1  0 0  :  mean =   0.1979, RMS =   0.9110, cov =   0.8299
#    2  0 0  :  mean =   0.1983, RMS =   0.9099, cov =   0.8280
#    3  0 0  :  mean =   0.1984, RMS =   0.9118, cov =   0.8313
#    4  0 0  :  mean =   0.2014, RMS =   0.9117, cov =   0.8312
#    5  0 0  :  mean =   0.2022, RMS =   0.9117, cov =   0.8312
#    6  0 0  :  mean =   0.2033, RMS =   0.9119, cov =   0.8315
#    7  0 0  :  mean =   0.2034, RMS =   0.9125, cov =   0.8327
#    8  0 0  :  mean =   0.2036, RMS =   0.9122, cov =   0.8321
#    9  0 0  :  mean =   0.2035, RMS =   0.9125, cov =   0.8327
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-035.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.20967183 0.94239093 0.96484339 ... 1.09080447 1.13952327 0.90100118]
#  [1.21838885 0.931751   0.95174461 ... 1.06511534 1.11277842 0.89510157]
#  [1.20032595 0.93178515 0.9554027  ... 1.07606607 1.112359   0.8892924 ]
#  ...
#  [1.24250359 0.95073771 0.97359637 ... 1.1003701  1.14186591 0.90968587]
#  [1.17270759 0.90605905 0.9346647  ... 1.09827687 1.1226834  0.86082862]
#  [1.24198925 0.93779727 0.96005298 ... 1.07962873 1.11678386 0.89772633]]
#    0  0 0  :  mean =   0.1935, RMS =   0.8976, cov =   0.8056
#    1  0 0  :  mean =   0.1910, RMS =   0.9017, cov =   0.8130
#    2  0 0  :  mean =   0.1896, RMS =   0.9021, cov =   0.8137
#    3  0 0  :  mean =   0.1910, RMS =   0.9034, cov =   0.8161
#    4  0 0  :  mean =   0.1928, RMS =   0.9027, cov =   0.8149
#    5  0 0  :  mean =   0.1915, RMS =   0.9007, cov =   0.8113
#    6  0 0  :  mean =   0.1897, RMS =   0.9002, cov =   0.8104
#    7  0 0  :  mean =   0.1904, RMS =   0.8998, cov =   0.8096
#    8  0 0  :  mean =   0.1901, RMS =   0.8987, cov =   0.8076
#    9  0 0  :  mean =   0.1906, RMS =   0.8991, cov =   0.8083
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-036.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.15154583 0.92904556 0.95853581 ... 1.10852475 1.15135527 0.87694581]
#  [1.15822196 0.91003045 0.9330437  ... 1.07954835 1.14417838 0.86964663]
#  [1.13727527 0.89903418 0.92245058 ... 1.07795129 1.14859455 0.85822427]
#  ...
#  [1.15106752 0.91414511 0.93894892 ... 1.10933995 1.1713671  0.87171314]
#  [1.15357621 0.88940687 0.9170677  ... 1.09477568 1.15963517 0.84314543]
#  [1.16703787 0.91053602 0.93692247 ... 1.09292448 1.14874146 0.86479006]]
#    0  0 0  :  mean =   0.1895, RMS =   0.8832, cov =   0.7800
#    1  0 0  :  mean =   0.1890, RMS =   0.8868, cov =   0.7864
#    2  0 0  :  mean =   0.1895, RMS =   0.8876, cov =   0.7878
#    3  0 0  :  mean =   0.1911, RMS =   0.8882, cov =   0.7889
#    4  0 0  :  mean =   0.1902, RMS =   0.8887, cov =   0.7899
#    5  0 0  :  mean =   0.1914, RMS =   0.8893, cov =   0.7908
#    6  0 0  :  mean =   0.1913, RMS =   0.8887, cov =   0.7898
#    7  0 0  :  mean =   0.1913, RMS =   0.8881, cov =   0.7887
#    8  0 0  :  mean =   0.1926, RMS =   0.8883, cov =   0.7890
#    9  0 0  :  mean =   0.1925, RMS =   0.8886, cov =   0.7895
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-037.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.21933705 0.9311029  0.96180843 ... 1.11005323 1.13308265 0.87802448]
#  [1.21183923 0.94065856 0.96772492 ... 1.10790446 1.14068727 0.89325458]
#  [1.20575602 0.9056553  0.93461322 ... 1.10603445 1.1300331  0.85963274]
#  ...
#  [1.17840744 0.8981724  0.92818593 ... 1.1239479  1.17663877 0.8491446 ]
#  [1.17887528 0.90902259 0.93731145 ... 1.08996658 1.12121062 0.86107934]
#  [1.2097856  0.92466737 0.95223704 ... 1.10927802 1.15397579 0.87768875]]
#    0  0 0  :  mean =   0.1944, RMS =   0.9045, cov =   0.8181
#    1  0 0  :  mean =   0.1926, RMS =   0.9059, cov =   0.8207
#    2  0 0  :  mean =   0.1932, RMS =   0.9064, cov =   0.8216
#    3  0 0  :  mean =   0.1922, RMS =   0.9055, cov =   0.8199
#    4  0 0  :  mean =   0.1952, RMS =   0.9062, cov =   0.8212
#    5  0 0  :  mean =   0.1965, RMS =   0.9065, cov =   0.8217
#    6  0 0  :  mean =   0.1963, RMS =   0.9051, cov =   0.8192
#    7  0 0  :  mean =   0.1968, RMS =   0.9039, cov =   0.8170
#    8  0 0  :  mean =   0.1966, RMS =   0.9034, cov =   0.8162
#    9  0 0  :  mean =   0.1960, RMS =   0.9031, cov =   0.8156
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-038.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.23639634 0.93066084 0.95545735 ... 1.08457425 1.11796044 0.88659218]
#  [1.27459235 0.92019735 0.94258677 ... 1.05287518 1.0951061  0.87824078]
#  [1.28589769 0.9238556  0.94803552 ... 1.07406729 1.11595352 0.88064484]
#  ...
#  [1.24414429 0.92649465 0.9488838  ... 1.07845592 1.12494064 0.88727699]
#  [1.21912492 0.94142932 0.96983856 ... 1.10534643 1.14156909 0.89038451]
#  [1.24244481 0.90403386 0.92773258 ... 1.07699121 1.1324871  0.86275623]]
#    0  0 0  :  mean =   0.1920, RMS =   0.8919, cov =   0.7954
#    1  0 0  :  mean =   0.2004, RMS =   0.8980, cov =   0.8063
#    2  0 0  :  mean =   0.2011, RMS =   0.9008, cov =   0.8114
#    3  0 0  :  mean =   0.1972, RMS =   0.8998, cov =   0.8097
#    4  0 0  :  mean =   0.1960, RMS =   0.8999, cov =   0.8098
#    5  0 0  :  mean =   0.1948, RMS =   0.8994, cov =   0.8089
#    6  0 0  :  mean =   0.1933, RMS =   0.8988, cov =   0.8079
#    7  0 0  :  mean =   0.1932, RMS =   0.9008, cov =   0.8115
#    8  0 0  :  mean =   0.1933, RMS =   0.9001, cov =   0.8103
#    9  0 0  :  mean =   0.1949, RMS =   0.9003, cov =   0.8105
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-039.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.12085681 0.85352282 0.88274988 ... 1.10144369 1.18121715 0.80778345]
#  [1.14326792 0.88832708 0.91497778 ... 1.10393464 1.18039235 0.84434751]
#  [1.12602611 0.88490241 0.91407214 ... 1.10988703 1.18064354 0.8366584 ]
#  ...
#  [1.13383023 0.88029755 0.90525919 ... 1.0922777  1.17117383 0.83886912]
#  [1.13471834 0.8688494  0.89706299 ... 1.09437921 1.16731176 0.82257931]
#  [1.15823847 0.8672619  0.89527954 ... 1.1067087  1.18505123 0.82283702]]
#    0  0 0  :  mean =   0.2068, RMS =   0.8889, cov =   0.7902
#    1  0 0  :  mean =   0.2011, RMS =   0.8924, cov =   0.7964
#    2  0 0  :  mean =   0.1992, RMS =   0.8923, cov =   0.7961
#    3  0 0  :  mean =   0.2041, RMS =   0.8916, cov =   0.7950
#    4  0 0  :  mean =   0.2055, RMS =   0.8919, cov =   0.7955
#    5  0 0  :  mean =   0.2050, RMS =   0.8923, cov =   0.7962
#    6  0 0  :  mean =   0.2053, RMS =   0.8917, cov =   0.7951
#    7  0 0  :  mean =   0.2047, RMS =   0.8917, cov =   0.7952
#    8  0 0  :  mean =   0.2044, RMS =   0.8919, cov =   0.7954
#    9  0 0  :  mean =   0.2043, RMS =   0.8917, cov =   0.7951
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-040.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.1314217  0.88362771 0.9075173  ... 1.11790685 1.19157682 0.84649509]
#  [1.17889649 0.88746744 0.9162341  ... 1.11946688 1.18401039 0.8414623 ]
#  [1.17235417 0.89419438 0.9223653  ... 1.11294177 1.17948922 0.84781922]
#  ...
#  [1.14763047 0.8997437  0.9301504  ... 1.11164907 1.16090909 0.84901083]
#  [1.15599072 0.88072385 0.91269588 ... 1.13316694 1.19974149 0.82989522]
#  [1.13938061 0.87711814 0.90849311 ... 1.11955407 1.18040572 0.8261823 ]]
#    0  0 0  :  mean =   0.1811, RMS =   0.8965, cov =   0.8037
#    1  0 0  :  mean =   0.1887, RMS =   0.8975, cov =   0.8056
#    2  0 0  :  mean =   0.1923, RMS =   0.8989, cov =   0.8080
#    3  0 0  :  mean =   0.1931, RMS =   0.8960, cov =   0.8028
#    4  0 0  :  mean =   0.1917, RMS =   0.8935, cov =   0.7983
#    5  0 0  :  mean =   0.1922, RMS =   0.8934, cov =   0.7981
#    6  0 0  :  mean =   0.1923, RMS =   0.8928, cov =   0.7972
#    7  0 0  :  mean =   0.1920, RMS =   0.8930, cov =   0.7975
#    8  0 0  :  mean =   0.1931, RMS =   0.8921, cov =   0.7958
#    9  0 0  :  mean =   0.1932, RMS =   0.8918, cov =   0.7953
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-041.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.16624022 0.88245443 0.91842323 ... 1.12860854 1.16263554 0.82640506]
#  [1.16584097 0.90293093 0.93683418 ... 1.12676469 1.16402109 0.84748617]
#  [1.19240988 0.88534326 0.92014749 ... 1.11559255 1.16203708 0.82897723]
#  ...
#  [1.13436768 0.8884494  0.91770193 ... 1.10482826 1.15983491 0.8401468 ]
#  [1.12972741 0.89762451 0.93155745 ... 1.1384536  1.18529456 0.8430722 ]
#  [1.14528967 0.87994421 0.91328206 ... 1.11518621 1.15547416 0.82716556]]
#    0  0 0  :  mean =   0.1906, RMS =   0.8964, cov =   0.8036
#    1  0 0  :  mean =   0.1886, RMS =   0.8957, cov =   0.8023
#    2  0 0  :  mean =   0.1929, RMS =   0.8955, cov =   0.8019
#    3  0 0  :  mean =   0.1916, RMS =   0.8978, cov =   0.8060
#    4  0 0  :  mean =   0.1894, RMS =   0.8985, cov =   0.8074
#    5  0 0  :  mean =   0.1903, RMS =   0.8982, cov =   0.8068
#    6  0 0  :  mean =   0.1911, RMS =   0.8994, cov =   0.8089
#    7  0 0  :  mean =   0.1914, RMS =   0.8984, cov =   0.8070
#    8  0 0  :  mean =   0.1906, RMS =   0.8979, cov =   0.8062
#    9  0 0  :  mean =   0.1899, RMS =   0.8975, cov =   0.8056
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-042.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.1572939  0.90276429 0.92784116 ... 1.08911754 1.14900485 0.85949594]
#  [1.20290642 0.92888469 0.95672998 ... 1.1216851  1.17363235 0.88076189]
#  [1.17940116 0.93345987 0.95893667 ... 1.1090054  1.15927577 0.88909169]
#  ...
#  [1.18703497 0.90223039 0.9301217  ... 1.10325979 1.15798367 0.85511552]
#  [1.12706575 0.87978938 0.90717009 ... 1.10605364 1.1764225  0.83552914]
#  [1.12662288 0.88265552 0.91349098 ... 1.107314   1.1594534  0.83222146]]
#    0  0 0  :  mean =   0.1899, RMS =   0.8975, cov =   0.8056
#    1  0 0  :  mean =   0.1944, RMS =   0.8955, cov =   0.8020
#    2  0 0  :  mean =   0.1918, RMS =   0.8958, cov =   0.8024
#    3  0 0  :  mean =   0.1934, RMS =   0.8926, cov =   0.7967
#    4  0 0  :  mean =   0.1947, RMS =   0.8926, cov =   0.7968
#    5  0 0  :  mean =   0.1970, RMS =   0.8932, cov =   0.7978
#    6  0 0  :  mean =   0.1957, RMS =   0.8921, cov =   0.7958
#    7  0 0  :  mean =   0.1960, RMS =   0.8921, cov =   0.7958
#    8  0 0  :  mean =   0.1963, RMS =   0.8917, cov =   0.7951
#    9  0 0  :  mean =   0.1961, RMS =   0.8919, cov =   0.7955
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-043.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.08430624 0.89219388 0.9294634  ... 1.1538387  1.21289723 0.82953474]
#  [1.13636519 0.89237376 0.92523808 ... 1.12893297 1.19957792 0.8356662 ]
#  [1.13130273 0.88818209 0.91995423 ... 1.13928429 1.2181578  0.83572906]
#  ...
#  [1.16231344 0.8952664  0.9288315  ... 1.11983128 1.17257756 0.83870023]
#  [1.11259746 0.88552844 0.91606728 ... 1.10430453 1.17429015 0.83332118]
#  [1.1789834  0.8860498  0.9208409  ... 1.13728496 1.19650984 0.82920951]]
#    0  0 0  :  mean =   0.1962, RMS =   0.8727, cov =   0.7616
#    1  0 0  :  mean =   0.1995, RMS =   0.8746, cov =   0.7649
#    2  0 0  :  mean =   0.1991, RMS =   0.8776, cov =   0.7701
#    3  0 0  :  mean =   0.1989, RMS =   0.8789, cov =   0.7725
#    4  0 0  :  mean =   0.1971, RMS =   0.8789, cov =   0.7724
#    5  0 0  :  mean =   0.1964, RMS =   0.8787, cov =   0.7720
#    6  0 0  :  mean =   0.1975, RMS =   0.8789, cov =   0.7724
#    7  0 0  :  mean =   0.1975, RMS =   0.8795, cov =   0.7735
#    8  0 0  :  mean =   0.1974, RMS =   0.8795, cov =   0.7736
#    9  0 0  :  mean =   0.1984, RMS =   0.8799, cov =   0.7742
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-044.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.19232562 0.921881   0.95452701 ... 1.13000441 1.1668305  0.86664562]
#  [1.13226215 0.87722207 0.90555113 ... 1.09204322 1.14613367 0.8311378 ]
#  [1.21481297 0.90275396 0.93325974 ... 1.11776582 1.17112136 0.85205939]
#  ...
#  [1.20749679 0.88161821 0.91273808 ... 1.11509611 1.17053403 0.83091507]
#  [1.19959593 0.89980786 0.92872611 ... 1.11850308 1.17354246 0.85245822]
#  [1.19048202 0.88362245 0.91381092 ... 1.1123597  1.17390388 0.83409039]]
#    0  0 0  :  mean =   0.1964, RMS =   0.8860, cov =   0.7850
#    1  0 0  :  mean =   0.1941, RMS =   0.8875, cov =   0.7877
#    2  0 0  :  mean =   0.1991, RMS =   0.8875, cov =   0.7877
#    3  0 0  :  mean =   0.1986, RMS =   0.8880, cov =   0.7886
#    4  0 0  :  mean =   0.2001, RMS =   0.8876, cov =   0.7879
#    5  0 0  :  mean =   0.2001, RMS =   0.8870, cov =   0.7868
#    6  0 0  :  mean =   0.2003, RMS =   0.8877, cov =   0.7881
#    7  0 0  :  mean =   0.2015, RMS =   0.8877, cov =   0.7880
#    8  0 0  :  mean =   0.2020, RMS =   0.8882, cov =   0.7889
#    9  0 0  :  mean =   0.2029, RMS =   0.8879, cov =   0.7883
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-045.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.20374286 0.8737992  0.89515691 ... 1.05184973 1.12664329 0.83727822]
#  [1.15212232 0.88392026 0.90707854 ... 1.06971984 1.15183264 0.84262662]
#  [1.17419346 0.9131299  0.93881774 ... 1.10015615 1.17275802 0.867011  ]
#  ...
#  [1.23298126 0.89631671 0.92299459 ... 1.07581674 1.14258488 0.84847011]
#  [1.21953052 0.88583282 0.91294535 ... 1.08290942 1.14842302 0.83956842]
#  [1.21991878 0.90521598 0.93174553 ... 1.08931108 1.15236077 0.85815149]]
#    0  0 0  :  mean =   0.2114, RMS =   0.8989, cov =   0.8080
#    1  0 0  :  mean =   0.2127, RMS =   0.8918, cov =   0.7953
#    2  0 0  :  mean =   0.2118, RMS =   0.8886, cov =   0.7896
#    3  0 0  :  mean =   0.2113, RMS =   0.8901, cov =   0.7922
#    4  0 0  :  mean =   0.2116, RMS =   0.8912, cov =   0.7943
#    5  0 0  :  mean =   0.2111, RMS =   0.8914, cov =   0.7946
#    6  0 0  :  mean =   0.2115, RMS =   0.8912, cov =   0.7942
#    7  0 0  :  mean =   0.2131, RMS =   0.8907, cov =   0.7933
#    8  0 0  :  mean =   0.2142, RMS =   0.8909, cov =   0.7936
#    9  0 0  :  mean =   0.2138, RMS =   0.8910, cov =   0.7938
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-046.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.12289666 0.90384797 0.93040917 ... 1.11585262 1.17499162 0.85946563]
#  [1.14520996 0.90597876 0.93510464 ... 1.13098802 1.17269956 0.85957878]
#  [1.11401897 0.94227541 0.9691035  ... 1.10802505 1.14463616 0.89380945]
#  ...
#  [1.15987845 0.94954938 0.97972247 ... 1.13829722 1.17100756 0.89791686]
#  [1.1370966  0.91295219 0.94135773 ... 1.11430368 1.16481124 0.86466693]
#  [1.13488471 0.93600056 0.96607432 ... 1.10513536 1.12787257 0.88303719]]
#    0  0 0  :  mean =   0.1954, RMS =   0.8951, cov =   0.8012
#    1  0 0  :  mean =   0.1923, RMS =   0.8959, cov =   0.8026
#    2  0 0  :  mean =   0.1893, RMS =   0.8924, cov =   0.7964
#    3  0 0  :  mean =   0.1890, RMS =   0.8946, cov =   0.8003
#    4  0 0  :  mean =   0.1903, RMS =   0.8954, cov =   0.8018
#    5  0 0  :  mean =   0.1881, RMS =   0.8967, cov =   0.8040
#    6  0 0  :  mean =   0.1891, RMS =   0.8983, cov =   0.8070
#    7  0 0  :  mean =   0.1885, RMS =   0.8985, cov =   0.8072
#    8  0 0  :  mean =   0.1896, RMS =   0.8987, cov =   0.8077
#    9  0 0  :  mean =   0.1892, RMS =   0.8987, cov =   0.8076
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-047.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18236941 0.89845042 0.92013559 ... 1.06708919 1.12541432 0.86182985]
#  [1.23122348 0.91922341 0.94252848 ... 1.0841404  1.13466843 0.87866133]
#  [1.21313723 0.93013457 0.95448934 ... 1.07322479 1.11016767 0.88614679]
#  ...
#  [1.21381819 0.91368074 0.93955863 ... 1.08464845 1.12664177 0.86864454]
#  [1.23146312 0.92108943 0.94543258 ... 1.1036675  1.15951642 0.87994054]
#  [1.20937275 0.89725243 0.92512268 ... 1.08406448 1.13337843 0.84926708]]
#    0  0 0  :  mean =   0.1932, RMS =   0.9012, cov =   0.8122
#    1  0 0  :  mean =   0.1954, RMS =   0.9021, cov =   0.8138
#    2  0 0  :  mean =   0.1929, RMS =   0.9021, cov =   0.8138
#    3  0 0  :  mean =   0.1929, RMS =   0.9023, cov =   0.8141
#    4  0 0  :  mean =   0.1961, RMS =   0.9011, cov =   0.8119
#    5  0 0  :  mean =   0.1955, RMS =   0.9023, cov =   0.8141
#    6  0 0  :  mean =   0.1955, RMS =   0.9025, cov =   0.8144
#    7  0 0  :  mean =   0.1962, RMS =   0.9026, cov =   0.8146
#    8  0 0  :  mean =   0.1960, RMS =   0.9035, cov =   0.8163
#    9  0 0  :  mean =   0.1968, RMS =   0.9033, cov =   0.8159
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-048.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.20084436 0.85622642 0.89255833 ... 1.1336676  1.2022431  0.79814206]
#  [1.1207163  0.88193567 0.91147025 ... 1.11003309 1.17635689 0.83306136]
#  [1.14595829 0.90750693 0.94054372 ... 1.12504576 1.17087226 0.85145672]
#  ...
#  [1.15835165 0.88467162 0.92135025 ... 1.14204327 1.20442291 0.82368655]
#  [1.07581782 0.87491826 0.91333293 ... 1.1333932  1.19370112 0.81032151]
#  [1.15600798 0.88507362 0.92188925 ... 1.12553971 1.17469237 0.82358262]]
#    0  0 0  :  mean =   0.2330, RMS =   0.8908, cov =   0.7935
#    1  0 0  :  mean =   0.2163, RMS =   0.8933, cov =   0.7980
#    2  0 0  :  mean =   0.2091, RMS =   0.8941, cov =   0.7995
#    3  0 0  :  mean =   0.2117, RMS =   0.8927, cov =   0.7970
#    4  0 0  :  mean =   0.2119, RMS =   0.8904, cov =   0.7928
#    5  0 0  :  mean =   0.2119, RMS =   0.8908, cov =   0.7935
#    6  0 0  :  mean =   0.2110, RMS =   0.8891, cov =   0.7905
#    7  0 0  :  mean =   0.2113, RMS =   0.8890, cov =   0.7904
#    8  0 0  :  mean =   0.2107, RMS =   0.8875, cov =   0.7876
#    9  0 0  :  mean =   0.2108, RMS =   0.8875, cov =   0.7876
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-049.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.24643858 0.86143876 0.88882627 ... 1.07442214 1.15058915 0.81610638]
#  [1.19978772 0.9086276  0.93344103 ... 1.08193144 1.15108952 0.86387977]
#  [1.22253163 0.89554576 0.92091427 ... 1.08481852 1.15975771 0.85148473]
#  ...
#  [1.18983803 0.90400327 0.93126575 ... 1.08023534 1.14152628 0.8559022 ]
#  [1.20990396 0.8481013  0.87318729 ... 1.06948807 1.1507628  0.80857896]
#  [1.24362669 0.90875288 0.93599932 ... 1.08392056 1.14368893 0.85983545]]
#    0  0 0  :  mean =   0.2246, RMS =   0.9050, cov =   0.8191
#    1  0 0  :  mean =   0.2183, RMS =   0.8995, cov =   0.8091
#    2  0 0  :  mean =   0.2156, RMS =   0.8974, cov =   0.8053
#    3  0 0  :  mean =   0.2127, RMS =   0.8972, cov =   0.8051
#    4  0 0  :  mean =   0.2127, RMS =   0.8960, cov =   0.8028
#    5  0 0  :  mean =   0.2118, RMS =   0.8974, cov =   0.8054
#    6  0 0  :  mean =   0.2120, RMS =   0.8991, cov =   0.8084
#    7  0 0  :  mean =   0.2110, RMS =   0.8996, cov =   0.8092
#    8  0 0  :  mean =   0.2109, RMS =   0.9001, cov =   0.8101
#    9  0 0  :  mean =   0.2107, RMS =   0.9003, cov =   0.8105
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-050.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.19116731 0.89597319 0.92456252 ... 1.10820812 1.16306103 0.84956891]
#  [1.23316291 0.8875162  0.9089262  ... 1.0744561  1.15331017 0.85146596]
#  [1.19838897 0.90241648 0.92828723 ... 1.09146772 1.15393531 0.85767686]
#  ...
#  [1.1611586  0.87495369 0.8950052  ... 1.07205574 1.15791396 0.84202308]
#  [1.19447533 0.88552302 0.90864027 ... 1.08348514 1.15650534 0.84690351]
#  [1.16172695 0.89861283 0.9243704  ... 1.099643   1.16894202 0.85532681]]
#    0  0 0  :  mean =   0.1962, RMS =   0.8934, cov =   0.7981
#    1  0 0  :  mean =   0.2035, RMS =   0.8961, cov =   0.8029
#    2  0 0  :  mean =   0.2037, RMS =   0.8936, cov =   0.7985
#    3  0 0  :  mean =   0.1993, RMS =   0.8934, cov =   0.7981
#    4  0 0  :  mean =   0.1998, RMS =   0.8920, cov =   0.7957
#    5  0 0  :  mean =   0.1999, RMS =   0.8913, cov =   0.7944
#    6  0 0  :  mean =   0.1997, RMS =   0.8925, cov =   0.7965
#    7  0 0  :  mean =   0.2003, RMS =   0.8925, cov =   0.7966
#    8  0 0  :  mean =   0.2015, RMS =   0.8926, cov =   0.7967
#    9  0 0  :  mean =   0.2014, RMS =   0.8921, cov =   0.7959
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-051.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.12568621 0.91432982 0.94394973 ... 1.11036535 1.15867989 0.86241803]
#  [1.17839851 0.91342458 0.94263226 ... 1.11115763 1.16213494 0.86291407]
#  [1.26473306 0.90936073 0.93529219 ... 1.09887129 1.15258804 0.8656291 ]
#  ...
#  [1.20840569 0.89765792 0.92791159 ... 1.11379953 1.16959343 0.8472515 ]
#  [1.19376839 0.88566796 0.91544679 ... 1.09886691 1.15432725 0.83551334]
#  [1.18507738 0.90589564 0.93591571 ... 1.1086239  1.16057435 0.85428069]]
#    0  0 0  :  mean =   0.1951, RMS =   0.8914, cov =   0.7945
#    1  0 0  :  mean =   0.1956, RMS =   0.8941, cov =   0.7994
#    2  0 0  :  mean =   0.2002, RMS =   0.8996, cov =   0.8092
#    3  0 0  :  mean =   0.2007, RMS =   0.8961, cov =   0.8030
#    4  0 0  :  mean =   0.2022, RMS =   0.8955, cov =   0.8019
#    5  0 0  :  mean =   0.2045, RMS =   0.8955, cov =   0.8019
#    6  0 0  :  mean =   0.2044, RMS =   0.8951, cov =   0.8013
#    7  0 0  :  mean =   0.2054, RMS =   0.8945, cov =   0.8001
#    8  0 0  :  mean =   0.2065, RMS =   0.8939, cov =   0.7991
#    9  0 0  :  mean =   0.2064, RMS =   0.8937, cov =   0.7988
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-052.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.2180959  0.88238773 0.9093607  ... 1.08672743 1.15446103 0.83693457]
#  [1.21073539 0.8688243  0.89878833 ... 1.08733334 1.15212249 0.81930605]
#  [1.18268292 0.88716837 0.91680608 ... 1.0983798  1.17222971 0.83557772]
#  ...
#  [1.1694325  0.86967892 0.89434891 ... 1.08943103 1.17080157 0.8297351 ]
#  [1.20073314 0.88661891 0.91650672 ... 1.09303573 1.15995734 0.83526994]
#  [1.17858798 0.87952554 0.90643225 ... 1.08213177 1.15772214 0.83344284]]
#    0  0 0  :  mean =   0.2128, RMS =   0.9035, cov =   0.8162
#    1  0 0  :  mean =   0.2129, RMS =   0.9012, cov =   0.8122
#    2  0 0  :  mean =   0.2119, RMS =   0.8990, cov =   0.8082
#    3  0 0  :  mean =   0.2131, RMS =   0.8983, cov =   0.8070
#    4  0 0  :  mean =   0.2151, RMS =   0.8999, cov =   0.8099
#    5  0 0  :  mean =   0.2157, RMS =   0.9002, cov =   0.8104
#    6  0 0  :  mean =   0.2165, RMS =   0.8996, cov =   0.8093
#    7  0 0  :  mean =   0.2152, RMS =   0.8993, cov =   0.8088
#    8  0 0  :  mean =   0.2149, RMS =   0.8998, cov =   0.8097
#    9  0 0  :  mean =   0.2141, RMS =   0.8996, cov =   0.8093
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-053.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.1920853  0.90169637 0.92662217 ... 1.08071236 1.12822402 0.8594421 ]
#  [1.15481801 0.92157466 0.94302394 ... 1.09286096 1.16244514 0.88382383]
#  [1.12043128 0.88822605 0.90755891 ... 1.07519765 1.1540429  0.85583548]
#  ...
#  [1.13937178 0.91990171 0.94415666 ... 1.08283994 1.1336258  0.87712361]
#  [1.17680169 0.91577006 0.94029088 ... 1.08182966 1.13182003 0.87314499]
#  [1.20882767 0.92228926 0.94395767 ... 1.07214478 1.12705804 0.88294964]]
#    0  0 0  :  mean =   0.1883, RMS =   0.8976, cov =   0.8057
#    1  0 0  :  mean =   0.1863, RMS =   0.8930, cov =   0.7974
#    2  0 0  :  mean =   0.1860, RMS =   0.8925, cov =   0.7965
#    3  0 0  :  mean =   0.1842, RMS =   0.8909, cov =   0.7937
#    4  0 0  :  mean =   0.1838, RMS =   0.8926, cov =   0.7967
#    5  0 0  :  mean =   0.1836, RMS =   0.8912, cov =   0.7943
#    6  0 0  :  mean =   0.1830, RMS =   0.8915, cov =   0.7948
#    7  0 0  :  mean =   0.1827, RMS =   0.8913, cov =   0.7945
#    8  0 0  :  mean =   0.1826, RMS =   0.8922, cov =   0.7961
#    9  0 0  :  mean =   0.1836, RMS =   0.8926, cov =   0.7968
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-054.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.17899806 0.90304199 0.92695028 ... 1.06444245 1.10933235 0.8624513 ]
#  [1.2297717  0.93788496 0.96003371 ... 1.09316724 1.14284515 0.89876994]
#  [1.16880496 0.89516655 0.91504453 ... 1.05502412 1.12613857 0.86052387]
#  ...
#  [1.19343447 0.90130089 0.9235589  ... 1.07634452 1.14849198 0.8635881 ]
#  [1.19779872 0.90302401 0.9266492  ... 1.0697245  1.12915713 0.8612893 ]
#  [1.16033359 0.87039524 0.89186799 ... 1.04077383 1.10186659 0.83480826]]
#    0  0 0  :  mean =   0.1896, RMS =   0.9187, cov =   0.8440
#    1  0 0  :  mean =   0.1905, RMS =   0.9178, cov =   0.8424
#    2  0 0  :  mean =   0.1915, RMS =   0.9168, cov =   0.8405
#    3  0 0  :  mean =   0.1914, RMS =   0.9147, cov =   0.8366
#    4  0 0  :  mean =   0.1928, RMS =   0.9144, cov =   0.8361
#    5  0 0  :  mean =   0.1936, RMS =   0.9142, cov =   0.8357
#    6  0 0  :  mean =   0.1960, RMS =   0.9143, cov =   0.8359
#    7  0 0  :  mean =   0.1961, RMS =   0.9149, cov =   0.8371
#    8  0 0  :  mean =   0.1959, RMS =   0.9149, cov =   0.8371
#    9  0 0  :  mean =   0.1960, RMS =   0.9148, cov =   0.8368
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-055.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.23816516 0.92547848 0.94766258 ... 1.09290852 1.15552559 0.88634259]
#  [1.23329323 0.88978417 0.91788472 ... 1.10084738 1.146991   0.84322407]
#  [1.23108936 0.90732287 0.94139564 ... 1.10551528 1.13522678 0.84904926]
#  ...
#  [1.22540583 0.93631229 0.9607884  ... 1.06770589 1.12345525 0.88894934]
#  [1.21135301 0.89830755 0.92699062 ... 1.09533443 1.14362591 0.85023663]
#  [1.1600546  0.92010255 0.95032835 ... 1.11381721 1.15670812 0.86880899]]
#    0  0 0  :  mean =   0.1930, RMS =   0.9011, cov =   0.8120
#    1  0 0  :  mean =   0.1989, RMS =   0.9011, cov =   0.8120
#    2  0 0  :  mean =   0.1999, RMS =   0.9009, cov =   0.8116
#    3  0 0  :  mean =   0.2033, RMS =   0.8991, cov =   0.8083
#    4  0 0  :  mean =   0.2003, RMS =   0.8991, cov =   0.8084
#    5  0 0  :  mean =   0.2008, RMS =   0.8996, cov =   0.8092
#    6  0 0  :  mean =   0.1999, RMS =   0.8997, cov =   0.8095
#    7  0 0  :  mean =   0.1994, RMS =   0.8998, cov =   0.8096
#    8  0 0  :  mean =   0.1987, RMS =   0.8997, cov =   0.8095
#    9  0 0  :  mean =   0.1968, RMS =   0.8992, cov =   0.8085
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-056.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.21764228 0.93391643 0.96239421 ... 1.1264325  1.17568857 0.88518714]
#  [1.18358528 0.92783374 0.95492086 ... 1.11833133 1.16641861 0.88108688]
#  [1.18788452 0.91647965 0.94150482 ... 1.08516471 1.13090613 0.87289039]
#  ...
#  [1.18380735 0.8995639  0.92556555 ... 1.07255298 1.12805636 0.85328917]
#  [1.17435378 0.8906635  0.92582566 ... 1.14247668 1.18566219 0.83539209]
#  [1.18414015 0.90752428 0.93670156 ... 1.12646199 1.18983127 0.85883838]]
#    0  0 0  :  mean =   0.2009, RMS =   0.8897, cov =   0.7916
#    1  0 0  :  mean =   0.1983, RMS =   0.8847, cov =   0.7827
#    2  0 0  :  mean =   0.1953, RMS =   0.8904, cov =   0.7927
#    3  0 0  :  mean =   0.1981, RMS =   0.8908, cov =   0.7935
#    4  0 0  :  mean =   0.1979, RMS =   0.8910, cov =   0.7939
#    5  0 0  :  mean =   0.1958, RMS =   0.8888, cov =   0.7899
#    6  0 0  :  mean =   0.1962, RMS =   0.8905, cov =   0.7930
#    7  0 0  :  mean =   0.1974, RMS =   0.8904, cov =   0.7929
#    8  0 0  :  mean =   0.1981, RMS =   0.8893, cov =   0.7909
#    9  0 0  :  mean =   0.1987, RMS =   0.8888, cov =   0.7900
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-057.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.22774342 0.93818215 0.96633532 ... 1.10301879 1.1282683  0.88917699]
#  [1.16924304 0.97537351 0.99668303 ... 1.09548473 1.13451875 0.93373305]
#  [1.2549624  0.93942698 0.96268099 ... 1.07021401 1.10290731 0.896377  ]
#  ...
#  [1.2489836  0.92887787 0.94952633 ... 1.06832608 1.11871606 0.89097024]
#  [1.24992985 0.942648   0.96427384 ... 1.06696186 1.095364   0.90334338]
#  [1.19454752 0.94343449 0.96779238 ... 1.08492192 1.12868236 0.89729203]]
#    0  0 0  :  mean =   0.1950, RMS =   0.9044, cov =   0.8180
#    1  0 0  :  mean =   0.1878, RMS =   0.9024, cov =   0.8143
#    2  0 0  :  mean =   0.1896, RMS =   0.9044, cov =   0.8179
#    3  0 0  :  mean =   0.1890, RMS =   0.9034, cov =   0.8162
#    4  0 0  :  mean =   0.1865, RMS =   0.9049, cov =   0.8188
# ...
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-187.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.15665033 0.91540537 0.93986281 ... 1.08340923 1.13858311 0.87275709]
#  [1.17341059 0.88886738 0.91802235 ... 1.12177472 1.16504794 0.84343436]
#  [1.18882237 0.90391682 0.92992766 ... 1.09656854 1.16420902 0.85930211]
#  ...
#  [1.20377207 0.8941058  0.91761787 ... 1.07710784 1.15439152 0.85398068]
#  [1.15951021 0.88168162 0.90777276 ... 1.09215471 1.16041439 0.8387186 ]
#  [1.19686775 0.89743739 0.9220746  ... 1.08580846 1.14873374 0.85543019]]
#    0  0 0  :  mean =   0.1823, RMS =   0.8943, cov =   0.7997
#    1  0 0  :  mean =   0.1865, RMS =   0.8905, cov =   0.7930
#    2  0 0  :  mean =   0.1898, RMS =   0.8923, cov =   0.7962
#    3  0 0  :  mean =   0.1921, RMS =   0.8896, cov =   0.7914
#    4  0 0  :  mean =   0.1922, RMS =   0.8922, cov =   0.7960
#    5  0 0  :  mean =   0.1921, RMS =   0.8929, cov =   0.7972
#    6  0 0  :  mean =   0.1904, RMS =   0.8937, cov =   0.7988
#    7  0 0  :  mean =   0.1920, RMS =   0.8943, cov =   0.7998
#    8  0 0  :  mean =   0.1922, RMS =   0.8944, cov =   0.8000
#    9  0 0  :  mean =   0.1927, RMS =   0.8951, cov =   0.8012
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-188.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.21203962 0.88500334 0.9168648  ... 1.10636847 1.1663759  0.8308674 ]
#  [1.25728708 0.8796327  0.91812174 ... 1.11983917 1.16109848 0.81514771]
#  [1.25561881 0.88557883 0.91511235 ... 1.09528381 1.14965803 0.83688322]
#  ...
#  [1.21273499 0.86769004 0.90188451 ... 1.10400325 1.1555905  0.81157214]
#  [1.20051301 0.86968049 0.90466596 ... 1.12029764 1.18031262 0.81194631]
#  [1.22799287 0.8655084  0.89565404 ... 1.09193239 1.14507795 0.81759719]]
#    0  0 0  :  mean =   0.2213, RMS =   0.8937, cov =   0.7988
#    1  0 0  :  mean =   0.2285, RMS =   0.8946, cov =   0.8004
#    2  0 0  :  mean =   0.2258, RMS =   0.8980, cov =   0.8065
#    3  0 0  :  mean =   0.2227, RMS =   0.8993, cov =   0.8088
#    4  0 0  :  mean =   0.2236, RMS =   0.8999, cov =   0.8099
#    5  0 0  :  mean =   0.2225, RMS =   0.8984, cov =   0.8072
#    6  0 0  :  mean =   0.2236, RMS =   0.8987, cov =   0.8077
#    7  0 0  :  mean =   0.2232, RMS =   0.8993, cov =   0.8088
#    8  0 0  :  mean =   0.2238, RMS =   0.8990, cov =   0.8081
#    9  0 0  :  mean =   0.2235, RMS =   0.8990, cov =   0.8082
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-189.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.20058188 0.92796051 0.94970489 ... 1.05933668 1.11430357 0.88627244]
#  [1.22962088 0.8986031  0.92389273 ... 1.0876757  1.14264861 0.85598226]
#  [1.21684893 0.91636266 0.94279017 ... 1.09231522 1.14459668 0.86990032]
#  ...
#  [1.25794817 0.90919861 0.93756882 ... 1.09581051 1.14467725 0.8600414 ]
#  [1.20773582 0.90956717 0.93463995 ... 1.06708045 1.1206216  0.86437043]
#  [1.16314982 0.91270892 0.93856045 ... 1.0974283  1.15047941 0.86851042]]
#    0  0 0  :  mean =   0.1971, RMS =   0.9132, cov =   0.8339
#    1  0 0  :  mean =   0.2008, RMS =   0.9158, cov =   0.8386
#    2  0 0  :  mean =   0.2023, RMS =   0.9127, cov =   0.8331
#    3  0 0  :  mean =   0.2036, RMS =   0.9112, cov =   0.8302
#    4  0 0  :  mean =   0.2051, RMS =   0.9113, cov =   0.8305
#    5  0 0  :  mean =   0.2035, RMS =   0.9115, cov =   0.8309
#    6  0 0  :  mean =   0.2036, RMS =   0.9119, cov =   0.8316
#    7  0 0  :  mean =   0.2048, RMS =   0.9121, cov =   0.8320
#    8  0 0  :  mean =   0.2040, RMS =   0.9120, cov =   0.8317
#    9  0 0  :  mean =   0.2025, RMS =   0.9113, cov =   0.8305
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-190.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.15426009 0.9174688  0.9422955  ... 1.09164087 1.13637024 0.87561208]
#  [1.16402824 0.91318672 0.93660845 ... 1.09614197 1.1512387  0.87400829]
#  [1.16943077 0.92770621 0.94748341 ... 1.07473597 1.12286307 0.89413259]
#  ...
#  [1.14443729 0.92228147 0.94481853 ... 1.08151257 1.13236651 0.88261023]
#  [1.19558277 0.89861052 0.9245004  ... 1.1056726  1.16741681 0.85678288]
#  [1.11813375 0.94071001 0.95973884 ... 1.06177494 1.11352108 0.90471564]]
#    0  0 0  :  mean =   0.1806, RMS =   0.9044, cov =   0.8180
#    1  0 0  :  mean =   0.1824, RMS =   0.9046, cov =   0.8183
#    2  0 0  :  mean =   0.1801, RMS =   0.9081, cov =   0.8247
#    3  0 0  :  mean =   0.1814, RMS =   0.9064, cov =   0.8216
#    4  0 0  :  mean =   0.1840, RMS =   0.9087, cov =   0.8257
#    5  0 0  :  mean =   0.1839, RMS =   0.9103, cov =   0.8287
#    6  0 0  :  mean =   0.1839, RMS =   0.9097, cov =   0.8275
#    7  0 0  :  mean =   0.1842, RMS =   0.9097, cov =   0.8275
#    8  0 0  :  mean =   0.1857, RMS =   0.9105, cov =   0.8290
#    9  0 0  :  mean =   0.1846, RMS =   0.9110, cov =   0.8299
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-191.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.1344869  0.90990916 0.93240315 ... 1.07637684 1.1359609  0.87072163]
#  [1.21411778 0.91704717 0.94138898 ... 1.08762385 1.1453725  0.87530909]
#  [1.16869619 0.9234941  0.94203835 ... 1.07833426 1.14605721 0.89097033]
#  ...
#  [1.15560632 0.91155012 0.93669698 ... 1.08788493 1.13776672 0.86855388]
#  [1.15532096 0.91652338 0.93876995 ... 1.07575259 1.12789659 0.87795444]
#  [1.08815034 0.92312765 0.94777124 ... 1.09819875 1.14561118 0.88085003]]
#    0  0 0  :  mean =   0.1817, RMS =   0.8967, cov =   0.8041
#    1  0 0  :  mean =   0.1871, RMS =   0.8982, cov =   0.8068
#    2  0 0  :  mean =   0.1835, RMS =   0.9003, cov =   0.8105
#    3  0 0  :  mean =   0.1858, RMS =   0.9001, cov =   0.8102
#    4  0 0  :  mean =   0.1841, RMS =   0.9005, cov =   0.8109
#    5  0 0  :  mean =   0.1843, RMS =   0.9003, cov =   0.8105
#    6  0 0  :  mean =   0.1863, RMS =   0.9005, cov =   0.8108
#    7  0 0  :  mean =   0.1856, RMS =   0.9007, cov =   0.8113
#    8  0 0  :  mean =   0.1846, RMS =   0.9009, cov =   0.8115
#    9  0 0  :  mean =   0.1829, RMS =   0.8996, cov =   0.8092
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-192.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.18423449 0.86039068 0.89463354 ... 1.13875752 1.18027482 0.81023584]
#  [1.19592625 0.82942044 0.86733405 ... 1.15610597 1.22225882 0.77473478]
#  [1.1383552  0.84227415 0.88074513 ... 1.15994132 1.20377833 0.78727876]
#  ...
#  [1.18984641 0.85694008 0.90252485 ... 1.19110305 1.22763552 0.79117037]
#  [1.1488138  0.84988927 0.88630144 ... 1.13867922 1.18801631 0.79586676]
#  [1.14934165 0.87842156 0.91639852 ... 1.16819795 1.20297476 0.82221625]]
#    0  0 0  :  mean =   0.1911, RMS =   0.9069, cov =   0.8225
#    1  0 0  :  mean =   0.2034, RMS =   0.9013, cov =   0.8124
#    2  0 0  :  mean =   0.2017, RMS =   0.8978, cov =   0.8061
#    3  0 0  :  mean =   0.2041, RMS =   0.8973, cov =   0.8051
#    4  0 0  :  mean =   0.2043, RMS =   0.8967, cov =   0.8040
#    5  0 0  :  mean =   0.2059, RMS =   0.8973, cov =   0.8051
#    6  0 0  :  mean =   0.2050, RMS =   0.8975, cov =   0.8056
#    7  0 0  :  mean =   0.2048, RMS =   0.8972, cov =   0.8050
#    8  0 0  :  mean =   0.2046, RMS =   0.8972, cov =   0.8049
#    9  0 0  :  mean =   0.2030, RMS =   0.8975, cov =   0.8055
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-193.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.13100307 0.87354668 0.89927135 ... 1.08778557 1.16883066 0.8309713 ]
#  [1.17507483 0.92136944 0.94175636 ... 1.08634843 1.17638925 0.88312779]
#  [1.12489109 0.92415973 0.94500203 ... 1.07592712 1.16046563 0.88433409]
#  ...
#  [1.13248196 0.88642738 0.9091376  ... 1.06322804 1.14165588 0.84728262]
#  [1.18300123 0.87852706 0.90359231 ... 1.08207546 1.16333179 0.83619772]
#  [1.15895473 0.89556202 0.91580687 ... 1.06318444 1.15036687 0.85908806]]
#    0  0 0  :  mean =   0.1985, RMS =   0.8938, cov =   0.7988
#    1  0 0  :  mean =   0.2003, RMS =   0.8987, cov =   0.8077
#    2  0 0  :  mean =   0.1982, RMS =   0.8979, cov =   0.8063
#    3  0 0  :  mean =   0.2020, RMS =   0.8989, cov =   0.8080
#    4  0 0  :  mean =   0.2007, RMS =   0.8989, cov =   0.8080
#    5  0 0  :  mean =   0.2003, RMS =   0.8992, cov =   0.8086
#    6  0 0  :  mean =   0.1991, RMS =   0.8981, cov =   0.8066
#    7  0 0  :  mean =   0.1994, RMS =   0.8982, cov =   0.8068
#    8  0 0  :  mean =   0.2004, RMS =   0.8986, cov =   0.8075
#    9  0 0  :  mean =   0.2010, RMS =   0.8985, cov =   0.8073
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-194.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.14221055 0.91275346 0.93828228 ... 1.10730385 1.16616213 0.86977963]
#  [1.15491961 0.90291291 0.92357669 ... 1.04699905 1.10405049 0.86603954]
#  [1.1480921  0.89784215 0.92391539 ... 1.07955238 1.12863138 0.85348041]
#  ...
#  [1.21085934 0.92045728 0.94605769 ... 1.08399765 1.12588962 0.87575175]
#  [1.18098024 0.90413936 0.93041866 ... 1.08245282 1.12828622 0.85925097]
#  [1.23948105 0.91649192 0.94023193 ... 1.07753097 1.12256498 0.87548971]]
#    0  0 0  :  mean =   0.1810, RMS =   0.9028, cov =   0.8150
#    1  0 0  :  mean =   0.1807, RMS =   0.9064, cov =   0.8216
#    2  0 0  :  mean =   0.1805, RMS =   0.9052, cov =   0.8194
#    3  0 0  :  mean =   0.1842, RMS =   0.9036, cov =   0.8164
#    4  0 0  :  mean =   0.1850, RMS =   0.9030, cov =   0.8154
#    5  0 0  :  mean =   0.1839, RMS =   0.9045, cov =   0.8182
#    6  0 0  :  mean =   0.1846, RMS =   0.9048, cov =   0.8187
#    7  0 0  :  mean =   0.1848, RMS =   0.9051, cov =   0.8192
#    8  0 0  :  mean =   0.1852, RMS =   0.9053, cov =   0.8196
#    9  0 0  :  mean =   0.1856, RMS =   0.9056, cov =   0.8200
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-195.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.32338898 0.9054221  0.9391557  ... 1.11027533 1.14631381 0.8476357 ]
#  [1.28004424 0.91828307 0.94954621 ... 1.12174309 1.16472755 0.86515226]
#  [1.23024599 0.89291322 0.92058926 ... 1.080959   1.13541934 0.84488138]
#  ...
#  [1.29201803 0.88841411 0.91713144 ... 1.08281837 1.12853035 0.83979619]
#  [1.21616637 0.92107946 0.94963992 ... 1.10754694 1.15533157 0.87143668]
#  [1.23672953 0.89129996 0.9199778  ... 1.09436867 1.14600165 0.843637  ]]
#    0  0 0  :  mean =   0.2206, RMS =   0.8948, cov =   0.8007
#    1  0 0  :  mean =   0.2146, RMS =   0.8955, cov =   0.8019
#    2  0 0  :  mean =   0.2131, RMS =   0.8946, cov =   0.8004
#    3  0 0  :  mean =   0.2129, RMS =   0.8980, cov =   0.8064
#    4  0 0  :  mean =   0.2130, RMS =   0.8979, cov =   0.8062
#    5  0 0  :  mean =   0.2137, RMS =   0.8974, cov =   0.8053
#    6  0 0  :  mean =   0.2131, RMS =   0.8977, cov =   0.8058
#    7  0 0  :  mean =   0.2135, RMS =   0.8981, cov =   0.8065
#    8  0 0  :  mean =   0.2121, RMS =   0.8987, cov =   0.8077
#    9  0 0  :  mean =   0.2116, RMS =   0.8986, cov =   0.8076
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-196.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.09720839 0.85363402 0.87978505 ... 1.08573323 1.17002465 0.81215943]
#  [1.10902354 0.87189691 0.90087509 ... 1.11867124 1.19173957 0.8271519 ]
#  [1.14456839 0.86726602 0.8976792  ... 1.12205255 1.18789863 0.82052033]
#  ...
#  [1.13143422 0.87125234 0.90232298 ... 1.10561925 1.16456539 0.82274001]
#  [1.11107671 0.86167503 0.88685213 ... 1.10731287 1.19026463 0.82387174]
#  [1.17862397 0.8645796  0.89542919 ... 1.11160438 1.18528087 0.81505972]]
#    0  0 0  :  mean =   0.1883, RMS =   0.8960, cov =   0.8027
#    1  0 0  :  mean =   0.1875, RMS =   0.8931, cov =   0.7976
#    2  0 0  :  mean =   0.1893, RMS =   0.8949, cov =   0.8008
#    3  0 0  :  mean =   0.1864, RMS =   0.8955, cov =   0.8019
#    4  0 0  :  mean =   0.1885, RMS =   0.8954, cov =   0.8017
#    5  0 0  :  mean =   0.1892, RMS =   0.8949, cov =   0.8008
#    6  0 0  :  mean =   0.1910, RMS =   0.8959, cov =   0.8026
#    7  0 0  :  mean =   0.1892, RMS =   0.8974, cov =   0.8054
#    8  0 0  :  mean =   0.1882, RMS =   0.8977, cov =   0.8058
#    9  0 0  :  mean =   0.1902, RMS =   0.8972, cov =   0.8050
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-197.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.15764255 0.86860694 0.88598798 ... 1.05845951 1.15099385 0.84107194]
#  [1.17384299 0.88307072 0.90226965 ... 1.05716878 1.14119071 0.85058   ]
#  [1.2047296  0.85678498 0.88220654 ... 1.08148793 1.16115179 0.8169026 ]
#  ...
#  [1.23455971 0.86358016 0.88687697 ... 1.07392453 1.15955261 0.82657487]
#  [1.1849592  0.87442704 0.89733068 ... 1.06967233 1.15267234 0.83685963]
#  [1.22414671 0.88397711 0.90556396 ... 1.07605061 1.15545531 0.84842845]]
#    0  0 0  :  mean =   0.1941, RMS =   0.9136, cov =   0.8347
#    1  0 0  :  mean =   0.1947, RMS =   0.9098, cov =   0.8278
#    2  0 0  :  mean =   0.2000, RMS =   0.9072, cov =   0.8231
#    3  0 0  :  mean =   0.2011, RMS =   0.9085, cov =   0.8253
#    4  0 0  :  mean =   0.2008, RMS =   0.9080, cov =   0.8244
#    5  0 0  :  mean =   0.2002, RMS =   0.9081, cov =   0.8246
#    6  0 0  :  mean =   0.2005, RMS =   0.9074, cov =   0.8234
#    7  0 0  :  mean =   0.2011, RMS =   0.9078, cov =   0.8242
#    8  0 0  :  mean =   0.2012, RMS =   0.9082, cov =   0.8249
#    9  0 0  :  mean =   0.2016, RMS =   0.9088, cov =   0.8260
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-198.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.17875247 0.88682821 0.91531397 ... 1.10511758 1.17226956 0.83888746]
#  [1.17093412 0.90232586 0.9318821  ... 1.10788552 1.15875371 0.85260814]
#  [1.13495838 0.88386167 0.91338374 ... 1.09948551 1.1548737  0.83426706]
#  ...
#  [1.09326939 0.88178345 0.90949333 ... 1.10886425 1.18230085 0.83599981]
#  [1.12835531 0.89933022 0.93229882 ... 1.13037744 1.18497825 0.84463753]
#  [1.13402046 0.91684464 0.95221692 ... 1.14545508 1.19163152 0.85649666]]
#    0  0 0  :  mean =   0.2111, RMS =   0.8908, cov =   0.7935
#    1  0 0  :  mean =   0.2075, RMS =   0.8942, cov =   0.7996
#    2  0 0  :  mean =   0.2045, RMS =   0.8937, cov =   0.7987
#    3  0 0  :  mean =   0.2043, RMS =   0.8929, cov =   0.7973
#    4  0 0  :  mean =   0.2035, RMS =   0.8926, cov =   0.7968
#    5  0 0  :  mean =   0.2019, RMS =   0.8917, cov =   0.7951
#    6  0 0  :  mean =   0.2000, RMS =   0.8919, cov =   0.7955
#    7  0 0  :  mean =   0.1999, RMS =   0.8914, cov =   0.7945
#    8  0 0  :  mean =   0.1997, RMS =   0.8906, cov =   0.7932
#    9  0 0  :  mean =   0.1997, RMS =   0.8891, cov =   0.7905
#
# ----- output-run-nn-study-nd-v1e-ndim1-res-sf-1.00-nens10/bootstrap-ensemble-run-weights-199.npy exists
# Shape of ensemble_final_push_weights : (10, 100000)
# 10
# [[1.22126406 0.84253725 0.87351457 ... 1.10224915 1.1798244  0.79379859]
#  [1.19026302 0.87476819 0.9096278  ... 1.11233625 1.15871248 0.81790306]
#  [1.22173692 0.88035747 0.9107563  ... 1.1053087  1.16692957 0.82954783]
#  ...
#  [1.22329049 0.87721224 0.91506955 ... 1.13517447 1.16689789 0.81895036]
#  [1.23561846 0.87146128 0.9014981  ... 1.09672714 1.1625818  0.82198659]
#  [1.16202979 0.86164276 0.89003429 ... 1.09425952 1.17343178 0.81508671]]
#    0  0 0  :  mean =   0.2332, RMS =   0.8928, cov =   0.7971
#    1  0 0  :  mean =   0.2197, RMS =   0.8970, cov =   0.8046
#    2  0 0  :  mean =   0.2198, RMS =   0.8988, cov =   0.8078
#    3  0 0  :  mean =   0.2172, RMS =   0.8975, cov =   0.8055
#    4  0 0  :  mean =   0.2169, RMS =   0.8960, cov =   0.8029
#    5  0 0  :  mean =   0.2156, RMS =   0.8977, cov =   0.8059
#    6  0 0  :  mean =   0.2157, RMS =   0.8974, cov =   0.8053
#    7  0 0  :  mean =   0.2154, RMS =   0.8975, cov =   0.8056
#    8  0 0  :  mean =   0.2159, RMS =   0.8978, cov =   0.8061
#    9  0 0  :  mean =   0.2160, RMS =   0.8981, cov =   0.8066
# CPU times: user 1.31 s, sys: 275 ms, total: 1.59 s
# Wall time: 1.57 s

# %%
print('\n')

ave_mean = np.zeros( shape=(n_ensembles, ndim) )
rms_mean = np.zeros( shape=(n_ensembles, ndim) )
rms_mean_err = np.zeros( shape=(n_ensembles, ndim) )

ave_cov = np.zeros( shape=(n_ensembles, ndim,ndim) )
rms_cov = np.zeros( shape=(n_ensembles, ndim,ndim) )
rms_cov_err = np.zeros( shape=(n_ensembles, ndim,ndim) )


for ri in range( n_ensembles ) :

    for fi in range(ndim) :

        ave_mean[ri,fi] = np.mean( all_mean[ri,fi] )
        ave_mean2 = np.mean( all_mean[ri,fi]*all_mean[ri,fi])
        rms_mean[ri,fi] = np.sqrt( ave_mean2 - ave_mean[ri,fi]*ave_mean[ri,fi] )
        rms_mean_err[ri,fi] = rms_mean[ri,fi] / np.sqrt(2*n_samples)
        print("  ave through ensemble run %2d :  feature %d  :  mean   ave %8.4f  (true %8.4f), rms %8.5f +/- %6.5f" % 
              (ri, fi, ave_mean[ri,fi], true_mu[fi], rms_mean[ri,fi], rms_mean_err[ri,fi] ))
    
print('\n')

for ri in range( n_ensembles ) :

    for fi in range(ndim) :

        ave_rms = np.mean( all_rms[ri,fi] )
        ave_rms2 = np.mean( all_rms[ri,fi]*all_rms[ri,fi])
        rms_rms = np.sqrt( ave_rms2 - ave_rms*ave_rms )
        print("  ave through ensemble run %2d :  feature %d  :  RMS    ave %8.4f  (true %8.4f), rms %8.4f" % 
              (ri, fi, ave_rms, true_sig[fi], rms_rms ))

print('\n')

for ri in range( n_ensembles ) :

    for fi1 in range(0,ndim-1) :
        for fi2 in range(fi1+1, ndim) :
            k = ndim - fi2 - 1
            ave_rho = np.mean( all_rho[ri,fi1,fi2])
            ave_rho2 = np.mean( all_rho[ri,fi1,fi2]*all_rho[ri,fi1,fi2] )
            rms_rho = np.sqrt( ave_rho2 - ave_rho*ave_rho )
            print("  ave through ensemble run %2d :  feature %d, %d  :  rho    ave %8.4f  (true %8.4f), rms %8.4f" %
                  ( ri, fi1, fi2, ave_rho, true_rho[fi1][k], rms_rho ))

print("\n")

for ri in range( n_ensembles ) :


    for fi1 in range(0,ndim) :
        for fi2 in range(fi1,ndim) :
            ave_cov[ri,fi1,fi2] = np.mean( all_cov[ri,fi1,fi2] )
            ave_cov2 = np.mean( all_cov[ri,fi1,fi2]*all_cov[ri,fi1,fi2] )
            rms_cov[ri,fi1,fi2] = np.sqrt( ave_cov2 - ave_cov[ri,fi1,fi2]*ave_cov[ri,fi1,fi2] )
            rms_cov_err[ri,fi1,fi2] = rms_cov[ri,fi1,fi2]/np.sqrt(2*n_samples)
            print("  ave through ensemble run %2d :  feature %d, %d  :  cov    ave %8.4f  (true %8.4f), rms %8.5f +/- %6.5f" %
                  ( ri, fi1, fi2, ave_cov[ri,fi1,fi2], true_cov[fi1,fi2], rms_cov[ri,fi1,fi2], rms_cov_err[ri,fi1,fi2] ) )

print("\n")
# Out:
#   ave through ensemble run  0 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  1 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  2 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  3 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  4 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  5 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  6 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  7 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  8 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#   ave through ensemble run  9 :  feature 0  :  mean   ave   0.0000  (true   0.2000), rms  0.00000 +/- 0.00000
#
#
#   ave through ensemble run  0 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  1 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  2 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  3 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  4 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  5 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  6 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  7 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  8 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#   ave through ensemble run  9 :  feature 0  :  RMS    ave   0.0000  (true   0.9000), rms   0.0000
#
#
#
#
#   ave through ensemble run  0 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  1 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  2 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  3 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  4 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  5 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  6 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  7 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  8 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000
#   ave through ensemble run  9 :  feature 0, 0  :  cov    ave   0.0000  (true   0.8100), rms  0.00000 +/- 0.00000

# %%
xvals = np.linspace(1,n_ensembles,n_ensembles)

# %%
fig,ax = plt.subplots( 1, 2, figsize=(2*6,4) )

fsize=12

axi = ax[0]
axi.plot( xvals, rms_mean[:,0], marker='o')
axi.grid(True)
axi.set_xlabel( 'Number of runs in ensemble', fontsize=fsize )
axi.set_ylabel( 'Inference uncertainty on model mean', fontsize=fsize )

axi = ax[1]
axi.plot( xvals, rms_cov[:,0], marker='o')
axi.grid(True)
axi.set_xlabel( 'Number of runs in ensemble', fontsize=fsize )
axi.set_ylabel( 'Inference uncertainty on model Variance', fontsize=fsize )

plt.subplots_adjust( wspace=0.30 )

plt.savefig( 'paper-plots/resolution-vs-n-average.pdf', bbox_inches='tight' )



plt.show()
