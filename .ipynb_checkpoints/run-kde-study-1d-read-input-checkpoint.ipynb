# %%
import matplotlib.pyplot as plt
import numpy as np

import time

import sys
import os

from datetime import datetime
import subprocess



from os.path import exists

# %%
print("\n\n")
print("  numpy version:  %s" % str(np.version.version) )
# Out:
#   numpy version:  2.3.2

# %% [markdown]
# ## Set model and resolution parameters

# %%
ndim = 1


of_niter = 5


smearing_val = 0.0000
#smearing_val = 0.1184
#smearing_val = 0.2368
#smearing_val = 0.3553
#smearing_val = 0.5132
#smearing_val = 0.7500




input_dir = 'input-samples/input-samples-smearing-%6.4f-v1b' % smearing_val


output_dir = 'output-run-kde-study-1d-read-input-v0a-smearing-%6.4f' % smearing_val



#-- parameters for simple pdf

hist_low = -10.
hist_high = 10.

hist_nbins = 1000


hist_binwidth = (hist_high - hist_low) / hist_nbins

window_dx = 0.10

window_nbins = int( window_dx / hist_binwidth )

print(' window_nbins : %d' % window_nbins)

hist_pars = {}
hist_pars['low']  = hist_low
hist_pars['high'] = hist_high
hist_pars['nbins'] = hist_nbins
hist_pars['binwidth'] = hist_binwidth
hist_pars['window_dx'] = window_dx
hist_pars['window_nbins'] = window_nbins
# Out:
#  window_nbins : 5

# %%
hist_pars
# Out:
# {'low': -10.0,
#  'high': 10.0,
#  'nbins': 1000,
#  'binwidth': 0.02,
#  'window_dx': 0.1,
#  'window_nbins': 5}

# %%
try:
    os.mkdir( output_dir )
except:
    print('\n\n Output directory already exists:  %s' % output_dir)
    #print('\n\n HALTING EXECUTION\n\n')
    #sys.exit()

# %%
config_file = open('%s/config.txt' % output_dir, 'w' )

config_file.write('  input_dir  %s\n' % input_dir )
config_file.write(' of_niter %d\n' % of_niter )
config_file.write( 'hist pars %s\n' % str(hist_pars) )
config_file.close()

print( subprocess.getoutput('cat %s/config.txt' % output_dir ))
# Out:
#   input_dir  input-samples/input-samples-smearing-0.0000-v1b
#  of_niter 5
# hist pars {'low': -10.0, 'high': 10.0, 'nbins': 1000, 'binwidth': 0.02, 'window_dx': 0.1, 'window_nbins': 5}

# %% [markdown]
# ## Count the number of samples in the input directory and read in the first one

# %%
n_samples = 0

for fi in range(5000) :
    
    fname = '%s/sample-%04d.npz' % (input_dir, fi)
    
    if exists(fname) :
        n_samples = n_samples + 1
        
print("\n\n Found %d samples.\n\n" % n_samples )
# Out:
#  Found 0 samples.

# %%
def read_sample( input_dir, sample_index ) :
    
    with np.load( '%s/sample-%04d.npz' % (input_dir, sample_index) ) as f :
        #read_true_pts = np.load(f)
        read_true_det_pts = f['data']
        read_train_pts = f['gen']
        read_train_det_pts = f['sim']

    ngen_true = len(read_true_det_pts)
    ngen_train = len(read_train_pts)

    this_ngen_true = ngen_true

    #-- package these in the same format as what I was using.

    #true_pts = np.zeros( shape=(ngen_true,1) )
    #true_pts[:,0] = read_true_pts

    true_det_pts = np.zeros( shape=(ngen_true,1) )
    true_det_pts[:,0] = read_true_det_pts

    train_pts = np.zeros( shape=(ngen_train,1) )
    train_pts[:,0] = read_train_pts

    train_det_pts = np.zeros( shape=(ngen_train,1) )
    train_det_pts[:,0] = read_train_det_pts
    
    return_dict = {}
    
    #return_dict['true_pts'] = true_pts
    return_dict['true_det_pts'] = true_det_pts
    return_dict['train_pts'] = train_pts
    return_dict['train_det_pts'] = train_det_pts
    return_dict['ngen_true'] = ngen_true
    return_dict['ngen_train'] = ngen_train
    
    return return_dict

# %%
rd = read_sample( input_dir, 0 )

ngen_true = rd['ngen_true']
ngen_train = rd['ngen_train']

#true_pts = rd['true_pts']
true_det_pts = rd['true_det_pts']
train_pts = rd['train_pts']
train_det_pts = rd['train_det_pts']


print('  true_pts:   ngen_true  = %8d,  shape = %s' % (ngen_true, str(true_det_pts.shape)) )
print('  train_pts:  ngen_train = %8d,  shape = %s' % (ngen_train, str(train_pts.shape)) )
# Out:
#   true_pts:   ngen_true  =    10039,  shape = (10039, 1)
#   train_pts:  ngen_train =   100000,  shape = (100000, 1)

# %% [markdown]
# ## Function that estimates the pdf from a histogram (multi-bin sum)

# %%
#-- computes pdf2/pdf1 at location of points1
#
#    for OmniFold step 1, points2 is the data, points1 is the MC
#

def pdf_ratio_from_hist( points1, points2, weights1, weights2, hist_pars, verbose=0 ) :
    
    ndim = points1.shape[1]
    
    if ndim > 1 :
        print('\n\n *** Only 1D supported for now.\n\n')
        sys.exit()
        
    hist_low = hist_pars['low']
    hist_high = hist_pars['high']
    hist_nbins = hist_pars['nbins']
    hist_binwidth = hist_pars['binwidth']
    
    
    nph1 = np.histogram( points1[:,0], hist_nbins, range=[hist_low, hist_high], weights=weights1 )
    nph2 = np.histogram( points2[:,0], hist_nbins, range=[hist_low, hist_high], weights=weights2 )
    
    hist_pdf1 = np.zeros(hist_nbins)
    hist_pdf2 = np.zeros(hist_nbins)

    for bi in range( hist_nbins ) :
        bilow = bi - window_nbins
        bihigh = bi + window_nbins
        if bilow < 0 : bilow = 0
        if bihigh >= hist_nbins : bihigh = hist_nbins-1

        hist_pdf1[bi] = np.sum( nph1[0][bilow: bihigh] )
        hist_pdf2[bi] = np.sum( nph2[0][bilow: bihigh] )
    
    hist_pdf1_norm = hist_pdf1 / np.sum(hist_pdf1)
    hist_pdf2_norm = hist_pdf2 / np.sum(hist_pdf2)
    
    hist_bin_indices1 = np.array(   ( (points1[:,0] - hist_low) / hist_binwidth ),   dtype=int )
    
    points1_pdf1_val = hist_pdf1_norm[ hist_bin_indices1 ]
    points1_pdf2_val = hist_pdf2_norm[ hist_bin_indices1 ]
    
    points1_pdf1_val = np.clip( points1_pdf1_val, 1.e-10, 1.e10)
    points1_pdf2_val = np.clip( points1_pdf2_val, 1.e-10, 1.e10)
    
    pdf_ratio = points1_pdf2_val / points1_pdf1_val
    
    return pdf_ratio

# %% [markdown]
# ## Define OmniFold implementation with Simple pdf

# %%
def hist_pdf_omnifold1a( theta0, theta_unknown_S, iterations, verbose=0 ) :
    
    weights = np.empty(shape=(iterations, 2, len(theta0)))
    # shape = (iteration, step, event)
    push_weights_for_output = np.empty(shape=(iterations, len(theta0)))

    theta0_G = theta0[:,0]
    theta0_S = theta0[:,1]

    ngen_train = len(theta0)
    of_ngen_true  = len(theta_unknown_S)
    ndim = theta0_G.shape[1]

    labels0 = np.zeros(len(theta0))
    labels_unknown = np.ones(len(theta_unknown_S))
    labels_unknown_step2 = np.ones(len(theta0_G))


    neval_train = ngen_train
    neval_true  = of_ngen_true


    if verbose :
        print("\n\n")
        print("  ======== simple_pdf2b\n\n")
        print("  shape of theta0_S : %s" % str(np.shape(theta0_S)) )
        print("  shape of theta0_G : %s" % str(np.shape(theta0_G)) )
        print("  shape of theta_unknown_S : %s" % str(np.shape(theta_unknown_S)) )
        print("\n  iterations = %d\n" % iterations )
        print("  ndim : %d" % ndim )
        print("  neval_train : %d" % neval_train )
        print("  neval_true  : %d" % neval_true )
        print("\n\n")

    # initial iterative weights are ones
    weights_pull = np.ones(len(theta0_S))
    weights_push = np.ones(len(theta0_S))


    sample_norm_sf = ( (1.*neval_train)/(1.*neval_true) ) *  ( (1.*of_ngen_true)/(1.*ngen_train) )
    
    
    if verbose :
        print('\n\n Calculating model pars for data or true (theta_unknown_S)')
        
    

    
    
    
    
    
    
    return_dict = {}
    
    for i in range(iterations):
    
        if (verbose>0):
            print("\nITERATION: {}\n".format(i + 1))
            
        if (verbose>0):
            print("   -- ITERATION %d  STEP 1\n" % (i+1) )
            
        print(" weights_push at the beginning")
        print( weights_push )

        


        pdf_ratio_step1 = pdf_ratio_from_hist( theta0_S, 
                                              theta_unknown_S, 
                                              weights_push, 
                                              np.ones( of_ngen_true ),
                                              hist_pars
                                             )
        if verbose>0 :
            print(' pdf_ratio_step1:  shape %s ' % str(pdf_ratio_step1.shape))
            print(pdf_ratio_step1)
        
        
        step1_output_weights = sample_norm_sf * pdf_ratio_step1

        weights_pull = weights_push * step1_output_weights
        
        if verbose>0 :
            print("  iter %d, step1_output_weights:  shape %s" % (i+1, str(step1_output_weights.shape)))
            print(step1_output_weights)


        weights[i, :1, :] = step1_output_weights


            
            

        if (verbose>0):
            print("\n   -- ITERATION %d  STEP 2\n" % (i+1) )
            
       

        
        pdf_ratio_step2 = pdf_ratio_from_hist( theta0_G, 
                                              theta0_G, 
                                              weights_push, 
                                              weights_pull,
                                              hist_pars
                                             )
        
        
        step2_output_weights = pdf_ratio_step2
        
        weights_push = weights_push * step2_output_weights
        
        push_weights_for_output[i] = weights_push
        
        weights[i, 1:2, :] = step2_output_weights
        
        if verbose>0 :
           print("  iter %d, step2_output_weights:" % (i+1))
           print(step2_output_weights)
        
    return_dict["weights"] = weights

    return_dict["push_weights"] = push_weights_for_output

    return_dict["final_push_weights"] = weights_push

    return return_dict

# %%
train_both = np.stack([train_pts, train_det_pts], axis=1)

# %%
rd = hist_pdf_omnifold1a( train_both, true_det_pts, of_niter, 1 )
# Out:
#   ======== simple_pdf2b
#
#
#   shape of theta0_S : (100000, 1)
#   shape of theta0_G : (100000, 1)
#   shape of theta_unknown_S : (10039, 1)
#
#   iterations = 5
#
#   ndim : 1
#   neval_train : 100000
#   neval_true  : 10039
#
#
#
#
#
#  Calculating model pars for data or true (theta_unknown_S)
#
# ITERATION: 1
#
#    -- ITERATION 1  STEP 1
#
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  pdf_ratio_step1:  shape (100000,)
# [0.94486151 1.24572137 0.59241193 ... 0.72866279 0.88527037 1.17469396]
#   iter 1, step1_output_weights:  shape (100000,)
# [0.94486151 1.24572137 0.59241193 ... 0.72866279 0.88527037 1.17469396]
#
#    -- ITERATION 1  STEP 2
#
#   iter 1, step2_output_weights:
# [0.9540787  1.24328891 0.59727325 ... 0.74037765 0.90142884 1.22017726]
#
# ITERATION: 2
#
#    -- ITERATION 2  STEP 1
#
#  weights_push at the beginning
# [0.9540787  1.24328891 0.59727325 ... 0.74037765 0.90142884 1.22017726]
#  pdf_ratio_step1:  shape (100000,)
# [0.98842353 1.00365992 0.97304053 ... 0.97227531 0.98244451 0.96365973]
#   iter 2, step1_output_weights:  shape (100000,)
# [0.98842353 1.00365992 0.97304053 ... 0.97227531 0.98244451 0.96365973]
#
#    -- ITERATION 2  STEP 2
#
#   iter 2, step2_output_weights:
# [0.99911127 1.00636817 0.97445463 ... 0.97803023 0.99815183 0.99982468]
#
# ITERATION: 3
#
#    -- ITERATION 3  STEP 1
#
#  weights_push at the beginning
# [0.95323079 1.25120639 0.58201568 ... 0.72411172 0.89976284 1.21996334]
#  pdf_ratio_step1:  shape (100000,)
# [0.98680401 0.99482605 0.98110872 ... 0.98813671 0.98434204 0.96410618]
#   iter 3, step1_output_weights:  shape (100000,)
# [0.98680401 0.99482605 0.98110872 ... 0.98813671 0.98434204 0.96410618]
#
#    -- ITERATION 3  STEP 2
#
#   iter 3, step2_output_weights:
# [0.99807756 0.99844864 0.97472123 ... 0.98792548 0.99691072 0.9985387 ]
#
# ITERATION: 4
#
#    -- ITERATION 4  STEP 1
#
#  weights_push at the beginning
# [0.95139826 1.24926531 0.56730304 ... 0.71536842 0.89698322 1.2181806 ]
#  pdf_ratio_step1:  shape (100000,)
# [0.98602624 0.99291684 0.99360418 ... 0.9979769  0.98866413 0.96555536]
#   iter 4, step1_output_weights:  shape (100000,)
# [0.98602624 0.99291684 0.99360418 ... 0.9979769  0.98866413 0.96555536]
#
#    -- ITERATION 4  STEP 2
#
#   iter 4, step2_output_weights:
# [0.99778884 0.99641264 0.98208856 ... 0.99421278 0.99880711 0.99766554]
#
# ITERATION: 5
#
#    -- ITERATION 5  STEP 1
#
#  weights_push at the beginning
# [0.94929456 1.24478375 0.55714183 ... 0.71122843 0.89591322 1.21533681]
#  pdf_ratio_step1:  shape (100000,)
# [0.98532755 0.99302958 1.00191854 ... 1.00364448 0.99206096 0.9684607 ]
#   iter 5, step1_output_weights:  shape (100000,)
# [0.98532755 0.99302958 1.00191854 ... 1.00364448 0.99206096 0.9684607 ]
#
#    -- ITERATION 5  STEP 2
#
#   iter 5, step2_output_weights:
# [0.99735901 0.9961781  0.98735687 ... 0.99770658 1.00040583 0.99859539]

# %%
of_weights = rd["weights"]

mc_weight_sf = (1.*len(true_det_pts))/(1.*len(train_both))

push_weights = rd["push_weights"]
push_weights_scaled = np.copy( push_weights )
push_weights_scaled = mc_weight_sf * push_weights

final_push_weights = rd["final_push_weights"]
final_push_weights_scaled = np.copy(final_push_weights)
final_push_weights_scaled = mc_weight_sf * final_push_weights

with open( '%s/omnifold-output-weights.npy' % output_dir, 'wb') as f :
    np.save(f, final_push_weights_scaled)

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
            
            thisax.hist( train_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )            
            ###hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            #hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

    else :
        
        for di in range(ndim) :

            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
                
            hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )            
            ###hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        
            #hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        

    

 
    if ndim > 1 :
        thisax = ax[ofi][0]
    else :
        thisax = ax[ofi]
        
    thisax.set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show()

# %%
hist_data_diff = hist_data_mc_ofweighted - hist_data_truth
hist_data_diff2 = hist_data_diff * hist_data_diff

hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        hist_data_sum_diff2[ofi,di] = np.sum( hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        if ndim > 1 :
            thisax = ax[di]
        else :
            thisax = ax
        thisax.plot(hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(hist_data_diff[ofi,di])
    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( hist_data_sum_diff2)
ax[1].plot( hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show()

# %%
fig,ax = plt.subplots( of_niter, 4, figsize=(24,7*of_niter))

hmin=-6
hmax=6
hbins=40

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

for ofi in range(0,of_niter) :

    ax[ofi][0].hist( of_weights[ofi,0,:], bins=hbins, range=[0.,1.5] )
    
    ax[ofi][1].hist( of_weights[ofi,1,:], bins=hbins, range=[0.,1.5] )
    
    ax[ofi][2].hist( push_weights[ofi,:], bins=hbins, range=[0.,2.0] )
    #ax[ofi][2].hist( calc_weight, bins=hbins, range=[0.,2.0], alpha=0.5 )
    
    
    ax[ofi][3].hist2d( of_weights[ofi,0,:], of_weights[ofi,1,:], bins=[hbins,hbins] )
    
    ax[ofi][0].set_xlabel( 'step 1 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][1].set_xlabel( 'step 2 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][3].set_xlabel( 'step 1 likelihood ratio', fontsize=lfontsize )
    ax[ofi][3].set_ylabel( 'step 2 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][2].set_xlabel( 'Iteration %d push weight' % ofi, fontsize=lfontsize )
    
    ax[ofi][0].set_title('Iteration %d' % ofi, fontsize=lfontsize )
    
    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(8*2,5))

hbins=80

final_push_weights_scaled = np.clip( final_push_weights_scaled, 1e-11, 1e11)

ax[0].hist( final_push_weights_scaled, bins=hbins)
ax[0].set_yscale('log')

ax[1].hist( np.log10(final_push_weights_scaled), bins=hbins)

plt.show()

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

det_hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
det_hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
            
            thisax.hist( train_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            det_hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_det_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            #det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            
    else :
        
        for di in range(ndim) :

            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
        
            det_hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_det_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
            
            #det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        

    

    
    if ndim > 1 :
        thisax = ax[ofi][0]
    else :
        thisax = ax[ofi]
    
    thisax.set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show()

# %%
det_hist_data_diff = det_hist_data_mc_ofweighted - det_hist_data_truth
det_hist_data_diff2 = det_hist_data_diff * det_hist_data_diff

det_hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        det_hist_data_sum_diff2[ofi,di] = np.sum( det_hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        if ndim > 1 :
            thisax = ax[di]
        else :
            thisax = ax
        thisax.plot(det_hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(det_hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(det_hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( det_hist_data_sum_diff2)
ax[1].plot( det_hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show()

# %%
step1_mean = np.zeros( of_niter )
step1_rms = np.zeros( of_niter )

step2_mean = np.zeros( of_niter )
step2_rms = np.zeros( of_niter )

iter_val = np.zeros( of_niter )

for ofi in range( of_niter ) :
    
    iter_val[ofi] = ofi
    
    step1_mean[ofi] = np.mean( of_weights[ofi,0,:] )
    step1_rms[ofi] = np.sqrt( np.var( of_weights[ofi,0,:]))
    
    step2_mean[ofi] = np.mean( of_weights[ofi,1,:] )
    step2_rms[ofi] = np.sqrt( np.var( of_weights[ofi,1,:]))
    
    print("  iter %2d : step 1 mean  %.3f  rms %.3f      step 2 mean  %.3f  rms %.3f" % 
          (ofi, step1_mean[ofi], step1_rms[ofi], step2_mean[ofi], step2_rms[ofi]) )
# Out:
#   iter  0 : step 1 mean  0.999  rms 0.227      step 2 mean  0.998  rms 0.225
#   iter  1 : step 1 mean  0.999  rms 0.053      step 2 mean  0.999  rms 0.032
#   iter  2 : step 1 mean  0.998  rms 0.047      step 2 mean  0.999  rms 0.027
#   iter  3 : step 1 mean  0.999  rms 0.045      step 2 mean  0.999  rms 0.025
#   iter  4 : step 1 mean  0.999  rms 0.044      step 2 mean  0.999  rms 0.024

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,7))

ax[0].plot( iter_val, step1_mean )
ax[0].plot( iter_val, step2_mean )
ax[0].set_ylim( 0.80, 1.05)

ax[1].plot( iter_val, step1_rms )
ax[1].plot( iter_val, step2_rms )
ax[1].set_ylim( 0, 1.1*np.max(step1_rms))


plt.show()

# %%
verbose = False



import gc

# %%
# %%time

rng = np.random.default_rng()

for bi in range(0,n_samples) :

    print('\n\n\n ==== processing sample %6d' % bi )
        
    rd = read_sample( input_dir, bi )

    ngen_true = rd['ngen_true']
    ngen_train = rd['ngen_train']

    #true_pts = rd['true_pts']
    true_det_pts = rd['true_det_pts']
    train_pts = rd['train_pts']
    train_det_pts = rd['train_det_pts']
    
    train_both = np.stack([train_pts, train_det_pts], axis=1)
        
    
    rd = hist_pdf_omnifold1a( train_both, true_det_pts, of_niter, 0 )
    
    
    
    mc_weight_sf = (1.*len(true_det_pts))/(1.*len(train_both))



    boot_final_push_weights = rd["final_push_weights"]
    boot_final_push_weights_scaled = boot_final_push_weights
    boot_final_push_weights_scaled = mc_weight_sf * boot_final_push_weights
    
    print("\n\n bootstrap %d final push weights scaled:" % bi)
    print( boot_final_push_weights_scaled )

     
    with open( '%s/bootstrap-weights-%03d.npy' % ( output_dir, bi ), 'wb' ) as f :
        np.save( f, boot_final_push_weights_scaled )
        
    del boot_final_push_weights_scaled
    del rd
    gc.collect()
# Out:
# CPU times: user 17 ms, sys: 3.96 ms, total: 20.9 ms
# Wall time: 24.7 ms
#  ==== processing sample     14
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.90631573 1.23749941 0.57633674 ... 0.70608076 0.83599937 1.22601597]
#  weights_push at the beginning
# [0.90565723 1.24423416 0.58384733 ... 0.69075604 0.8243192  1.22221972]
#  weights_push at the beginning
# [0.90751478 1.24495066 0.58846139 ... 0.67789398 0.81674839 1.22707064]
#  weights_push at the beginning
# [0.90994371 1.24275496 0.59122932 ... 0.66831113 0.81202602 1.2312183 ]
#
#
#  bootstrap 14 final push weights scaled:
# [0.09129143 0.1240347  0.05931762 ... 0.06615667 0.08093974 0.12352851]
#
#
#
#  ==== processing sample     15
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94545814 1.2137149  0.53860067 ... 0.76865896 0.8792382  1.15832155]
#  weights_push at the beginning
# [0.94471459 1.21920909 0.53149876 ... 0.75722469 0.87598593 1.15907175]
#  weights_push at the beginning
# [0.94381629 1.21702253 0.52879456 ... 0.7486824  0.87497344 1.16900243]
#  weights_push at the beginning
# [0.94309375 1.21254056 0.52749727 ... 0.74340687 0.87530512 1.18111199]
#
#
#  bootstrap 15 final push weights scaled:
# [0.09553125 0.12244426 0.0533584  ... 0.07499584 0.08881762 0.12112556]
#
#
#
#  ==== processing sample     16
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92057053 1.18454467 0.55214397 ... 0.75515708 0.89379016 1.29915738]
#  weights_push at the beginning
# [0.90653093 1.18658749 0.53441386 ... 0.75571598 0.90856668 1.28967351]
#  weights_push at the beginning
# [0.89566355 1.18476475 0.52747511 ... 0.75484902 0.91875487 1.28516908]
#  weights_push at the beginning
# [0.88752607 1.18130982 0.52626947 ... 0.75426746 0.92692555 1.28298628]
#
#
#  bootstrap 16 final push weights scaled:
# [0.08857146 0.11835305 0.05305655 ... 0.07577756 0.09388971 0.12893047]
#
#
#
#  ==== processing sample     17
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.00699337 1.24611649 0.50830069 ... 0.71460064 0.87921465 1.24567491]
#  weights_push at the beginning
# [1.02027455 1.26653607 0.50020734 ... 0.71297663 0.87434562 1.24836957]
#  weights_push at the beginning
# [1.02411419 1.27452885 0.49455991 ... 0.71194973 0.86921843 1.26070878]
#  weights_push at the beginning
# [1.02559116 1.27795943 0.49033004 ... 0.71177736 0.86589585 1.2738867 ]
#
#
#  bootstrap 17 final push weights scaled:
# [0.10215046 0.12740315 0.04847916 ... 0.07089574 0.08600375 0.12805375]
#
#
#
#  ==== processing sample     18
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95252802 1.23145279 0.59993679 ... 0.78382857 0.86438949 1.20415516]
#  weights_push at the beginning
# [0.96066851 1.24688533 0.60075383 ... 0.79130909 0.85495903 1.19988142]
#  weights_push at the beginning
# [0.96582015 1.25126346 0.6009847  ... 0.79402962 0.84879863 1.20143099]
#  weights_push at the beginning
# [0.96961674 1.25188343 0.60103091 ... 0.79584657 0.84446041 1.20223661]
#
#
#  bootstrap 18 final push weights scaled:
# [0.09827913 0.12644486 0.06071064 ... 0.08057459 0.08498323 0.12148443]
#
#
#
#  ==== processing sample     19
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99530164 1.23631863 0.63473158 ... 0.71731174 0.90397282 1.25090712]
#  weights_push at the beginning
# [1.00273064 1.24945225 0.64002127 ... 0.71157826 0.89789592 1.27368715]
#  weights_push at the beginning
# [1.00577902 1.25357688 0.63785206 ... 0.70914673 0.89066954 1.28969101]
#  weights_push at the beginning
# [1.0077269  1.2554183  0.63505598 ... 0.70771368 0.88576441 1.29934068]
#
#
#  bootstrap 19 final push weights scaled:
# [0.10021767 0.12479656 0.06283874 ... 0.07021256 0.08766794 0.1297876 ]
#
#
#
#  ==== processing sample     20
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98835744 1.22584618 0.52300907 ... 0.76410609 0.88667156 1.26216456]
#  weights_push at the beginning
# [0.99830019 1.23805253 0.5077178  ... 0.76924248 0.8800866  1.27193783]
#  weights_push at the beginning
# [1.00010268 1.24149922 0.49951094 ... 0.77309546 0.87550937 1.27631673]
#  weights_push at the beginning
# [0.99933934 1.24203571 0.49435525 ... 0.77685506 0.87300659 1.27321165]
#
#
#  bootstrap 20 final push weights scaled:
# [0.10002783 0.12452433 0.04918171 ... 0.07822762 0.08739097 0.12700083]
#
#
#
#  ==== processing sample     21
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96767205 1.21182688 0.57723441 ... 0.7503056  0.84051032 1.2744908 ]
#  weights_push at the beginning
# [0.97361721 1.21762928 0.58306418 ... 0.75214512 0.84647812 1.29224487]
#  weights_push at the beginning
# [0.97009837 1.22172877 0.58717724 ... 0.75174429 0.85167933 1.30647079]
#  weights_push at the beginning
# [0.96569213 1.22411779 0.59048875 ... 0.75151975 0.85590446 1.31714029]
#
#
#  bootstrap 21 final push weights scaled:
# [0.09816477 0.12512228 0.06054832 ... 0.07672242 0.08773377 0.13533712]
#
#
#
#  ==== processing sample     22
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9372799  1.19624356 0.60727262 ... 0.80553054 0.90912467 1.16739712]
#  weights_push at the beginning
# [0.93754527 1.18821703 0.60594553 ... 0.80475108 0.90817754 1.14773078]
#  weights_push at the beginning
# [0.94035102 1.18270055 0.60383767 ... 0.80156697 0.90592439 1.13738456]
#  weights_push at the beginning
# [0.94360055 1.17934295 0.60232923 ... 0.80021777 0.90381964 1.12763926]
#
#
#  bootstrap 22 final push weights scaled:
# [0.09429292 0.11726597 0.05989079 ... 0.0797266  0.08984691 0.11145739]
#
#
#
#  ==== processing sample     23
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93099139 1.20292116 0.55816778 ... 0.74166476 0.86369621 1.28028691]
#  weights_push at the beginning
# [0.93413836 1.20146428 0.55766005 ... 0.74150158 0.85681643 1.30157588]
#  weights_push at the beginning
# [0.93689122 1.1988486  0.5620823  ... 0.7413244  0.85119567 1.31729705]
#  weights_push at the beginning
# [0.93895941 1.19649526 0.56775891 ... 0.74179865 0.84736229 1.32870636]
#
#
#  bootstrap 23 final push weights scaled:
# [0.09405564 0.11949777 0.05736557 ... 0.07427353 0.08449077 0.13387711]
#
#
#
#  ==== processing sample     24
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99062693 1.2884649  0.56065248 ... 0.7453426  0.84944362 1.1807252 ]
#  weights_push at the beginning
# [1.00516175 1.30879096 0.55297753 ... 0.7474844  0.84060991 1.15871853]
#  weights_push at the beginning
# [1.00696122 1.31517783 0.55018966 ... 0.74937637 0.83548315 1.15229512]
#  weights_push at the beginning
# [1.00519614 1.31758514 0.55053648 ... 0.75134498 0.83262851 1.14879361]
#
#
#  bootstrap 24 final push weights scaled:
# [0.10021229 0.13181562 0.05521877 ... 0.07531198 0.08307601 0.1146376 ]
#
#
#
#  ==== processing sample     25
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96105323 1.15727328 0.55956214 ... 0.78164778 0.83642011 1.30396836]
#  weights_push at the beginning
# [0.9739193  1.14089562 0.56016888 ... 0.78205099 0.82668688 1.31751188]
#  weights_push at the beginning
# [0.97909513 1.12835306 0.56037137 ... 0.78321886 0.82447553 1.321708  ]
#  weights_push at the beginning
# [0.98126058 1.11937901 0.56061994 ... 0.78521154 0.82496914 1.32238775]
#
#
#  bootstrap 25 final push weights scaled:
# [0.09827755 0.11139602 0.0561341  ... 0.07877778 0.08270195 0.13237308]
#
#
#
#  ==== processing sample     26
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94896524 1.19663919 0.53883956 ... 0.72406322 0.84417217 1.29473273]
#  weights_push at the beginning
# [0.95564061 1.20853448 0.53433903 ... 0.72036365 0.83060665 1.29404681]
#  weights_push at the beginning
# [0.95876869 1.21820801 0.53026429 ... 0.71776482 0.82375552 1.29080578]
#  weights_push at the beginning
# [0.96030704 1.22409262 0.52640599 ... 0.71695855 0.82088335 1.2867926 ]
#
#
#  bootstrap 26 final push weights scaled:
# [0.09821178 0.12545091 0.05341498 ... 0.07330862 0.08379032 0.13115209]
#
#
#
#  ==== processing sample     27
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95167205 1.23576651 0.62982783 ... 0.7982358  0.83057751 1.23820276]
#  weights_push at the beginning
# [0.96177273 1.24840853 0.62527004 ... 0.81380665 0.81313745 1.25471339]
#  weights_push at the beginning
# [0.96628135 1.25415949 0.61794874 ... 0.81681429 0.80431077 1.26549971]
#  weights_push at the beginning
# [0.96844985 1.25743986 0.61250722 ... 0.81617272 0.79864745 1.27134417]
#
#
#  bootstrap 27 final push weights scaled:
# [0.09772722 0.12695961 0.06133155 ... 0.08207844 0.08003961 0.12853951]
#  ==== processing sample     28
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92433852 1.23128784 0.55494364 ... 0.69488195 0.87566665 1.22132255]
#  weights_push at the beginning
# [0.92237492 1.22853757 0.54256874 ... 0.68212976 0.86396366 1.23170133]
#  weights_push at the beginning
# [0.92271422 1.2269006  0.53634638 ... 0.67372127 0.85417605 1.24042459]
#  weights_push at the beginning
# [0.92273001 1.22573406 0.5345966  ... 0.66896802 0.8483517  1.24530183]
#
#
#  bootstrap 28 final push weights scaled:
# [0.09126182 0.12125888 0.05300984 ... 0.06599163 0.08365781 0.12357194]
#
#
#
#  ==== processing sample     29
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9449106  1.27209296 0.48961907 ... 0.72037939 0.88749816 1.24424516]
#  weights_push at the beginning
# [0.94309431 1.28431631 0.47878105 ... 0.71283866 0.87767753 1.26951962]
#  weights_push at the beginning
# [0.94305418 1.28282238 0.47489355 ... 0.71153734 0.86992498 1.28597674]
#  weights_push at the beginning
# [0.94296044 1.27851612 0.47462153 ... 0.71320122 0.86545069 1.29523559]
#
#
#  bootstrap 29 final push weights scaled:
# [0.0944475  0.12773704 0.04771801 ... 0.07175061 0.08649953 0.1304636 ]
#
#
#
#  ==== processing sample     30
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97170678 1.2122952  0.5529349  ... 0.72456785 0.9147056  1.27620022]
#  weights_push at the beginning
# [0.96588746 1.21810654 0.54666327 ... 0.71921831 0.92574318 1.31080706]
#  weights_push at the beginning
# [0.95931321 1.21747172 0.54359545 ... 0.7143536  0.93030359 1.33367966]
#  weights_push at the beginning
# [0.95443842 1.21576701 0.54244045 ... 0.7099956  0.93357443 1.34536079]
#
#
#  bootstrap 30 final push weights scaled:
# [0.09783505 0.12493078 0.05576888 ... 0.07265699 0.09637085 0.13902953]
#
#
#
#  ==== processing sample     31
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91764089 1.20097937 0.63415116 ... 0.79979317 0.91611755 1.18983768]
#  weights_push at the beginning
# [0.9033668  1.20194459 0.63799228 ... 0.80900963 0.92392877 1.20740537]
#  weights_push at the beginning
# [0.89574865 1.19946148 0.63879471 ... 0.81615504 0.92886204 1.22208038]
#  weights_push at the beginning
# [0.89156175 1.1951749  0.63911644 ... 0.82181286 0.93242484 1.23091353]
#
#
#  bootstrap 31 final push weights scaled:
# [0.08903416 0.11911889 0.06401021 ... 0.08272936 0.0935785  0.12383052]
#
#
#
#  ==== processing sample     32
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92027987 1.19911765 0.58136322 ... 0.72243082 0.88403971 1.29320009]
#  weights_push at the beginning
# [0.9168944  1.20192225 0.58535166 ... 0.71639956 0.87218349 1.30752714]
#  weights_push at the beginning
# [0.91627085 1.20163164 0.5881568  ... 0.71244132 0.86230556 1.32028719]
#  weights_push at the beginning
# [0.91517904 1.20024804 0.5911924  ... 0.71074513 0.85605498 1.32791353]
#
#
#  bootstrap 32 final push weights scaled:
# [0.09072876 0.11909166 0.05907544 ... 0.07059819 0.08466717 0.13242056]
#
#
#
#  ==== processing sample     33
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99731553 1.13560496 0.5696198  ... 0.77454153 0.90911228 1.31890257]
#  weights_push at the beginning
# [1.00653824 1.13051677 0.56593447 ... 0.78279392 0.91217719 1.33374499]
#  weights_push at the beginning
# [1.00837596 1.13166159 0.56624633 ... 0.78408438 0.91166475 1.3423418 ]
#  weights_push at the beginning
# [1.00901495 1.13207908 0.56725282 ... 0.78379636 0.91062205 1.34982483]
#
#
#  bootstrap 33 final push weights scaled:
# [0.09972649 0.11175616 0.05613812 ... 0.07735873 0.08983346 0.13404807]
#
#
#
#  ==== processing sample     34
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93837869 1.25911203 0.57111154 ... 0.74535195 0.86916855 1.22876351]
#  weights_push at the beginning
# [0.94088972 1.28647652 0.57797972 ... 0.74548358 0.85864803 1.22565233]
#  weights_push at the beginning
# [0.94299354 1.29792863 0.58019459 ... 0.74472476 0.85335585 1.22591623]
#  weights_push at the beginning
# [0.94403911 1.30173114 0.58034963 ... 0.74431479 0.8513775  1.22715111]
#
#
#  bootstrap 34 final push weights scaled:
# [0.09349277 0.12889992 0.05742509 ... 0.07367202 0.08423808 0.12172402]
#
#
#
#  ==== processing sample     35
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99608482 1.19683154 0.58444867 ... 0.77592831 0.88516409 1.28320329]
#  weights_push at the beginning
# [0.996087   1.20669623 0.59780834 ... 0.78223668 0.89084603 1.30404927]
#  weights_push at the beginning
# [0.98700226 1.20850941 0.60409772 ... 0.78452666 0.89461413 1.31917176]
#  weights_push at the beginning
# [0.97757396 1.20741926 0.60733846 ... 0.78626118 0.89761133 1.32836814]
#
#
#  bootstrap 35 final push weights scaled:
# [0.09699366 0.12062836 0.0609534  ... 0.07887422 0.09007514 0.13348833]
#
#
#
#  ==== processing sample     36
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.87885975 1.21683244 0.54948756 ... 0.70034083 0.86987254 1.2796006 ]
#  weights_push at the beginning
# [0.86020765 1.20509427 0.55103517 ... 0.68394501 0.87932112 1.28079712]
#  weights_push at the beginning
# [0.85062095 1.19514261 0.55283453 ... 0.67467152 0.88092379 1.28143481]
#  weights_push at the beginning
# [0.84617593 1.18721264 0.55374071 ... 0.66906884 0.8803529  1.28180189]
#
#
#  bootstrap 36 final push weights scaled:
# [0.08457675 0.11829305 0.05547818 ... 0.06666179 0.08810031 0.12851683]
#
#
#
#  ==== processing sample     37
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98002497 1.22672311 0.56558138 ... 0.74294623 0.89992539 1.25962043]
#  weights_push at the beginning
# [0.98987576 1.24218119 0.55555916 ... 0.73293082 0.88942215 1.27074323]
#  weights_push at the beginning
# [0.99580266 1.24731968 0.55282076 ... 0.72943026 0.8811086  1.28404025]
#  weights_push at the beginning
# [0.99949362 1.24899447 0.55317758 ... 0.72897228 0.87633505 1.29722553]
#
#
#  bootstrap 37 final push weights scaled:
# [0.10056171 0.12547126 0.05569192 ... 0.07326983 0.08773403 0.13148501]
#
#
#
#  ==== processing sample     38
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96057749 1.20507541 0.50971408 ... 0.7989496  0.83364647 1.25013833]
#  weights_push at the beginning
# [0.96130606 1.22181319 0.50513628 ... 0.80440709 0.82545195 1.24878901]
#  weights_push at the beginning
# [0.9553768  1.22582614 0.50436456 ... 0.80245452 0.82471721 1.24968137]
#  weights_push at the beginning
# [0.94821768 1.2249553  0.50394692 ... 0.79979272 0.82585029 1.24990001]
#
#
#  bootstrap 38 final push weights scaled:
# [0.09375542 0.121772   0.05015476 ... 0.07940425 0.0824243  0.12452849]
#
#
#
#  ==== processing sample     39
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96281556 1.20480588 0.59029623 ... 0.75537616 0.86754491 1.23966383]
#  weights_push at the beginning
# [0.9634178  1.21841618 0.59050549 ... 0.74594219 0.86441358 1.23816562]
#  weights_push at the beginning
# [0.95824172 1.22441982 0.59156537 ... 0.73938929 0.86177472 1.24354425]
#  weights_push at the beginning
# [0.95248328 1.22711676 0.59302254 ... 0.73472071 0.85992524 1.24993758]
#
#
#  bootstrap 39 final push weights scaled:
# [0.09525889 0.123541   0.05978364 ... 0.07352929 0.08636405 0.12634066]
#
#
#
#  ==== processing sample     40
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9624842  1.20561292 0.57270122 ... 0.68932376 0.886632   1.24912014]
#  weights_push at the beginning
# [0.96106476 1.21282129 0.57486913 ... 0.6771016  0.89987553 1.24429429]
#  weights_push at the beginning
# [0.95617858 1.21506785 0.57891495 ... 0.67241479 0.90687612 1.25149884]
#  weights_push at the beginning
# [0.95232658 1.21507556 0.58352328 ... 0.67033725 0.91266116 1.26010168]
#
#
#  bootstrap 40 final push weights scaled:
# [0.09376308 0.11996294 0.05807811 ... 0.06610289 0.09068183 0.12527141]
#
#
#
#  ==== processing sample     41
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96349748 1.22154719 0.57620652 ... 0.78041881 0.92710922 1.14273378]
#  weights_push at the beginning
# [0.95819219 1.23511537 0.56373811 ... 0.77908019 0.93102624 1.12519129]
#  weights_push at the beginning
# [0.95464625 1.23610888 0.55670027 ... 0.78131114 0.93467942 1.11733171]
#  weights_push at the beginning
# [0.95199761 1.233524   0.55385318 ... 0.78471406 0.93920168 1.10997068]
#
#
#  bootstrap 41 final push weights scaled:
# [0.09489339 0.1229143  0.05525752 ... 0.07873612 0.09431395 0.11021454]
#  ==== processing sample     42
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93898758 1.19231927 0.53786618 ... 0.67568248 0.8884312  1.24088407]
#  weights_push at the beginning
# [0.93039218 1.17322837 0.52521559 ... 0.65801629 0.88900524 1.25036945]
#  weights_push at the beginning
# [0.92402672 1.16324794 0.51860109 ... 0.64777611 0.88881449 1.25861611]
#  weights_push at the beginning
# [0.91914701 1.15840159 0.51461451 ... 0.64171647 0.89108293 1.26280493]
#
#
#  bootstrap 42 final push weights scaled:
# [0.09103594 0.11505966 0.05095105 ... 0.06349921 0.08906607 0.1259482 ]
#
#
#
#  ==== processing sample     43
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97927997 1.1781419  0.56477169 ... 0.73582697 0.83160586 1.26554106]
#  weights_push at the beginning
# [1.00022417 1.16967751 0.56672536 ... 0.72859961 0.81737342 1.26638249]
#  weights_push at the beginning
# [1.00940947 1.16460782 0.5679761  ... 0.72403818 0.81003677 1.26953486]
#  weights_push at the beginning
# [1.01413524 1.15987236 0.57038401 ... 0.72143302 0.80655758 1.27161952]
#
#
#  bootstrap 43 final push weights scaled:
# [0.10179821 0.11569389 0.05742309 ... 0.07207555 0.08060486 0.1274674 ]
#
#
#
#  ==== processing sample     44
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97430878 1.13937431 0.5513821  ... 0.81101305 0.88002965 1.19295311]
#  weights_push at the beginning
# [0.97595997 1.11974827 0.54374468 ... 0.83500256 0.89577496 1.20386531]
#  weights_push at the beginning
# [0.97142984 1.11035452 0.53776788 ... 0.84800216 0.90732808 1.21914488]
#  weights_push at the beginning
# [0.96749207 1.10473928 0.53375624 ... 0.85735719 0.91552918 1.22904871]
#
#
#  bootstrap 44 final push weights scaled:
# [0.09780572 0.11161392 0.05382559 ... 0.0876664  0.09342298 0.12522987]
#
#
#
#  ==== processing sample     45
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99840215 1.20725791 0.56160923 ... 0.75891607 0.85057193 1.19365494]
#  weights_push at the beginning
# [1.00643459 1.20679063 0.55679354 ... 0.75479625 0.85194039 1.18075945]
#  weights_push at the beginning
# [1.00224157 1.20414638 0.5553287  ... 0.75098664 0.85614026 1.17648712]
#  weights_push at the beginning
# [0.99605052 1.20096607 0.55574995 ... 0.74898448 0.86108601 1.17402607]
#
#
#  bootstrap 45 final push weights scaled:
# [0.09823344 0.11887949 0.05525222 ... 0.0742471  0.08595937 0.11637103]
#
#
#
#  ==== processing sample     46
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99825886 1.20632005 0.62140821 ... 0.72154115 0.87825923 1.22079357]
#  weights_push at the beginning
# [1.01465972 1.21196476 0.61084136 ... 0.70240983 0.86571784 1.22145533]
#  weights_push at the beginning
# [1.02352626 1.21117698 0.60407828 ... 0.69261148 0.85595277 1.21953449]
#  weights_push at the beginning
# [1.02948582 1.20945792 0.60059495 ... 0.68735184 0.85009085 1.21658854]
#
#
#  bootstrap 46 final push weights scaled:
# [0.10172614 0.11893085 0.0589286  ... 0.0673727  0.08335771 0.11956472]
#
#
#
#  ==== processing sample     47
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94718303 1.20664596 0.60463052 ... 0.7473255  0.86868245 1.1123802 ]
#  weights_push at the beginning
# [0.94574293 1.20845754 0.61773586 ... 0.74995917 0.8667035  1.08086567]
#  weights_push at the beginning
# [0.94204522 1.20601535 0.62224176 ... 0.74740832 0.86687984 1.06923683]
#  weights_push at the beginning
# [0.93799105 1.20299981 0.62449165 ... 0.74355779 0.8686221  1.06212575]
#
#
#  bootstrap 47 final push weights scaled:
# [0.09293559 0.11950138 0.06229028 ... 0.0735933  0.08667132 0.10518722]
#
#
#
#  ==== processing sample     48
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98525031 1.20652203 0.5806703  ... 0.75274659 0.90678143 1.33122942]
#  weights_push at the beginning
# [0.98921035 1.22264981 0.58058183 ... 0.7452266  0.90834593 1.354856  ]
#  weights_push at the beginning
# [0.98820605 1.22921521 0.58121361 ... 0.7360628  0.91058363 1.36686378]
#  weights_push at the beginning
# [0.98614723 1.23184422 0.58180544 ... 0.72837729 0.91429452 1.37386795]
#
#
#  bootstrap 48 final push weights scaled:
# [0.09917444 0.12427185 0.05868387 ... 0.07278375 0.09258256 0.13898951]
#
#
#
#  ==== processing sample     49
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98518625 1.22050726 0.61700986 ... 0.71445631 0.87454553 1.34267973]
#  weights_push at the beginning
# [0.99217153 1.22889897 0.60620689 ... 0.71034734 0.87919051 1.37471504]
#  weights_push at the beginning
# [0.99174192 1.22858556 0.59753248 ... 0.71203703 0.87949716 1.3863323 ]
#  weights_push at the beginning
# [0.99085639 1.22694108 0.59277589 ... 0.71515035 0.87908757 1.388594  ]
#
#
#  bootstrap 49 final push weights scaled:
# [0.09882901 0.12232676 0.0589306  ... 0.07171816 0.08769764 0.13853311]
#
#
#
#  ==== processing sample     50
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95467883 1.24665101 0.53246959 ... 0.76947791 0.90073682 1.24818941]
#  weights_push at the beginning
# [0.95142935 1.26597784 0.52776517 ... 0.77109924 0.89975587 1.25509559]
#  weights_push at the beginning
# [0.94679347 1.27130325 0.52412149 ... 0.76986218 0.90101433 1.26821306]
#  weights_push at the beginning
# [0.94181311 1.27218354 0.52107367 ... 0.76839121 0.90393429 1.28142647]
#
#
#  bootstrap 50 final push weights scaled:
# [0.09350114 0.12693286 0.05173374 ... 0.07650463 0.09051945 0.12910152]
#
#
#
#  ==== processing sample     51
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95745522 1.1892925  0.6180068  ... 0.78542165 0.84790621 1.24484022]
#  weights_push at the beginning
# [0.96391733 1.19419031 0.6356772  ... 0.78725894 0.82638543 1.26928867]
#  weights_push at the beginning
# [0.96633741 1.19783255 0.64003856 ... 0.78390202 0.8143298  1.28314411]
#  weights_push at the beginning
# [0.96640576 1.20024611 0.64140969 ... 0.78041445 0.80707096 1.28937815]
#
#
#  bootstrap 51 final push weights scaled:
# [0.0966079  0.12036078 0.06428422 ... 0.07782635 0.08030241 0.12930873]
#
#
#
#  ==== processing sample     52
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99751955 1.25282353 0.54820558 ... 0.7749854  0.89462282 1.13187723]
#  weights_push at the beginning
# [1.01345066 1.26822164 0.54385802 ... 0.78217816 0.88904042 1.1061051 ]
#  weights_push at the beginning
# [1.02107838 1.27212681 0.5430637  ... 0.78984294 0.88409116 1.09625848]
#  weights_push at the beginning
# [1.0255925  1.27186664 0.5435337  ... 0.7973633  0.88080671 1.09115789]
#
#
#  bootstrap 52 final push weights scaled:
# [0.10391504 0.12830833 0.05502513 ... 0.08126044 0.08877543 0.1100676 ]
#
#
#
#  ==== processing sample     53
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9183651  1.21326877 0.59575502 ... 0.72626051 0.88239195 1.17530769]
#  weights_push at the beginning
# [0.90875401 1.21665687 0.58386865 ... 0.72392819 0.88429589 1.16805669]
#  weights_push at the beginning
# [0.9040641  1.21346867 0.5744827  ... 0.72362566 0.88073353 1.17008116]
#  weights_push at the beginning
# [0.90223942 1.20911096 0.56764765 ... 0.72429982 0.87628856 1.17219093]
#
#
#  bootstrap 53 final push weights scaled:
# [0.08996203 0.12025161 0.05609493 ... 0.07239066 0.08700368 0.11716103]
#
#
#
#  ==== processing sample     54
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93284832 1.19410635 0.59270563 ... 0.78045359 0.91734708 1.21223958]
#  weights_push at the beginning
# [0.92495665 1.1893467  0.59261489 ... 0.79029886 0.92453201 1.22213722]
#  weights_push at the beginning
# [0.92017898 1.18829061 0.59127354 ... 0.79548352 0.92779977 1.23842388]
#  weights_push at the beginning
# [0.91714142 1.1885248  0.58961893 ... 0.79900869 0.93035724 1.25216753]
#
#
#  bootstrap 54 final push weights scaled:
# [0.0896564  0.11651033 0.05759414 ... 0.07856124 0.09136953 0.12377931]
#
#
#
#  ==== processing sample     55
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94736021 1.16333316 0.59052796 ... 0.82314634 0.91851666 1.28745234]
#  weights_push at the beginning
# [0.94066344 1.16107469 0.5990764  ... 0.83328276 0.91418981 1.32908022]
#  weights_push at the beginning
# [0.93736498 1.1604576  0.6018954  ... 0.83349184 0.91201244 1.35258892]
#  weights_push at the beginning
# [0.9347173  1.16040589 0.60379361 ... 0.83269152 0.9112719  1.36704076]
#
#
#  bootstrap 55 final push weights scaled:
# [0.09352785 0.11646635 0.06073251 ... 0.08348309 0.09140172 0.13821427]
#  ==== processing sample     56
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98485564 1.14676342 0.61225126 ... 0.78371611 0.85736231 1.2744634 ]
#  weights_push at the beginning
# [0.99245041 1.14690594 0.61354408 ... 0.7915992  0.85365803 1.29017109]
#  weights_push at the beginning
# [0.99251087 1.14682442 0.61485486 ... 0.79755112 0.85454347 1.30521892]
#  weights_push at the beginning
# [0.99121075 1.14629764 0.6169724  ... 0.80301365 0.85689402 1.31625277]
#
#
#  bootstrap 56 final push weights scaled:
# [0.09879074 0.11436831 0.06181862 ... 0.08066802 0.08579665 0.13219134]
#
#
#
#  ==== processing sample     57
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97258217 1.25246066 0.53180186 ... 0.73418168 0.82760957 1.27137292]
#  weights_push at the beginning
# [0.9918413  1.26103234 0.52958107 ... 0.72302916 0.81072277 1.3139056 ]
#  weights_push at the beginning
# [1.00258226 1.26255455 0.52869496 ... 0.71241185 0.79796754 1.34503335]
#  weights_push at the beginning
# [1.01020272 1.26184901 0.52890909 ... 0.70534532 0.78804408 1.36552931]
#
#
#  bootstrap 57 final push weights scaled:
# [0.1025215  0.12715413 0.05343211 ... 0.07072667 0.07872641 0.13931338]
#
#
#
#  ==== processing sample     58
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95188985 1.18336848 0.63511508 ... 0.75417826 0.8776358  1.22358691]
#  weights_push at the beginning
# [0.95130387 1.17237274 0.65497349 ... 0.74472894 0.86902835 1.21906187]
#  weights_push at the beginning
# [0.95125388 1.16204345 0.66465496 ... 0.73810177 0.86083925 1.22145809]
#  weights_push at the beginning
# [0.95164088 1.15408082 0.67068616 ... 0.73376343 0.85421473 1.2257636 ]
#
#
#  bootstrap 58 final push weights scaled:
# [0.09573894 0.11548247 0.0678556  ... 0.0735361  0.08539083 0.12381473]
#
#
#
#  ==== processing sample     59
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9413681  1.18590804 0.64013419 ... 0.78250542 0.90319332 1.2203268 ]
#  weights_push at the beginning
# [0.94029089 1.18511635 0.65391903 ... 0.79128933 0.90546702 1.21908436]
#  weights_push at the beginning
# [0.94127628 1.18112996 0.66180556 ... 0.79623406 0.90618295 1.21987364]
#  weights_push at the beginning
# [0.94275884 1.17585151 0.66790005 ... 0.80011755 0.90695006 1.21915508]
#
#
#  bootstrap 59 final push weights scaled:
# [0.09534932 0.11821072 0.06795236 ... 0.08116393 0.09168068 0.12305298]
#
#
#
#  ==== processing sample     60
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94701158 1.16802563 0.59516284 ... 0.73279924 0.92942592 1.2434245 ]
#  weights_push at the beginning
# [0.93889433 1.16265141 0.61085488 ... 0.73584374 0.95057707 1.24261728]
#  weights_push at the beginning
# [0.93449303 1.16293509 0.61626515 ... 0.74068758 0.9611541  1.2490891 ]
#  weights_push at the beginning
# [0.93330146 1.16498795 0.61986321 ... 0.74507598 0.96846635 1.25340894]
#
#
#  bootstrap 60 final push weights scaled:
# [0.09229664 0.11544335 0.06162018 ... 0.07400418 0.09630786 0.12408243]
#
#
#
#  ==== processing sample     61
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97339994 1.1864265  0.60921349 ... 0.74988834 0.88961398 1.28908748]
#  weights_push at the beginning
# [0.97892995 1.18909996 0.61336895 ... 0.75186387 0.88600456 1.29519655]
#  weights_push at the beginning
# [0.98076325 1.18789344 0.6139297  ... 0.75318852 0.88160246 1.2955266 ]
#  weights_push at the beginning
# [0.98163818 1.18467205 0.6152148  ... 0.7542519  0.87842891 1.2947166 ]
#
#
#  bootstrap 61 final push weights scaled:
# [0.0974422  0.11721452 0.06125588 ... 0.0749487  0.08695876 0.12845462]
#
#
#
#  ==== processing sample     62
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99660138 1.17980259 0.56940139 ... 0.75663521 0.86304895 1.21804218]
#  weights_push at the beginning
# [1.01484256 1.17947566 0.56957428 ... 0.76034619 0.85271925 1.18892768]
#  weights_push at the beginning
# [1.02362075 1.17808055 0.5679103  ... 0.76209902 0.84516652 1.16883572]
#  weights_push at the beginning
# [1.02937112 1.17572138 0.5668798  ... 0.76420038 0.83969812 1.1540965 ]
#
#
#  bootstrap 62 final push weights scaled:
# [0.10362007 0.11760805 0.05675682 ... 0.07686782 0.08374879 0.1146752 ]
#
#
#
#  ==== processing sample     63
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95833283 1.22984286 0.53197931 ... 0.72656769 0.90543363 1.23823043]
#  weights_push at the beginning
# [0.95420399 1.2386972  0.52358406 ... 0.72426318 0.9035492  1.24866738]
#  weights_push at the beginning
# [0.95170586 1.23912486 0.52132879 ... 0.72534394 0.89774808 1.25977088]
#  weights_push at the beginning
# [0.95061564 1.23682334 0.5214637  ... 0.72813648 0.89269917 1.27079532]
#
#
#  bootstrap 63 final push weights scaled:
# [0.09517563 0.12363821 0.05237299 ... 0.07329198 0.08902713 0.1284239 ]
#
#
#
#  ==== processing sample     64
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.90307356 1.16344448 0.55928683 ... 0.71662454 0.88173736 1.27716087]
#  weights_push at the beginning
# [0.88697051 1.15751484 0.55015372 ... 0.71432276 0.88974197 1.29031133]
#  weights_push at the beginning
# [0.87654551 1.15382395 0.54540185 ... 0.7118286  0.89451743 1.30058327]
#  weights_push at the beginning
# [0.86909538 1.1503193  0.54164762 ... 0.70988108 0.89882231 1.30929035]
#
#
#  bootstrap 64 final push weights scaled:
# [0.08639434 0.11485184 0.05383936 ... 0.07090804 0.09036147 0.13186988]
#
#
#
#  ==== processing sample     65
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93907694 1.22756082 0.56557719 ... 0.77910863 0.90020946 1.20309304]
#  weights_push at the beginning
# [0.93360873 1.23391582 0.56923134 ... 0.78532787 0.89430366 1.19183904]
#  weights_push at the beginning
# [0.92989757 1.23576348 0.5719163  ... 0.78475881 0.89042008 1.19673223]
#  weights_push at the beginning
# [0.92652624 1.23667387 0.57509788 ... 0.78297906 0.88833899 1.20549106]
#
#
#  bootstrap 65 final push weights scaled:
# [0.09175838 0.12295168 0.05749283 ... 0.07760719 0.08813262 0.1207678 ]
#
#
#
#  ==== processing sample     66
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93224139 1.22172282 0.52151465 ... 0.78859983 0.86547726 1.18653045]
#  weights_push at the beginning
# [0.93500105 1.22220489 0.50975646 ... 0.78990412 0.85413772 1.17758283]
#  weights_push at the beginning
# [0.93650007 1.21858166 0.50657839 ... 0.78840255 0.84797713 1.18392525]
#  weights_push at the beginning
# [0.93651677 1.21361093 0.50669837 ... 0.78856428 0.84461953 1.19419263]
#
#
#  bootstrap 66 final push weights scaled:
# [0.09500516 0.12270674 0.05158683 ... 0.0802026  0.08557445 0.12248905]
#
#
#
#  ==== processing sample     67
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96145303 1.11393745 0.62878841 ... 0.79259704 0.89138964 1.29246107]
#  weights_push at the beginning
# [0.95687001 1.09988055 0.63461342 ... 0.80875279 0.89646369 1.31097122]
#  weights_push at the beginning
# [0.9493928  1.09524579 0.63698639 ... 0.81571385 0.89946443 1.32298725]
#  weights_push at the beginning
# [0.94289453 1.09225701 0.63869778 ... 0.81893036 0.90104659 1.32931157]
#
#
#  bootstrap 67 final push weights scaled:
# [0.09409569 0.10937532 0.06419556 ... 0.08233432 0.09045375 0.13371968]
#
#
#
#  ==== processing sample     68
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92978694 1.19622559 0.61138585 ... 0.78884385 0.85387613 1.24204021]
#  weights_push at the beginning
# [0.93021987 1.21462198 0.61822417 ... 0.7910064  0.84415344 1.26621299]
#  weights_push at the beginning
# [0.93086404 1.22653898 0.62233138 ... 0.79430279 0.8404467  1.28428772]
#  weights_push at the beginning
# [0.93142859 1.23469846 0.62527987 ... 0.79808473 0.83891518 1.29523148]
#
#
#  bootstrap 68 final push weights scaled:
# [0.09400062 0.12512856 0.06329219 ... 0.0808724  0.08452366 0.13139703]
#
#
#
#  ==== processing sample     69
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95489936 1.18764316 0.56698482 ... 0.74038188 0.88126915 1.32194247]
#  weights_push at the beginning
# [0.95716526 1.18195838 0.55749699 ... 0.73523255 0.87543833 1.34241959]
#  weights_push at the beginning
# [0.95751284 1.17618608 0.55160708 ... 0.73337311 0.87073682 1.3550529 ]
#  weights_push at the beginning
# [0.9573286  1.17106317 0.54925693 ... 0.73304784 0.86784977 1.3625628 ]
#
#
#  bootstrap 69 final push weights scaled:
# [0.09652968 0.11771088 0.05536985 ... 0.07397376 0.08735933 0.13797519]
#  ==== processing sample     70
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92068112 1.25253663 0.50796039 ... 0.78510043 0.92419679 1.21905724]
#  weights_push at the beginning
# [0.90488377 1.26392112 0.50426471 ... 0.79014065 0.9399773  1.19720812]
#  weights_push at the beginning
# [0.89403577 1.26631037 0.50761575 ... 0.79331041 0.94872925 1.18447827]
#  weights_push at the beginning
# [0.88615842 1.26767129 0.51317744 ... 0.79594397 0.95471195 1.17502279]
#
#
#  bootstrap 70 final push weights scaled:
# [0.08794966 0.1268505  0.05186301 ... 0.0797287  0.09587872 0.11671198]
#
#
#
#  ==== processing sample     71
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9598431  1.19415879 0.56744346 ... 0.75827242 0.89414476 1.20882577]
#  weights_push at the beginning
# [0.95801289 1.20277667 0.56027306 ... 0.7721432  0.89560813 1.20811063]
#  weights_push at the beginning
# [0.95470345 1.21042454 0.55314161 ... 0.78005695 0.89608085 1.21706804]
#  weights_push at the beginning
# [0.95201801 1.2156555  0.54719496 ... 0.78476287 0.89687012 1.2265869 ]
#
#
#  bootstrap 71 final push weights scaled:
# [0.09384221 0.12043043 0.05356323 ... 0.07779075 0.08864546 0.1220233 ]
#
#
#
#  ==== processing sample     72
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94693544 1.15533742 0.55571162 ... 0.77365271 0.87097915 1.1651902 ]
#  weights_push at the beginning
# [0.94782503 1.14583294 0.55838924 ... 0.77437678 0.86692817 1.15175208]
#  weights_push at the beginning
# [0.94750084 1.13995128 0.56462905 ... 0.77168592 0.86286123 1.15111036]
#  weights_push at the beginning
# [0.94720637 1.13537891 0.57138732 ... 0.76983219 0.85933177 1.15119938]
#
#
#  bootstrap 72 final push weights scaled:
# [0.09500424 0.11354523 0.0579962  ... 0.0771471  0.08592968 0.11545641]
#
#
#
#  ==== processing sample     73
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91166918 1.20560523 0.51962323 ... 0.733675   0.84941493 1.26838906]
#  weights_push at the beginning
# [0.91045058 1.20466632 0.5077844  ... 0.72686254 0.84379682 1.26922465]
#  weights_push at the beginning
# [0.90973168 1.20093118 0.5024941  ... 0.72001736 0.83934634 1.27434246]
#  weights_push at the beginning
# [0.90912877 1.19526575 0.50013824 ... 0.71548074 0.8364036  1.27469664]
#
#
#  bootstrap 73 final push weights scaled:
# [0.09053472 0.11851216 0.04976318 ... 0.0710214  0.08318404 0.12674316]
#
#
#
#  ==== processing sample     74
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92497619 1.15310435 0.55772505 ... 0.79520668 0.91363516 1.24162109]
#  weights_push at the beginning
# [0.90635159 1.14313395 0.55622312 ... 0.80840094 0.92446129 1.25422936]
#  weights_push at the beginning
# [0.89374943 1.1384492  0.55950477 ... 0.81325716 0.93083196 1.26189359]
#  weights_push at the beginning
# [0.88513794 1.13590505 0.56349315 ... 0.81525301 0.9347051  1.26403602]
#
#
#  bootstrap 74 final push weights scaled:
# [0.0882054  0.11382119 0.0569242  ... 0.0818554  0.09400293 0.12686999]
#
#
#
#  ==== processing sample     75
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91604874 1.23752981 0.55797371 ... 0.7010503  0.88722042 1.24326834]
#  weights_push at the beginning
# [0.90833322 1.25254168 0.55190758 ... 0.68936078 0.88755282 1.23905185]
#  weights_push at the beginning
# [0.90495112 1.26082093 0.5475324  ... 0.68691773 0.88400864 1.24353864]
#  weights_push at the beginning
# [0.90331808 1.26618226 0.54492359 ... 0.68819413 0.88123326 1.24966505]
#
#
#  bootstrap 75 final push weights scaled:
# [0.09033292 0.12717927 0.05439489 ... 0.06918865 0.08807389 0.12575368]
#
#
#
#  ==== processing sample     76
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93939099 1.25042366 0.51001611 ... 0.73977346 0.89746613 1.23266378]
#  weights_push at the beginning
# [0.93332406 1.26114106 0.50066335 ... 0.73423606 0.90109077 1.23231252]
#  weights_push at the beginning
# [0.92897334 1.26049637 0.49606864 ... 0.73416775 0.90268673 1.23604148]
#  weights_push at the beginning
# [0.92594466 1.25692423 0.49293663 ... 0.73589606 0.90468846 1.23953294]
#
#
#  bootstrap 76 final push weights scaled:
# [0.09234366 0.12527262 0.049021   ... 0.07376168 0.09069701 0.12431625]
#
#
#
#  ==== processing sample     77
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.916245   1.21590079 0.60401621 ... 0.74392351 0.85940318 1.18336992]
#  weights_push at the beginning
# [0.91152045 1.20640807 0.60644775 ... 0.75225777 0.85092456 1.18919438]
#  weights_push at the beginning
# [0.90976179 1.19517587 0.605286   ... 0.75737652 0.84684408 1.2026618 ]
#  weights_push at the beginning
# [0.90876905 1.18427699 0.60339013 ... 0.76090807 0.84565852 1.21418682]
#
#
#  bootstrap 77 final push weights scaled:
# [0.0917127  0.11865296 0.06073525 ... 0.07713686 0.08542541 0.12358743]
#
#
#
#  ==== processing sample     78
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.90503784 1.23996298 0.59016283 ... 0.74606961 0.90333539 1.28294504]
#  weights_push at the beginning
# [0.89455103 1.25880675 0.59672902 ... 0.73588817 0.90571489 1.30688521]
#  weights_push at the beginning
# [0.88978063 1.27052181 0.59916104 ... 0.72984778 0.90559911 1.32229855]
#  weights_push at the beginning
# [0.88677505 1.27779518 0.59972485 ... 0.72665812 0.90608512 1.33293419]
#
#
#  bootstrap 78 final push weights scaled:
# [0.08744262 0.12681595 0.0592945  ... 0.0716891  0.08970534 0.13266163]
#
#
#
#  ==== processing sample     79
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97013512 1.18897355 0.62574471 ... 0.81000665 0.83276282 1.25185353]
#  weights_push at the beginning
# [0.98423243 1.18407888 0.63343703 ... 0.82054701 0.83012611 1.26673496]
#  weights_push at the beginning
# [0.98771249 1.18093996 0.64158962 ... 0.82331312 0.8331154  1.27868386]
#  weights_push at the beginning
# [0.98857936 1.17823987 0.6504842  ... 0.82458327 0.83689022 1.28713838]
#
#
#  bootstrap 79 final push weights scaled:
# [0.09787927 0.11635675 0.06522245 ... 0.08172012 0.0831803  0.12807624]
#
#
#
#  ==== processing sample     80
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93577914 1.18827139 0.59587073 ... 0.76073625 0.87113771 1.22841012]
#  weights_push at the beginning
# [0.93261086 1.17741984 0.58183948 ... 0.75687659 0.87334797 1.23770321]
#  weights_push at the beginning
# [0.92878656 1.16755506 0.5725169  ... 0.75496609 0.87664698 1.24115715]
#  weights_push at the beginning
# [0.92571208 1.15955404 0.56688755 ... 0.75345883 0.88027492 1.23848018]
#
#
#  bootstrap 80 final push weights scaled:
# [0.09225152 0.11519261 0.05627113 ... 0.07510953 0.08827683 0.12324647]
#
#
#
#  ==== processing sample     81
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.90487357 1.2051265  0.53726311 ... 0.83253929 0.88334354 1.29832258]
#  weights_push at the beginning
# [0.89723857 1.20612534 0.53052219 ... 0.8488177  0.88016168 1.32031078]
#  weights_push at the beginning
# [0.89467253 1.20320857 0.52893501 ... 0.8544423  0.8787827  1.33530692]
#  weights_push at the beginning
# [0.8933796  1.19871612 0.52804612 ... 0.85875512 0.87751992 1.3462877 ]
#
#
#  bootstrap 81 final push weights scaled:
# [0.08976103 0.12006395 0.05299996 ... 0.08677533 0.08810157 0.1362801 ]
#
#
#
#  ==== processing sample     82
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94064497 1.16585058 0.59329153 ... 0.7909835  0.87097821 1.21506413]
#  weights_push at the beginning
# [0.93555122 1.16970695 0.59383627 ... 0.79631565 0.86438054 1.2262603 ]
#  weights_push at the beginning
# [0.93101121 1.1730139  0.59200971 ... 0.79799802 0.86391503 1.23533557]
#  weights_push at the beginning
# [0.92690732 1.1750797  0.59083197 ... 0.79861877 0.86603746 1.24016759]
#
#
#  bootstrap 82 final push weights scaled:
# [0.09182824 0.11700916 0.05873595 ... 0.07943254 0.08643534 0.12367591]
#
#
#
#  ==== processing sample     83
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.88103335 1.23752292 0.56291678 ... 0.76609228 0.8396729  1.23857917]
#  weights_push at the beginning
# [0.8725782  1.23303132 0.56341936 ... 0.76968153 0.83680653 1.24543445]
#  weights_push at the beginning
# [0.8673217  1.22774049 0.56798123 ... 0.771864   0.83793521 1.25667432]
#  weights_push at the beginning
# [0.86322319 1.22319106 0.57318273 ... 0.77384009 0.84009374 1.26422063]
#
#
#  bootstrap 83 final push weights scaled:
# [0.08505329 0.12057629 0.05718513 ... 0.07670577 0.08330461 0.12557861]
#  ==== processing sample     84
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94670406 1.16017655 0.4918104  ... 0.71315499 0.86536216 1.18935117]
#  weights_push at the beginning
# [0.95519611 1.14380156 0.48464449 ... 0.7083507  0.8559981  1.20516511]
#  weights_push at the beginning
# [0.96276703 1.1374741  0.48394884 ... 0.70937316 0.84727276 1.22005321]
#  weights_push at the beginning
# [0.96933302 1.13392922 0.48442686 ... 0.71250672 0.84110157 1.22943618]
#
#
#  bootstrap 84 final push weights scaled:
# [0.09793689 0.11371226 0.04871728 ... 0.07193876 0.08408869 0.12419024]
#
#
#
#  ==== processing sample     85
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97244112 1.21347547 0.62023708 ... 0.81237514 0.8486734  1.2363204 ]
#  weights_push at the beginning
# [0.98783145 1.21017913 0.61640427 ... 0.82467539 0.84103484 1.24999885]
#  weights_push at the beginning
# [0.99370561 1.20226595 0.60931336 ... 0.83196737 0.84192718 1.264113  ]
#  weights_push at the beginning
# [0.99539234 1.19553815 0.60310051 ... 0.83696865 0.84576909 1.27471469]
#
#
#  bootstrap 85 final push weights scaled:
# [0.09896891 0.11840514 0.05946682 ... 0.0835914  0.08459253 0.1275983 ]
#
#
#
#  ==== processing sample     86
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92739597 1.2079951  0.61968259 ... 0.71220366 0.87640508 1.20755573]
#  weights_push at the beginning
# [0.92086697 1.20136897 0.62460982 ... 0.70522452 0.87130012 1.20899117]
#  weights_push at the beginning
# [0.9169457  1.19569586 0.62403453 ... 0.70120253 0.86824268 1.21424415]
#  weights_push at the beginning
# [0.91400424 1.19143462 0.62185451 ... 0.6985141  0.8679621  1.21756744]
#
#
#  bootstrap 86 final push weights scaled:
# [0.08974784 0.1169944  0.06094758 ... 0.06861434 0.08559043 0.12017609]
#
#
#
#  ==== processing sample     87
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93705792 1.20907044 0.59090346 ... 0.80659859 0.89216275 1.19551688]
#  weights_push at the beginning
# [0.93486146 1.20158808 0.59241948 ... 0.8022357  0.88776802 1.18703361]
#  weights_push at the beginning
# [0.93333288 1.19618501 0.59329313 ... 0.79498045 0.88494903 1.1866357 ]
#  weights_push at the beginning
# [0.93183519 1.19490595 0.59343017 ... 0.78937329 0.88319825 1.18691929]
#
#
#  bootstrap 87 final push weights scaled:
# [0.09291219 0.11946749 0.05920193 ... 0.07843375 0.08809956 0.11858558]
#
#
#
#  ==== processing sample     88
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99577847 1.14490425 0.55097957 ... 0.75690163 0.94871166 1.21218385]
#  weights_push at the beginning
# [0.99731439 1.1313847  0.54731064 ... 0.7577703  0.94868931 1.22654054]
#  weights_push at the beginning
# [0.99734502 1.12701407 0.53987508 ... 0.75786851 0.94568741 1.24240228]
#  weights_push at the beginning
# [0.9968624  1.12541276 0.53227758 ... 0.75813724 0.94423588 1.25468087]
#
#
#  bootstrap 88 final push weights scaled:
# [0.10110789 0.11420461 0.05332227 ... 0.07699484 0.09582418 0.12836602]
#
#
#
#  ==== processing sample     89
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95714018 1.17329699 0.52698925 ... 0.75206088 0.91659295 1.25993481]
#  weights_push at the beginning
# [0.95274636 1.18891292 0.51737127 ... 0.75249078 0.92249516 1.27194076]
#  weights_push at the beginning
# [0.94890407 1.19899255 0.50636953 ... 0.75072255 0.92411175 1.28338649]
#  weights_push at the beginning
# [0.94576822 1.20352846 0.49690481 ... 0.74839242 0.9259111  1.29134567]
#
#
#  bootstrap 89 final push weights scaled:
# [0.09499571 0.12142368 0.04929928 ... 0.07515372 0.09355618 0.13065317]
#
#
#
#  ==== processing sample     90
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91298205 1.1528954  0.60833179 ... 0.80679182 0.91025971 1.22056024]
#  weights_push at the beginning
# [0.90324635 1.15504678 0.62916156 ... 0.819317   0.91458281 1.23101289]
#  weights_push at the beginning
# [0.89953178 1.16018204 0.64266725 ... 0.82317677 0.91587704 1.2467641 ]
#  weights_push at the beginning
# [0.89813664 1.16422286 0.65348247 ... 0.82487973 0.9159587  1.25700458]
#
#
#  bootstrap 90 final push weights scaled:
# [0.09060799 0.11781558 0.0668859  ... 0.08335054 0.09236609 0.12749025]
#
#
#
#  ==== processing sample     91
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94237026 1.26886119 0.60893367 ... 0.78423528 0.84201837 1.24808799]
#  weights_push at the beginning
# [0.9424479  1.28990906 0.62223592 ... 0.79563426 0.83154922 1.24779853]
#  weights_push at the beginning
# [0.93813146 1.29993933 0.63379487 ... 0.79902077 0.82711577 1.24722207]
#  weights_push at the beginning
# [0.93276756 1.30555125 0.64396415 ... 0.8006228  0.8247661  1.24770051]
#
#
# ...
# [0.89518741 1.19766946 0.52520947 ... 0.82595278 0.85502467 1.19285353]
#  weights_push at the beginning
# [0.88904347 1.19805858 0.5138701  ... 0.83647802 0.84516563 1.20250867]
#  weights_push at the beginning
# [0.88713341 1.20207048 0.50633936 ... 0.8390172  0.84419626 1.21692741]
#  weights_push at the beginning
# [0.8852528  1.2047791  0.50113017 ... 0.84004552 0.84603053 1.22861266]
#
#
#  bootstrap 474 final push weights scaled:
# [0.08942796 0.12211805 0.05035286 ... 0.08507783 0.08593198 0.12534758]
#
#
#
#  ==== processing sample    475
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98723443 1.16149654 0.52712912 ... 0.79827716 0.86540941 1.29885515]
#  weights_push at the beginning
# [0.9946763  1.15301813 0.52119135 ... 0.81353873 0.86855434 1.33730411]
#  weights_push at the beginning
# [0.99315684 1.1504742  0.518574   ... 0.81863846 0.87206109 1.36072441]
#  weights_push at the beginning
# [0.99063288 1.1487583  0.51737694 ... 0.82140938 0.87455144 1.37538988]
#
#
#  bootstrap 475 final push weights scaled:
# [0.09778599 0.11347512 0.0510998  ... 0.08142542 0.08664469 0.13705849]
#  ==== processing sample    476
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91838309 1.21743275 0.55371795 ... 0.82703991 0.84674781 1.30072203]
#  weights_push at the beginning
# [0.92060374 1.22142681 0.55908247 ... 0.84560257 0.84397831 1.32478207]
#  weights_push at the beginning
# [0.92175035 1.21716481 0.56255246 ... 0.85162144 0.84752328 1.34686152]
#  weights_push at the beginning
# [0.9219991  1.21172984 0.56320578 ... 0.85491458 0.85192384 1.36417989]
#
#
#  bootstrap 476 final push weights scaled:
# [0.09237353 0.12089844 0.0563047  ... 0.08588597 0.08575139 0.13807014]
#
#
#
#  ==== processing sample    477
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97268891 1.23498664 0.57025453 ... 0.78787242 0.86262471 1.17646972]
#  weights_push at the beginning
# [0.98318877 1.23898314 0.57014132 ... 0.79763208 0.85423386 1.19028093]
#  weights_push at the beginning
# [0.98873828 1.23795693 0.56871908 ... 0.79986629 0.84903494 1.20602163]
#  weights_push at the beginning
# [0.99289916 1.2352129  0.56863978 ... 0.80018819 0.84544894 1.21847116]
#
#
#  bootstrap 477 final push weights scaled:
# [0.09954263 0.12307277 0.05689534 ... 0.07990816 0.08418732 0.12278183]
#
#
#
#  ==== processing sample    478
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96757171 1.24286601 0.57862236 ... 0.73087607 0.87060322 1.25128268]
#  weights_push at the beginning
# [0.97004789 1.25057532 0.58544238 ... 0.72400204 0.86987719 1.26580835]
#  weights_push at the beginning
# [0.96896357 1.25153923 0.59259985 ... 0.7210217  0.86755919 1.27091759]
#  weights_push at the beginning
# [0.96836027 1.25150866 0.59892774 ... 0.72080183 0.86548266 1.27077957]
#
#
#  bootstrap 478 final push weights scaled:
# [0.09721656 0.12564891 0.06068265 ... 0.07250254 0.08672342 0.12744796]
#
#
#
#  ==== processing sample    479
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98310128 1.23189008 0.57972806 ... 0.73613435 0.87115728 1.25258219]
#  weights_push at the beginning
# [0.99430257 1.24001613 0.58691915 ... 0.72622334 0.86559373 1.25435725]
#  weights_push at the beginning
# [0.99753943 1.24116406 0.59330377 ... 0.71645388 0.8599482  1.25077019]
#  weights_push at the beginning
# [0.99855663 1.24064566 0.59797692 ... 0.70821568 0.85589016 1.24664451]
#
#
#  bootstrap 479 final push weights scaled:
# [0.09803439 0.12177481 0.05904883 ... 0.06884555 0.08376913 0.12207735]
#
#
#
#  ==== processing sample    480
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96119256 1.21105544 0.52179511 ... 0.72003584 0.8618389  1.34952416]
#  weights_push at the beginning
# [0.96632089 1.22167104 0.51281194 ... 0.71637191 0.85672974 1.3461196 ]
#  weights_push at the beginning
# [0.96581911 1.2240746  0.51133854 ... 0.71193349 0.85259942 1.34336956]
#  weights_push at the beginning
# [0.96404228 1.22270138 0.51187859 ... 0.70846504 0.85020706 1.34347262]
#
#
#  bootstrap 480 final push weights scaled:
# [0.0982141  0.12455113 0.05234228 ... 0.07206635 0.08667282 0.13734549]
#
#
#
#  ==== processing sample    481
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.88890881 1.19643254 0.53145506 ... 0.78688108 0.83976109 1.26275775]
#  weights_push at the beginning
# [0.88314835 1.19708754 0.53231318 ... 0.78265774 0.828254   1.27986673]
#  weights_push at the beginning
# [0.88166028 1.19837775 0.53546128 ... 0.77757842 0.82357123 1.29075153]
#  weights_push at the beginning
# [0.88076043 1.19956721 0.53885745 ... 0.77508079 0.82147705 1.29631911]
#
#
#  bootstrap 481 final push weights scaled:
# [0.08875036 0.1211337  0.05468208 ... 0.0780956  0.08275464 0.13105324]
#
#
#
#  ==== processing sample    482
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99168619 1.24050403 0.56807054 ... 0.77702044 0.87209321 1.19823011]
#  weights_push at the beginning
# [1.00315028 1.26427359 0.57718154 ... 0.78961766 0.86807618 1.20621458]
#  weights_push at the beginning
# [1.00645089 1.2733215  0.57981174 ... 0.79549662 0.86651493 1.21351487]
#  weights_push at the beginning
# [1.00749894 1.27574874 0.58072291 ... 0.7994454  0.86637246 1.2167869 ]
#
#
#  bootstrap 482 final push weights scaled:
# [0.09888088 0.12515378 0.05704105 ... 0.07875538 0.085052   0.11954022]
#
#
#
#  ==== processing sample    483
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98456559 1.22355837 0.53767405 ... 0.79333823 0.88266183 1.24887056]
#  weights_push at the beginning
# [0.9950689  1.22852618 0.54301443 ... 0.79288132 0.87417637 1.25223208]
#  weights_push at the beginning
# [0.99893623 1.22786873 0.54724735 ... 0.79103839 0.86821545 1.26241242]
#  weights_push at the beginning
# [1.00067962 1.22687003 0.54959692 ... 0.79043008 0.8639647  1.27113876]
#
#
#  bootstrap 483 final push weights scaled:
# [0.10057539 0.1231245  0.05530969 ... 0.07938982 0.0864476  0.12838641]
#
#
#
#  ==== processing sample    484
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95882014 1.23791159 0.54177927 ... 0.76119204 0.84884611 1.27244846]
#  weights_push at the beginning
# [0.96969991 1.24691608 0.53815864 ... 0.77166102 0.83895665 1.29721053]
#  weights_push at the beginning
# [0.97473565 1.25074722 0.5369297  ... 0.77521176 0.83266055 1.32031623]
#  weights_push at the beginning
# [0.97772356 1.25197457 0.53709673 ... 0.7779966  0.82859615 1.33687833]
#
#
#  bootstrap 484 final push weights scaled:
# [0.09724684 0.12431152 0.05340052 ... 0.07750916 0.0819638  0.13389243]
#
#
#
#  ==== processing sample    485
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9558969  1.1831496  0.55363363 ... 0.84092713 0.86062235 1.24149382]
#  weights_push at the beginning
# [0.96346185 1.19208449 0.54388988 ... 0.85392542 0.84886267 1.24411658]
#  weights_push at the beginning
# [0.96525727 1.19752488 0.54228204 ... 0.85821772 0.84458259 1.24765912]
#  weights_push at the beginning
# [0.964092   1.1993588  0.54300092 ... 0.86189065 0.8429788  1.25159308]
#
#
#  bootstrap 485 final push weights scaled:
# [0.09674326 0.12068013 0.05471338 ... 0.08709305 0.08477224 0.12639125]
#
#
#
#  ==== processing sample    486
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95524301 1.17108735 0.53589693 ... 0.71977157 0.95870453 1.23344076]
#  weights_push at the beginning
# [0.94480386 1.16944131 0.53599906 ... 0.7090357  0.96413518 1.23094294]
#  weights_push at the beginning
# [0.94170925 1.16533209 0.53638541 ... 0.70350505 0.96156803 1.22910229]
#  weights_push at the beginning
# [0.94161255 1.16067292 0.53565309 ... 0.70122092 0.95937854 1.22669579]
#
#
#  bootstrap 486 final push weights scaled:
# [0.09342809 0.11465816 0.05297158 ... 0.06947058 0.0950158  0.12142343]
#
#
#
#  ==== processing sample    487
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93770397 1.27193114 0.56449116 ... 0.74770047 0.82441971 1.25015208]
#  weights_push at the beginning
# [0.94755595 1.28207028 0.56248374 ... 0.7289344  0.81033517 1.26334613]
#  weights_push at the beginning
# [0.95186447 1.28344845 0.56240727 ... 0.71642459 0.80531907 1.2720968 ]
#  weights_push at the beginning
# [0.95323107 1.28328792 0.5639554  ... 0.70944985 0.80462244 1.27618037]
#
#
#  bootstrap 487 final push weights scaled:
# [0.09494476 0.12779075 0.05637599 ... 0.07031751 0.08032251 0.12739818]
#
#
#
#  ==== processing sample    488
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97418194 1.19024185 0.56864666 ... 0.7545623  0.91893116 1.20325316]
#  weights_push at the beginning
# [0.97178324 1.19151308 0.55897074 ... 0.75511441 0.92220856 1.20071605]
#  weights_push at the beginning
# [0.9677009  1.19407087 0.55259861 ... 0.75583832 0.9206125  1.2054377 ]
#  weights_push at the beginning
# [0.9643366  1.19617642 0.54879076 ... 0.75655561 0.91882672 1.21107581]
#
#
#  bootstrap 488 final push weights scaled:
# [0.09472386 0.11803287 0.05382694 ... 0.0745866  0.09038256 0.11986337]
#
#
#
#  ==== processing sample    489
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91196057 1.1588915  0.56732567 ... 0.7748959  0.8823333  1.31004531]
#  weights_push at the beginning
# [0.90411841 1.15009666 0.57828477 ... 0.77678806 0.8795979  1.34384044]
#  weights_push at the beginning
# [0.8992669  1.1455892  0.58455795 ... 0.77407181 0.87763745 1.37316698]
#  weights_push at the beginning
# [0.89524902 1.14167748 0.58881417 ... 0.77119439 0.87660102 1.39714616]
#
#
#  bootstrap 489 final push weights scaled:
# [0.08854995 0.1130619  0.0587936  ... 0.07634486 0.08700462 0.14074876]
#  ==== processing sample    490
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98578993 1.19016826 0.5188474  ... 0.74608049 0.90879752 1.18189688]
#  weights_push at the beginning
# [0.98988892 1.17798665 0.53078226 ... 0.74288432 0.91389818 1.17461021]
#  weights_push at the beginning
# [0.99039602 1.17093326 0.54269143 ... 0.74086695 0.9136803  1.17858576]
#  weights_push at the beginning
# [0.99126301 1.16696383 0.55133033 ... 0.74090721 0.91264341 1.18378736]
#
#
#  bootstrap 490 final push weights scaled:
# [0.09946036 0.1166753  0.05586868 ... 0.07436438 0.09135582 0.11918481]
#
#
#
#  ==== processing sample    491
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96193481 1.21017072 0.58058442 ... 0.7771368  0.90814539 1.28126777]
#  weights_push at the beginning
# [0.95715959 1.21456926 0.60187944 ... 0.77569243 0.9158739  1.30146692]
#  weights_push at the beginning
# [0.95050223 1.22070422 0.61705537 ... 0.7737206  0.91881531 1.31848851]
#  weights_push at the beginning
# [0.94493861 1.22656511 0.62844402 ... 0.7736091  0.92047884 1.33251176]
#
#
#  bootstrap 491 final push weights scaled:
# [0.09365852 0.12264558 0.06346381 ... 0.07718133 0.09182204 0.13392733]
#
#
#
#  ==== processing sample    492
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96573758 1.24533855 0.54391385 ... 0.75636466 0.87331927 1.22351434]
#  weights_push at the beginning
# [0.98021219 1.26040888 0.53794994 ... 0.74890966 0.86527088 1.19624931]
#  weights_push at the beginning
# [0.98917782 1.26163791 0.53424495 ... 0.74503415 0.85667597 1.1761165 ]
#  weights_push at the beginning
# [0.99589528 1.2588601  0.53218819 ... 0.74316542 0.84927548 1.15931194]
#
#
#  bootstrap 492 final push weights scaled:
# [0.10053921 0.12604248 0.05333121 ... 0.07450798 0.08466261 0.11505912]
#
#
#
#  ==== processing sample    493
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97843754 1.22664003 0.55874548 ... 0.73011975 0.85510574 1.2394512 ]
#  weights_push at the beginning
# [0.99727484 1.23420149 0.57909996 ... 0.71645774 0.83647419 1.2516352 ]
#  weights_push at the beginning
# [1.00907785 1.23333008 0.59043611 ... 0.70607869 0.82333068 1.26757509]
#  weights_push at the beginning
# [1.01703389 1.23024744 0.59678017 ... 0.69868167 0.81481005 1.27993451]
#
#
#  bootstrap 493 final push weights scaled:
# [0.1044079  0.12528421 0.06131314 ... 0.07079907 0.08265484 0.13171166]
#
#
#
#  ==== processing sample    494
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96713585 1.21124437 0.57503544 ... 0.72826865 0.91030696 1.16257969]
#  weights_push at the beginning
# [0.96803989 1.22076151 0.5581741  ... 0.72245937 0.90960639 1.15871286]
#  weights_push at the beginning
# [0.96898653 1.22676084 0.54853135 ... 0.7177039  0.90679298 1.15658887]
#  weights_push at the beginning
# [0.9702122  1.23009099 0.54375565 ... 0.71444737 0.90557755 1.1528644 ]
#
#
#  bootstrap 494 final push weights scaled:
# [0.09739549 0.12354911 0.0543055  ... 0.0714252  0.09082025 0.1152721 ]
#
#
#
#  ==== processing sample    495
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97738319 1.22468679 0.57537345 ... 0.79327203 0.89299925 1.17687329]
#  weights_push at the beginning
# [0.98138827 1.24547581 0.58177036 ... 0.79561995 0.89454929 1.16045394]
#  weights_push at the beginning
# [0.98026208 1.25569196 0.58689497 ... 0.79483162 0.89615745 1.15332079]
#  weights_push at the beginning
# [0.97791739 1.26199185 0.59152102 ... 0.79398825 0.89828116 1.14813299]
#
#
#  bootstrap 495 final push weights scaled:
# [0.10012643 0.13005949 0.06116343 ... 0.08146423 0.09251048 0.11745713]
#
#
#
#  ==== processing sample    496
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96016602 1.24023697 0.54036288 ... 0.83535613 0.85849938 1.24302034]
#  weights_push at the beginning
# [0.96845519 1.25037035 0.53222073 ... 0.86334969 0.85411044 1.25364676]
#  weights_push at the beginning
# [0.96949061 1.25343043 0.529604   ... 0.87517306 0.85677883 1.26985583]
#  weights_push at the beginning
# [0.96780517 1.25437578 0.52882473 ... 0.88143316 0.8610474  1.28532826]
#
#
#  bootstrap 496 final push weights scaled:
# [0.09620301 0.12502884 0.05266576 ... 0.08818821 0.08621853 0.12953635]
#
#
#
#  ==== processing sample    497
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.01127512 1.18029356 0.5148162  ... 0.83181172 0.85053434 1.31621549]
#  weights_push at the beginning
# [1.03908588 1.18317491 0.52581589 ... 0.84203815 0.82655744 1.34507807]
#  weights_push at the beginning
# [1.05590712 1.18358857 0.53003954 ... 0.84281597 0.81260687 1.36002626]
#  weights_push at the beginning
# [1.06753258 1.18211489 0.53120648 ... 0.84227263 0.80294083 1.36844847]
#
#
#  bootstrap 497 final push weights scaled:
# [0.10610182 0.11627647 0.05232735 ... 0.08293565 0.07842139 0.13542945]
#
#
#
#  ==== processing sample    498
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94598797 1.2463076  0.60766647 ... 0.74944925 0.89115622 1.24401244]
#  weights_push at the beginning
# [0.93867778 1.26317725 0.60399686 ... 0.75472485 0.90481051 1.25185993]
#  weights_push at the beginning
# [0.93019565 1.26980709 0.60072377 ... 0.75965109 0.91341167 1.25651615]
#  weights_push at the beginning
# [0.92348942 1.27239286 0.5991442  ... 0.76427168 0.92031357 1.26009341]
#
#
#  bootstrap 498 final push weights scaled:
# [0.0920381  0.1276266  0.06000252 ... 0.07705356 0.09285022 0.12666446]
#
#
#
#  ==== processing sample    499
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92814021 1.27808892 0.5684532  ... 0.77132114 0.88770582 1.24147554]
#  weights_push at the beginning
# [0.92014628 1.30250952 0.56998483 ... 0.77037846 0.88762718 1.24665378]
#  weights_push at the beginning
# [0.91455005 1.30963598 0.56527952 ... 0.76859639 0.88568827 1.24743925]
#  weights_push at the beginning
# [0.9103729  1.31090451 0.56042003 ... 0.7673346  0.88379751 1.24614858]
#
#
#  bootstrap 499 final push weights scaled:
# [0.09045346 0.13070525 0.05546216 ... 0.07644898 0.08800939 0.12419458]
# CPU times: user 60 s, sys: 741 ms, total: 1min
# Wall time: 1min

# %%
print('Done')
# Out:
# Done
