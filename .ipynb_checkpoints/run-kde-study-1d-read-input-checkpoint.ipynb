# %%
import matplotlib.pyplot as plt
import numpy as np

import time

import sys
import os

from datetime import datetime
import subprocess

from os.path import exists
from pathlib import Path
datadir = Path("/pscratch/sd/k/kdesai/unbinned-inference-paper")

# %% [markdown]
# ## Set model and resolution parameters

# %%
ndim = 1
of_niter = 5

#smearing_val = 0.0000
#smearing_val = 0.1184
#smearing_val = 0.2368
#smearing_val = 0.3553
#smearing_val = 0.5132
smearing_val = 0.7500


input_dir = datadir/f'input-samples/input-samples-smearing-{smearing_val:6.4f}-v1b'
output_dir = datadir/f'output-run-kde-study-1d-read-input-v0a-smearing-{smearing_val:6.4f}'
#-- parameters for simple pdf

hist_low = -10.
hist_high = 10.
hist_nbins = 1000
hist_binwidth = (hist_high - hist_low) / hist_nbins
window_dx = 0.10
window_nbins = int(window_dx / hist_binwidth )
print(f'{window_nbins = }')

hist_pars = {}
hist_pars['low']  = hist_low
hist_pars['high'] = hist_high
hist_pars['nbins'] = hist_nbins
hist_pars['binwidth'] = hist_binwidth
hist_pars['window_dx'] = window_dx
hist_pars['window_nbins'] = window_nbins

hist_pars
# Out:
# window_nbins = 5
# {'low': -10.0,
#  'high': 10.0,
#  'nbins': 1000,
#  'binwidth': 0.02,
#  'window_dx': 0.1,
#  'window_nbins': 5}

# %%
output_dir.mkdir(exist_ok = True)

# %%
config_file = open(output_dir/'config.txt', 'w')

config_file.write(f'input_dir {input_dir}\n')
config_file.write(f'of_niter {of_niter}\n')
config_file.write(f'hist pars {hist_pars}n')
config_file.close()

print(subprocess.getoutput(f'cat {output_dir}/config.txt'))
# Out:
# input_dir /pscratch/sd/k/kdesai/unbinned-inference-paper/input-samples/input-samples-smearing-0.7500-v1b
# of_niter 5
# hist pars {'low': -10.0, 'high': 10.0, 'nbins': 1000, 'binwidth': 0.02, 'window_dx': 0.1, 'window_nbins': 5}n

# %% [markdown]
# ## Count the number of samples in the input directory and read in the first one

# %%
n_samples = 0

for fi in range(5000) :
    
    fname = '%s/sample-%04d.npz' % (input_dir, fi)
    
    if exists(fname) :
        n_samples = n_samples + 1
        
print(f"{n_samples = })
# Out:
#  Found 500 samples.

# %%
def read_sample( input_dir, sample_index ) :
    
    with np.load( '%s/sample-%04d.npz' % (input_dir, sample_index) ) as f :
        #read_true_pts = np.load(f)
        read_true_det_pts = f['data']
        read_train_pts = f['gen']
        read_train_det_pts = f['sim']

    ngen_true = len(read_true_det_pts)
    ngen_train = len(read_train_pts)

    this_ngen_true = ngen_true

    true_det_pts = np.empty(shape=(ngen_true,1) )
    true_det_pts[:,0] = read_true_det_pts

    train_pts = np.zeros( shape=(ngen_train,1) )
    train_pts[:,0] = read_train_pts

    train_det_pts = np.zeros( shape=(ngen_train,1) )
    train_det_pts[:,0] = read_train_det_pts
    
    return_dict = {}
    return_dict['true_det_pts'] = true_det_pts
    return_dict['train_pts'] = train_pts
    return_dict['train_det_pts'] = train_det_pts
    return_dict['ngen_true'] = ngen_true
    return_dict['ngen_train'] = ngen_train
    
    return return_dict

# %%
rd = read_sample( input_dir, 0 )

ngen_true = rd['ngen_true']
ngen_train = rd['ngen_train']

true_det_pts = rd['true_det_pts']
train_pts = rd['train_pts']
train_det_pts = rd['train_det_pts']

print('true_pts:   ngen_true  = %8d,  shape = %s' % (ngen_true, str(true_det_pts.shape)) )
print('train_pts:  ngen_train = %8d,  shape = %s' % (ngen_train, str(train_pts.shape)) )
# Out:
#   true_pts:   ngen_true  =    10039,  shape = (10039, 1)
#   train_pts:  ngen_train =   100000,  shape = (100000, 1)

# %% [markdown]
# ## Function that estimates the pdf from a histogram (multi-bin sum)

# %%
#-- computes pdf2/pdf1 at location of points1
#
#    for OmniFold step 1, points2 is the data, points1 is the MC
#

def pdf_ratio_from_hist( points1, points2, weights1, weights2, hist_pars, verbose=0 ) :
    
    ndim = points1.shape[1]
    
    if ndim > 1 :
        print('\n\n *** Only 1D supported for now.\n\n')
        sys.exit()
        
    hist_low = hist_pars['low']
    hist_high = hist_pars['high']
    hist_nbins = hist_pars['nbins']
    hist_binwidth = hist_pars['binwidth']
    
    
    nph1 = np.histogram( points1[:,0], hist_nbins, range=[hist_low, hist_high], weights=weights1 )
    nph2 = np.histogram( points2[:,0], hist_nbins, range=[hist_low, hist_high], weights=weights2 )
    
    hist_pdf1 = np.zeros(hist_nbins)
    hist_pdf2 = np.zeros(hist_nbins)

    for bi in range( hist_nbins ) :
        bilow = bi - window_nbins
        bihigh = bi + window_nbins
        if bilow < 0 : bilow = 0
        if bihigh >= hist_nbins : bihigh = hist_nbins-1

        hist_pdf1[bi] = np.sum( nph1[0][bilow: bihigh] )
        hist_pdf2[bi] = np.sum( nph2[0][bilow: bihigh] )
    
    hist_pdf1_norm = hist_pdf1 / np.sum(hist_pdf1)
    hist_pdf2_norm = hist_pdf2 / np.sum(hist_pdf2)
    
    hist_bin_indices1 = np.array(   ( (points1[:,0] - hist_low) / hist_binwidth ),   dtype=int )
    
    points1_pdf1_val = hist_pdf1_norm[ hist_bin_indices1 ]
    points1_pdf2_val = hist_pdf2_norm[ hist_bin_indices1 ]
    
    points1_pdf1_val = np.clip( points1_pdf1_val, 1.e-10, 1.e10)
    points1_pdf2_val = np.clip( points1_pdf2_val, 1.e-10, 1.e10)
    
    pdf_ratio = points1_pdf2_val / points1_pdf1_val
    
    return pdf_ratio

# %% [markdown]
# ## Define OmniFold implementation with Simple pdf

# %%
def hist_pdf_omnifold1a( theta0, theta_unknown_S, iterations, verbose=0 ) :
    
    weights = np.empty(shape=(iterations, 2, len(theta0)))
    # shape = (iteration, step, event)
    push_weights_for_output = np.empty(shape=(iterations, len(theta0)))

    theta0_G = theta0[:,0]
    theta0_S = theta0[:,1]

    ngen_train = len(theta0)
    of_ngen_true  = len(theta_unknown_S)
    ndim = theta0_G.shape[1]

    labels0 = np.zeros(len(theta0))
    labels_unknown = np.ones(len(theta_unknown_S))
    labels_unknown_step2 = np.ones(len(theta0_G))


    neval_train = ngen_train
    neval_true  = of_ngen_true


    if verbose :
        print("\n\n")
        print("  ======== simple_pdf2b\n\n")
        print("  shape of theta0_S : %s" % str(np.shape(theta0_S)) )
        print("  shape of theta0_G : %s" % str(np.shape(theta0_G)) )
        print("  shape of theta_unknown_S : %s" % str(np.shape(theta_unknown_S)) )
        print("\n  iterations = %d\n" % iterations )
        print("  ndim : %d" % ndim )
        print("  neval_train : %d" % neval_train )
        print("  neval_true  : %d" % neval_true )
        print("\n\n")

    # initial iterative weights are ones
    weights_pull = np.ones(len(theta0_S))
    weights_push = np.ones(len(theta0_S))


    sample_norm_sf = ( (1.*neval_train)/(1.*neval_true) ) *  ( (1.*of_ngen_true)/(1.*ngen_train) )
    
    
    if verbose :
        print('\n\n Calculating model pars for data or true (theta_unknown_S)')
        
    

    
    
    
    
    
    
    return_dict = {}
    
    for i in range(iterations):
    
        if (verbose>0):
            print("\nITERATION: {}\n".format(i + 1))
            
        if (verbose>0):
            print("   -- ITERATION %d  STEP 1\n" % (i+1) )
            
        print(" weights_push at the beginning")
        print( weights_push )

        


        pdf_ratio_step1 = pdf_ratio_from_hist( theta0_S, 
                                              theta_unknown_S, 
                                              weights_push, 
                                              np.ones( of_ngen_true ),
                                              hist_pars
                                             )
        if verbose>0 :
            print(' pdf_ratio_step1:  shape %s ' % str(pdf_ratio_step1.shape))
            print(pdf_ratio_step1)
        
        
        step1_output_weights = sample_norm_sf * pdf_ratio_step1

        weights_pull = weights_push * step1_output_weights
        
        if verbose>0 :
            print("  iter %d, step1_output_weights:  shape %s" % (i+1, str(step1_output_weights.shape)))
            print(step1_output_weights)


        weights[i, :1, :] = step1_output_weights


            
            

        if (verbose>0):
            print("\n   -- ITERATION %d  STEP 2\n" % (i+1) )
            
       

        
        pdf_ratio_step2 = pdf_ratio_from_hist( theta0_G, 
                                              theta0_G, 
                                              weights_push, 
                                              weights_pull,
                                              hist_pars
                                             )
        
        
        step2_output_weights = pdf_ratio_step2
        
        weights_push = weights_push * step2_output_weights
        
        push_weights_for_output[i] = weights_push
        
        weights[i, 1:2, :] = step2_output_weights
        
        if verbose>0 :
           print("  iter %d, step2_output_weights:" % (i+1))
           print(step2_output_weights)
        
    return_dict["weights"] = weights

    return_dict["push_weights"] = push_weights_for_output

    return_dict["final_push_weights"] = weights_push

    return return_dict

# %%
train_both = np.stack([train_pts, train_det_pts], axis=1)

# %%
rd = hist_pdf_omnifold1a( train_both, true_det_pts, of_niter, 1 )
# Out:
#   ======== simple_pdf2b
#
#
#   shape of theta0_S : (100000, 1)
#   shape of theta0_G : (100000, 1)
#   shape of theta_unknown_S : (10039, 1)
#
#   iterations = 5
#
#   ndim : 1
#   neval_train : 100000
#   neval_true  : 10039
#
#
#
#
#
#  Calculating model pars for data or true (theta_unknown_S)
#
# ITERATION: 1
#
#    -- ITERATION 1  STEP 1
#
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  pdf_ratio_step1:  shape (100000,)
# [0.96093515 1.12831711 0.75943138 ... 0.7784402  0.98322818 1.19473172]
#   iter 1, step1_output_weights:  shape (100000,)
# [0.96093515 1.12831711 0.75943138 ... 0.7784402  0.98322818 1.19473172]
#
#    -- ITERATION 1  STEP 2
#
#   iter 1, step2_output_weights:
# [0.96700242 1.09774658 0.78820264 ... 0.87638346 0.93535992 1.14803855]
#
# ITERATION: 2
#
#    -- ITERATION 2  STEP 1
#
#  weights_push at the beginning
# [0.96700242 1.09774658 0.78820264 ... 0.87638346 0.93535992 1.14803855]
#  pdf_ratio_step1:  shape (100000,)
# [0.96734492 1.08340218 0.87421283 ... 0.90218891 0.97855361 1.08045117]
#   iter 2, step1_output_weights:  shape (100000,)
# [0.96734492 1.08340218 0.87421283 ... 0.90218891 0.97855361 1.08045117]
#
#    -- ITERATION 2  STEP 2
#
#   iter 2, step2_output_weights:
# [0.9863875  1.0382245  0.89732762 ... 0.94476818 0.97245421 1.04917858]
#
# ITERATION: 3
#
#    -- ITERATION 3  STEP 1
#
#  weights_push at the beginning
# [0.95383909 1.1397074  0.70727599 ... 0.82797921 0.9095947  1.20449745]
#  pdf_ratio_step1:  shape (100000,)
# [0.96857308 1.06497646 0.92735684 ... 0.96003509 0.97532565 1.04272422]
#   iter 3, step1_output_weights:  shape (100000,)
# [0.96857308 1.06497646 0.92735684 ... 0.96003509 0.97532565 1.04272422]
#
#    -- ITERATION 3  STEP 2
#
#   iter 3, step2_output_weights:
# [0.99546998 1.01753793 0.95107231 ... 0.97657495 0.98937582 1.01876129]
#
# ITERATION: 4
#
#    -- ITERATION 4  STEP 1
#
#  weights_push at the beginning
# [0.94951819 1.15969551 0.67267062 ... 0.80858376 0.899931   1.22709538]
#  pdf_ratio_step1:  shape (100000,)
# [0.96743481 1.05566129 0.95123536 ... 0.98626442 0.97228685 1.02850226]
#   iter 4, step1_output_weights:  shape (100000,)
# [0.96743481 1.05566129 0.95123536 ... 0.98626442 0.97228685 1.02850226]
#
#    -- ITERATION 4  STEP 2
#
#   iter 4, step2_output_weights:
# [0.99856345 1.00876714 0.97669507 ... 0.99052775 0.99608525 1.00862496]
#
# ITERATION: 5
#
#    -- ITERATION 5  STEP 1
#
#  weights_push at the beginning
# [0.94815416 1.16986273 0.65699407 ... 0.80092465 0.896408   1.23767903]
#  pdf_ratio_step1:  shape (100000,)
# [0.96597178 1.05053608 0.96203199 ... 0.99824041 0.96996103 1.02263161]
#   iter 5, step1_output_weights:  shape (100000,)
# [0.96597178 1.05053608 0.96203199 ... 0.99824041 0.96996103 1.02263161]
#
#    -- ITERATION 5  STEP 2
#
#   iter 5, step2_output_weights:
# [0.99930714 1.00459835 0.9891515  ... 0.99665533 0.99856728 1.00532574]

# %%
of_weights = rd["weights"]

mc_weight_sf = (1.*len(true_det_pts))/(1.*len(train_both))

push_weights = rd["push_weights"]
push_weights_scaled = np.copy( push_weights )
push_weights_scaled = mc_weight_sf * push_weights

final_push_weights = rd["final_push_weights"]
final_push_weights_scaled = np.copy(final_push_weights)
final_push_weights_scaled = mc_weight_sf * final_push_weights

with open( '%s/omnifold-output-weights.npy' % output_dir, 'wb') as f :
    np.save(f, final_push_weights_scaled)

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
            
            thisax.hist( train_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )            
            ###hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            #hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

    else :
        
        for di in range(ndim) :

            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
                
            hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )            
            ###hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        
            #hist_data_truth[ofi,di],_,_ =         thisax.hist( true_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        

    

 
    if ndim > 1 :
        thisax = ax[ofi][0]
    else :
        thisax = ax[ofi]
        
    thisax.set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show()

# %%
hist_data_diff = hist_data_mc_ofweighted - hist_data_truth
hist_data_diff2 = hist_data_diff * hist_data_diff

hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        hist_data_sum_diff2[ofi,di] = np.sum( hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        if ndim > 1 :
            thisax = ax[di]
        else :
            thisax = ax
        thisax.plot(hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(hist_data_diff[ofi,di])
    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( hist_data_sum_diff2)
ax[1].plot( hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show()

# %%
fig,ax = plt.subplots( of_niter, 4, figsize=(24,7*of_niter))

hmin=-6
hmax=6
hbins=40

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

for ofi in range(0,of_niter) :

    ax[ofi][0].hist( of_weights[ofi,0,:], bins=hbins, range=[0.,1.5] )
    
    ax[ofi][1].hist( of_weights[ofi,1,:], bins=hbins, range=[0.,1.5] )
    
    ax[ofi][2].hist( push_weights[ofi,:], bins=hbins, range=[0.,2.0] )
    #ax[ofi][2].hist( calc_weight, bins=hbins, range=[0.,2.0], alpha=0.5 )
    
    
    ax[ofi][3].hist2d( of_weights[ofi,0,:], of_weights[ofi,1,:], bins=[hbins,hbins] )
    
    ax[ofi][0].set_xlabel( 'step 1 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][1].set_xlabel( 'step 2 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][3].set_xlabel( 'step 1 likelihood ratio', fontsize=lfontsize )
    ax[ofi][3].set_ylabel( 'step 2 likelihood ratio', fontsize=lfontsize )
    
    ax[ofi][2].set_xlabel( 'Iteration %d push weight' % ofi, fontsize=lfontsize )
    
    ax[ofi][0].set_title('Iteration %d' % ofi, fontsize=lfontsize )
    
    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(8*2,5))

hbins=80

final_push_weights_scaled = np.clip( final_push_weights_scaled, 1e-11, 1e11)

ax[0].hist( final_push_weights_scaled, bins=hbins)
ax[0].set_yscale('log')

ax[1].hist( np.log10(final_push_weights_scaled), bins=hbins)

plt.show()

# %%
fig,ax = plt.subplots( of_niter, ndim, figsize=(18,4*of_niter))

hmin=-6
hmax=6
hbins=40

det_hist_data_mc_ofweighted = np.zeros( shape=(of_niter,ndim,hbins))
det_hist_data_truth         = np.zeros( shape=(of_niter,ndim,hbins))

lfontsize = 17

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

do_renorm = True


for ofi in range(0,of_niter) :

    if do_renorm :
        
        for di in range(ndim) :
            
            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
            
            thisax.hist( train_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='train particle' )
            det_hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_det_pts[:,di], weights=push_weights[ofi], bins=hbins, density=True, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts[:,di], bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            #det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, density=True, range=[hmin,hmax], label='true particle', histtype='step', color='black' )

            
    else :
        
        for di in range(ndim) :

            if ndim > 1 :
                thisax = ax[ofi][di]
            else :
                thisax = ax[ofi]
        
            det_hist_data_mc_ofweighted[ofi,di],_,_ = thisax.hist( train_det_pts[:,di], weights=push_weights_scaled[ofi], bins=hbins, range=[hmin,hmax], label='OF weighted particle', alpha=0.5 )
            det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts[:,di], bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
            
            #det_hist_data_truth[ofi,di],_,_ =         thisax.hist( true_det_pts10x[:,di], weights=true_pts10x_weights, bins=hbins, range=[hmin,hmax], label='true particle', histtype='step', color='black' )
        

    

    
    if ndim > 1 :
        thisax = ax[ofi][0]
    else :
        thisax = ax[ofi]
    
    thisax.set_title('Iteration %d' % ofi, fontsize=lfontsize )



plt.show()

# %%
det_hist_data_diff = det_hist_data_mc_ofweighted - det_hist_data_truth
det_hist_data_diff2 = det_hist_data_diff * det_hist_data_diff

det_hist_data_sum_diff2 = np.zeros( shape=(of_niter,ndim))

for ofi in range( of_niter ) :
    for di in range( ndim ) :
        det_hist_data_sum_diff2[ofi,di] = np.sum( det_hist_data_diff2[ofi,di])

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

for ofi in range(of_niter) :
    for di in range( ndim ) :
        if ndim > 1 :
            thisax = ax[di]
        else :
            thisax = ax
        thisax.plot(det_hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, ndim, figsize=(18,5))

ofi = 0
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(det_hist_data_diff[ofi,di])

ofi = of_niter-1
for di in range( ndim ) :
    if ndim > 1 :
        thisax = ax[di]
    else :
        thisax = ax
    thisax.plot(det_hist_data_diff[ofi,di])

    
plt.show()

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,5))
ax[0].plot( det_hist_data_sum_diff2)
ax[1].plot( det_hist_data_sum_diff2)
ax[1].set_yscale('log')
plt.show()

# %%
step1_mean = np.zeros( of_niter )
step1_rms = np.zeros( of_niter )

step2_mean = np.zeros( of_niter )
step2_rms = np.zeros( of_niter )

iter_val = np.zeros( of_niter )

for ofi in range( of_niter ) :
    
    iter_val[ofi] = ofi
    
    step1_mean[ofi] = np.mean( of_weights[ofi,0,:] )
    step1_rms[ofi] = np.sqrt( np.var( of_weights[ofi,0,:]))
    
    step2_mean[ofi] = np.mean( of_weights[ofi,1,:] )
    step2_rms[ofi] = np.sqrt( np.var( of_weights[ofi,1,:]))
    
    print("  iter %2d : step 1 mean  %.3f  rms %.3f      step 2 mean  %.3f  rms %.3f" % 
          (ofi, step1_mean[ofi], step1_rms[ofi], step2_mean[ofi], step2_rms[ofi]) )
# Out:
#   iter  0 : step 1 mean  0.999  rms 0.169      step 2 mean  0.999  rms 0.123
#   iter  1 : step 1 mean  0.993  rms 0.099      step 2 mean  0.993  rms 0.058
#   iter  2 : step 1 mean  0.995  rms 0.079      step 2 mean  0.995  rms 0.031
#   iter  3 : step 1 mean  0.997  rms 0.075      step 2 mean  0.997  rms 0.020
#   iter  4 : step 1 mean  0.998  rms 0.075      step 2 mean  0.998  rms 0.015

# %%
fig,ax = plt.subplots( 1, 2, figsize=(18,7))

ax[0].plot( iter_val, step1_mean )
ax[0].plot( iter_val, step2_mean )
ax[0].set_ylim( 0.80, 1.05)

ax[1].plot( iter_val, step1_rms )
ax[1].plot( iter_val, step2_rms )
ax[1].set_ylim( 0, 1.1*np.max(step1_rms))


plt.show()

# %%
verbose = False



import gc

# %%
# %%time

rng = np.random.default_rng()

for bi in range(0,n_samples) :

    print('\n\n\n ==== processing sample %6d' % bi )
        
    rd = read_sample( input_dir, bi )

    ngen_true = rd['ngen_true']
    ngen_train = rd['ngen_train']

    #true_pts = rd['true_pts']
    true_det_pts = rd['true_det_pts']
    train_pts = rd['train_pts']
    train_det_pts = rd['train_det_pts']
    
    train_both = np.stack([train_pts, train_det_pts], axis=1)
        
    
    rd = hist_pdf_omnifold1a( train_both, true_det_pts, of_niter, 0 )
    
    
    
    mc_weight_sf = (1.*len(true_det_pts))/(1.*len(train_both))



    boot_final_push_weights = rd["final_push_weights"]
    boot_final_push_weights_scaled = boot_final_push_weights
    boot_final_push_weights_scaled = mc_weight_sf * boot_final_push_weights
    
    print("\n\n bootstrap %d final push weights scaled:" % bi)
    print( boot_final_push_weights_scaled )

     
    with open( '%s/bootstrap-weights-%03d.npy' % ( output_dir, bi ), 'wb' ) as f :
        np.save( f, boot_final_push_weights_scaled )
        
    del boot_final_push_weights_scaled
    del rd
    gc.collect()
# Out:
#  ==== processing sample      0
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96700242 1.09774658 0.78820264 ... 0.87638346 0.93535992 1.14803855]
#  weights_push at the beginning
# [0.95383909 1.1397074  0.70727599 ... 0.82797921 0.9095947  1.20449745]
#  weights_push at the beginning
# [0.94951819 1.15969551 0.67267062 ... 0.80858376 0.899931   1.22709538]
#  weights_push at the beginning
# [0.94815416 1.16986273 0.65699407 ... 0.80092465 0.896408   1.23767903]
#
#
#  bootstrap 0 final push weights scaled:
# [0.09511925 0.11798256 0.06524012 ... 0.0801359  0.08986147 0.12491232]
#
#
#
#  ==== processing sample      1
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98399738 1.09104909 0.77629134 ... 0.88760845 0.95318686 1.12275412]
#  weights_push at the beginning
# [0.98270136 1.12923848 0.68365328 ... 0.84327509 0.93825089 1.16257316]
#  weights_push at the beginning
# [0.98739019 1.14659598 0.63873766 ... 0.82582037 0.93628912 1.17358374]
#  weights_push at the beginning
# [0.99332437 1.15468704 0.6143038  ... 0.81951193 0.93886429 1.17538356]
#
#
#  bootstrap 1 final push weights scaled:
# [0.10095929 0.1170865  0.06063099 ... 0.0826898  0.0952877  0.11875615]
#
#
#
#  ==== processing sample      2
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95950526 1.10493363 0.77884218 ... 0.86801713 0.93143503 1.15669066]
#  weights_push at the beginning
# [0.94305412 1.15053163 0.69623385 ... 0.81586784 0.90390882 1.21458727]
#  weights_push at the beginning
# [0.93747781 1.17283335 0.66206995 ... 0.7944003  0.89363591 1.23527844]
#  weights_push at the beginning
# [0.93582754 1.18478634 0.6474956  ... 0.78528822 0.89004831 1.24244525]
#
#
#  bootstrap 2 final push weights scaled:
# [0.09290129 0.11836267 0.0637324  ... 0.07760789 0.08829237 0.12364354]
#
#
#
#  ==== processing sample      3
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96723411 1.10375303 0.76629619 ... 0.86764304 0.93471496 1.14813967]
#  weights_push at the beginning
# [0.95586833 1.14890968 0.67358169 ... 0.81398856 0.90992133 1.19859863]
#  weights_push at the beginning
# [0.95404391 1.1710108  0.63056462 ... 0.79099723 0.90211007 1.21370505]
#  weights_push at the beginning
# [0.95532881 1.18270433 0.60803716 ... 0.78061775 0.90081391 1.21674723]
#
#
#  bootstrap 3 final push weights scaled:
# [0.09574411 0.11894918 0.05951333 ... 0.07759221 0.09020814 0.12163893]
#
#
#
#  ==== processing sample      4
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97241159 1.10990555 0.75721697 ... 0.85828839 0.9335249  1.13966373]
#  weights_push at the beginning
# [0.96251135 1.15981222 0.66201449 ... 0.79820554 0.90572973 1.18299665]
#  weights_push at the beginning
# [0.9608749  1.18544489 0.6191692  ... 0.77022018 0.89444183 1.19197752]
#  weights_push at the beginning
# [0.96187441 1.19977164 0.59828557 ... 0.7557659  0.88961186 1.18953709]
#
#
#  bootstrap 4 final push weights scaled:
# [0.0978264  0.12270471 0.05969402 ... 0.07590784 0.09009947 0.12022748]
#
#
#
#  ==== processing sample      5
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96366849 1.11249396 0.76637916 ... 0.86233126 0.9260918  1.14465282]
#  weights_push at the beginning
# [0.94847445 1.16309178 0.67694956 ... 0.80618619 0.89460218 1.19224878]
#  weights_push at the beginning
# [0.94306074 1.18878943 0.63826548 ... 0.78190104 0.88110936 1.20448977]
#  weights_push at the beginning
# [0.94106683 1.20307374 0.6205053  ... 0.77085338 0.87475733 1.2044769 ]
#
#
#  bootstrap 5 final push weights scaled:
# [0.09273049 0.11952738 0.06041414 ... 0.07553571 0.08594539 0.11844339]
#
#
#
#  ==== processing sample      6
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96441482 1.11122607 0.74591958 ... 0.85297079 0.92815467 1.15963655]
#  weights_push at the beginning
# [0.95113589 1.1593399  0.64749856 ... 0.79217234 0.89895959 1.21427474]
#  weights_push at the beginning
# [0.94845154 1.18266889 0.60323939 ... 0.76490063 0.88809282 1.22986902]
#  weights_push at the beginning
# [0.94946451 1.19478245 0.58130456 ... 0.75147197 0.88439451 1.23156418]
#
#
#  bootstrap 6 final push weights scaled:
# [0.09638658 0.12170722 0.05772337 ... 0.07538905 0.08949485 0.12448046]
#
#
#
#  ==== processing sample      7
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96566262 1.11401289 0.74517697 ... 0.85334662 0.92654829 1.16351085]
#  weights_push at the beginning
# [0.95216768 1.16414946 0.64519953 ... 0.79262245 0.89601434 1.22291711]
#  weights_push at the beginning
# [0.94870698 1.18893025 0.59883574 ... 0.76556373 0.88404181 1.24379654]
#  weights_push at the beginning
# [0.94877849 1.20208342 0.57433217 ... 0.75254653 0.87948251 1.25104031]
#
#
#  bootstrap 7 final push weights scaled:
# [0.09537842 0.12144441 0.05622147 ... 0.07489768 0.08815489 0.1259127 ]
#
#
#
#  ==== processing sample      8
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9639535  1.11107094 0.74939776 ... 0.85698302 0.92871026 1.15837944]
#  weights_push at the beginning
# [0.95034443 1.159749   0.65227531 ... 0.79896084 0.89991417 1.21373272]
#  weights_push at the beginning
# [0.94737988 1.18374124 0.6086175  ... 0.774117   0.88940953 1.2312669 ]
#  weights_push at the beginning
# [0.94820928 1.19647768 0.58695477 ... 0.76304007 0.88613473 1.23560007]
#
#
#  bootstrap 8 final push weights scaled:
# [0.0947423  0.12002146 0.05739082 ... 0.07559573 0.08831607 0.12322918]
#
#
#
#  ==== processing sample      9
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97010844 1.10050851 0.76905141 ... 0.86894196 0.935434   1.1393126 ]
#  weights_push at the beginning
# [0.96081727 1.1444838  0.67730604 ... 0.81510253 0.90994337 1.18509727]
#  weights_push at the beginning
# [0.96059786 1.16605315 0.63499768 ... 0.79130632 0.90091958 1.19706584]
#  weights_push at the beginning
# [0.96329001 1.17746488 0.61322633 ... 0.77992479 0.89827258 1.19752347]
#
#
#  bootstrap 9 final push weights scaled:
# [0.09899199 0.12124951 0.06155959 ... 0.07927813 0.09197332 0.12234593]
#
#
#
#  ==== processing sample     10
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95440575 1.11501717 0.75111389 ... 0.85414207 0.91875729 1.17424789]
#  weights_push at the beginning
# [0.93592415 1.16414334 0.65692045 ... 0.79822222 0.88615458 1.23774847]
#  weights_push at the beginning
# [0.93019567 1.18812998 0.61590616 ... 0.77701014 0.87420684 1.25951101]
#  weights_push at the beginning
# [0.92903275 1.20107222 0.59634166 ... 0.76986585 0.87024495 1.26612355]
#
#
#  bootstrap 10 final push weights scaled:
# [0.0925422  0.12038715 0.0584147  ... 0.07656491 0.08657318 0.12624996]
#
#
#
#  ==== processing sample     11
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96082259 1.10147787 0.78143256 ... 0.8653756  0.92764363 1.15170265]
#  weights_push at the beginning
# [0.94409638 1.1453906  0.69766153 ... 0.81127583 0.89678015 1.20681269]
#  weights_push at the beginning
# [0.93769521 1.16680432 0.66115388 ... 0.78821496 0.88338079 1.22545851]
#  weights_push at the beginning
# [0.93501238 1.17823236 0.64366909 ... 0.77772981 0.87678941 1.23083398]
#
#
#  bootstrap 11 final push weights scaled:
# [0.09381064 0.11907315 0.06377854 ... 0.07764815 0.08771548 0.12377757]
#
#
#
#  ==== processing sample     12
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97525604 1.10108285 0.76448991 ... 0.87385979 0.94342819 1.13968569]
#  weights_push at the beginning
# [0.9690008  1.14464285 0.66923716 ... 0.82170392 0.92248734 1.18839405]
#  weights_push at the beginning
# [0.97096199 1.16527733 0.62414058 ... 0.79876285 0.91653557 1.20433258]
#  weights_push at the beginning
# [0.97540829 1.17553017 0.60011319 ... 0.78796834 0.91619714 1.20919262]
#
#
#  bootstrap 12 final push weights scaled:
# [0.09720084 0.11708727 0.05812107 ... 0.07760481 0.09101487 0.12007814]
#
#
#
#  ==== processing sample     13
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97249034 1.09783559 0.77005145 ... 0.87366927 0.93972129 1.14622912]
#  weights_push at the beginning
# [0.96530054 1.13787165 0.67781863 ... 0.8233954  0.91840605 1.19601521]
#  weights_push at the beginning
# [0.96713162 1.15558463 0.63456622 ... 0.80266984 0.91330886 1.21100742]
#  weights_push at the beginning
# [0.97170966 1.163465   0.61171267 ... 0.79394863 0.914212   1.21421302]
#
#
#  bootstrap 13 final push weights scaled:
# [0.09806252 0.11714377 0.06009009 ... 0.07935918 0.09208526 0.12189268]
#
#
#
#  ==== processing sample     14
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96623504 1.10684609 0.75826284 ... 0.86265181 0.93244712 1.1544264 ]
#  weights_push at the beginning
# [0.95441568 1.15236014 0.66251436 ... 0.80634481 0.90526399 1.20760102]
#  weights_push at the beginning
# [0.95287087 1.17386808 0.61836877 ... 0.78186894 0.8954252  1.22358588]
#  weights_push at the beginning
# [0.95484938 1.18457082 0.59564179 ... 0.77058096 0.89230523 1.22655689]
#
#
#  bootstrap 14 final push weights scaled:
# [0.09584214 0.11909232 0.05834057 ... 0.07657211 0.08923528 0.12264025]
#
#
#
#  ==== processing sample     15
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9792467  1.10678518 0.75682266 ... 0.86824841 0.94402766 1.12533111]
#  weights_push at the beginning
# [0.97374699 1.15448557 0.65695654 ... 0.81193916 0.92182957 1.16139402]
#  weights_push at the beginning
# [0.97506885 1.17799893 0.60890453 ... 0.78584063 0.91408998 1.16696997]
#  weights_push at the beginning
# [0.97818976 1.19022299 0.58316072 ... 0.7726895  0.91185347 1.16314515]
#
#
#  bootstrap 15 final push weights scaled:
# [0.0994554  0.12130071 0.05761203 ... 0.07759485 0.09239301 0.1173    ]
#
#
#
#  ==== processing sample     16
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9535775  1.11573236 0.7695011  ... 0.85388495 0.91892157 1.16278893]
#  weights_push at the beginning
# [0.9313568  1.17090681 0.68365008 ... 0.79308822 0.88193857 1.2235145 ]
#  weights_push at the beginning
# [0.92061427 1.20137684 0.64826893 ... 0.76559454 0.86407233 1.24515805]
#  weights_push at the beginning
# [0.9143975  1.22020962 0.6333045  ... 0.7519922  0.85412948 1.25225458]
#
#
#  bootstrap 16 final push weights scaled:
# [0.09148299 0.12396204 0.06308599 ... 0.07486717 0.08521803 0.12608716]
#
#
#
#  ==== processing sample     17
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96443479 1.11696305 0.75704158 ... 0.85694015 0.92690725 1.15406674]
#  weights_push at the beginning
# [0.95028322 1.16976661 0.66283805 ... 0.79907929 0.89702317 1.20622069]
#  weights_push at the beginning
# [0.94622234 1.19701052 0.62110281 ... 0.77472233 0.8857871  1.22101053]
#  weights_push at the beginning
# [0.94555569 1.21257996 0.60117877 ... 0.76433538 0.88190151 1.2227629 ]
#
#
#  bootstrap 17 final push weights scaled:
# [0.09415532 0.12170729 0.0588939  ... 0.07568819 0.08770046 0.1215203 ]
#
#
#
#  ==== processing sample     18
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96326056 1.10541942 0.76846937 ... 0.86437327 0.93158318 1.15261935]
#  weights_push at the beginning
# [0.94920829 1.15140328 0.67894465 ... 0.80929605 0.90420875 1.20357315]
#  weights_push at the beginning
# [0.94549901 1.17401615 0.63957055 ... 0.78558062 0.89410502 1.21763885]
#  weights_push at the beginning
# [0.94527002 1.18600677 0.62093394 ... 0.77470565 0.89055934 1.21908719]
#
#
#  bootstrap 18 final push weights scaled:
# [0.0955763  0.12052376 0.06183541 ... 0.07774665 0.08986727 0.12295012]
#
#
#
#  ==== processing sample     19
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98232221 1.10064948 0.76422016 ... 0.87620025 0.94815749 1.12805934]
#  weights_push at the beginning
# [0.97948059 1.14408756 0.66734223 ... 0.82492794 0.9296879  1.16891061]
#  weights_push at the beginning
# [0.98301896 1.16472074 0.62047594 ... 0.80246882 0.92511629 1.17963549]
#  weights_push at the beginning
# [0.98806059 1.1750248  0.59488355 ... 0.79213046 0.92561163 1.18079846]
#
#
#  bootstrap 19 final push weights scaled:
# [0.09863726 0.11725885 0.057578   ... 0.0782125  0.0921686  0.11719346]
#
#
#
#  ==== processing sample     20
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97248743 1.10927941 0.73468759 ... 0.85271967 0.93229792 1.1546039 ]
#  weights_push at the beginning
# [0.96559347 1.1547109  0.62737876 ... 0.79069581 0.90601347 1.20513019]
#  weights_push at the beginning
# [0.96852685 1.17525582 0.57551469 ... 0.7622406  0.89771464 1.21823042]
#  weights_push at the beginning
# [0.97461245 1.18457849 0.54679052 ... 0.7477924  0.89637419 1.21871965]
#
#
#  bootstrap 20 final push weights scaled:
# [0.0983829  0.11915891 0.05305101 ... 0.07416056 0.08999552 0.1218898 ]
#
#
#
#  ==== processing sample     21
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97127698 1.10627967 0.75949438 ... 0.86849451 0.93559135 1.15749906]
#  weights_push at the beginning
# [0.96223935 1.15117837 0.66434228 ... 0.81541455 0.91135165 1.21579139]
#  weights_push at the beginning
# [0.96223728 1.17204346 0.62049244 ... 0.79310272 0.90420435 1.23742058]
#  weights_push at the beginning
# [0.9650824  1.18218794 0.59793736 ... 0.78344819 0.90360249 1.24611632]
#
#
#  bootstrap 21 final push weights scaled:
# [0.09885027 0.12118312 0.05975269 ... 0.07954924 0.09241538 0.12766482]
#
#
#
#  ==== processing sample     22
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96918642 1.099129   0.77297595 ... 0.86740517 0.93311613 1.1398773 ]
#  weights_push at the beginning
# [0.95832653 1.14194853 0.68318155 ... 0.81072909 0.90499858 1.18836038]
#  weights_push at the beginning
# [0.95645249 1.16214589 0.64195449 ... 0.7837582  0.89314093 1.20330326]
#  weights_push at the beginning
# [0.95766735 1.17200486 0.62079979 ... 0.76916702 0.887676   1.20659099]
#
#
#  bootstrap 22 final push weights scaled:
# [0.09559341 0.11720949 0.06065754 ... 0.07571779 0.08812555 0.12015365]
#
#
#
#  ==== processing sample     23
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95684091 1.10855818 0.75012235 ... 0.85135473 0.92072108 1.16720151]
#  weights_push at the beginning
# [0.9397891  1.15429029 0.65816714 ... 0.79047334 0.88855109 1.22519962]
#  weights_push at the beginning
# [0.93490401 1.17636271 0.6193653  ... 0.76307213 0.8762316  1.2424295 ]
#  weights_push at the beginning
# [0.93443634 1.1881828  0.60155135 ... 0.74913027 0.87164993 1.24511206]
#
#
#  bootstrap 23 final push weights scaled:
# [0.09356816 0.11955894 0.05932537 ... 0.0741282  0.087039   0.12434758]
#
#
#
#  ==== processing sample     24
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95753339 1.11325852 0.76331136 ... 0.85155855 0.92188372 1.16260489]
#  weights_push at the beginning
# [0.93917553 1.16311781 0.67314916 ... 0.78972444 0.88768276 1.2223646 ]
#  weights_push at the beginning
# [0.93223763 1.18785064 0.63374126 ... 0.76134367 0.87230888 1.2431424 ]
#  weights_push at the beginning
# [0.92961656 1.20116521 0.61474129 ... 0.74669866 0.86449078 1.24955305]
#
#
#  bootstrap 24 final push weights scaled:
# [0.09283709 0.12086384 0.06047839 ... 0.07380299 0.08596454 0.12507378]
#
#
#
#  ==== processing sample     25
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96437733 1.10630842 0.76130888 ... 0.86482545 0.93171354 1.16007384]
#  weights_push at the beginning
# [0.9512642  1.1514027  0.66765982 ... 0.81148761 0.90424341 1.21933591]
#  weights_push at the beginning
# [0.94850043 1.17265004 0.6247336  ... 0.78986698 0.89400491 1.24101912]
#  weights_push at the beginning
# [0.94928789 1.1833058  0.60255876 ... 0.78118175 0.89033686 1.24923581]
#
#
#  bootstrap 25 final push weights scaled:
# [0.09516146 0.11896728 0.0590338  ... 0.07786158 0.0889642  0.12538062]
#
#
#
#  ==== processing sample     26
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.955879   1.11840347 0.74686449 ... 0.8434977  0.91720672 1.1732808 ]
#  weights_push at the beginning
# [0.93692151 1.17087383 0.64960261 ... 0.77887883 0.88172452 1.23482674]
#  weights_push at the beginning
# [0.93016798 1.19743929 0.6060892  ... 0.74979262 0.86660584 1.25405737]
#  weights_push at the beginning
# [0.92802165 1.212258   0.58429331 ... 0.73539022 0.85966995 1.25797102]
#
#
#  bootstrap 26 final push weights scaled:
# [0.0947888  0.12481729 0.05850147 ... 0.07436371 0.08749587 0.12844732]
#
#
#
#  ==== processing sample     27
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96746452 1.10272635 0.76793191 ... 0.86278132 0.9279883  1.15008361]
#  weights_push at the beginning
# [0.95609527 1.14681869 0.67679341 ... 0.80662285 0.8989813  1.19905266]
#  weights_push at the beginning
# [0.9544543  1.16819388 0.63511484 ... 0.78205957 0.88810377 1.21108343]
#  weights_push at the beginning
# [0.9560296  1.17943886 0.61371549 ... 0.77048288 0.88424209 1.2104086 ]
#
#
#  bootstrap 27 final push weights scaled:
# [0.0965841  0.11951083 0.06064219 ... 0.07706366 0.08899601 0.12154116]
#
#
#
#  ==== processing sample     28
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96427814 1.11023299 0.75389927 ... 0.85608687 0.92697573 1.14462957]
#  weights_push at the beginning
# [0.94989156 1.16032032 0.65931444 ... 0.79542904 0.89561811 1.19071561]
#  weights_push at the beginning
# [0.94527699 1.18640629 0.61708659 ... 0.76701524 0.88195589 1.201151  ]
#  weights_push at the beginning
# [0.94402613 1.20148079 0.59620842 ... 0.75193877 0.87528378 1.19943304]
#
#
#  bootstrap 28 final push weights scaled:
# [0.09343065 0.11990107 0.05793217 ... 0.0735461  0.08627285 0.11822805]
#
#
#
#  ==== processing sample     29
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96356766 1.10567548 0.75903925 ... 0.8567698  0.92931257 1.15749816]
#  weights_push at the beginning
# [0.94997335 1.15051891 0.66743096 ... 0.79897015 0.90089738 1.21165153]
#  weights_push at the beginning
# [0.94702562 1.17210873 0.62744808 ... 0.77393312 0.89029341 1.22762997]
#  weights_push at the beginning
# [0.94775277 1.18348034 0.60843192 ... 0.76218482 0.88647594 1.23015087]
#
#
#  bootstrap 29 final push weights scaled:
# [0.09516796 0.11927973 0.06004773 ... 0.0758002  0.08872299 0.12312863]
#
#
#
#  ==== processing sample     30
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97461522 1.10851006 0.75177968 ... 0.86591155 0.9430267  1.14614117]
#  weights_push at the beginning
# [0.96723082 1.15688922 0.65063757 ... 0.80951742 0.92139058 1.19858233]
#  weights_push at the beginning
# [0.96815359 1.18079904 0.60205284 ... 0.78398052 0.91506018 1.21721379]
#  weights_push at the beginning
# [0.97167739 1.19325522 0.57574582 ... 0.77152757 0.91465983 1.22431378]
#
#
#  bootstrap 30 final push weights scaled:
# [0.10041019 0.12349251 0.0576641  ... 0.07874662 0.09432173 0.12638949]
#
#
#
#  ==== processing sample     31
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96717839 1.09604945 0.78694959 ... 0.87571028 0.94065901 1.13867992]
#  weights_push at the beginning
# [0.95435611 1.13851146 0.70206659 ... 0.82514178 0.91694668 1.19012125]
#  weights_push at the beginning
# [0.95047298 1.1593435  0.66307615 ... 0.8034956  0.90830883 1.20890295]
#  weights_push at the beginning
# [0.94972149 1.17029119 0.64313087 ... 0.79390696 0.90558061 1.21589279]
#
#
#  bootstrap 31 final push weights scaled:
# [0.09509673 0.11777147 0.06327982 ... 0.07906495 0.09061927 0.12203177]
#
#
#
#  ==== processing sample     32
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95184842 1.11387037 0.75173112 ... 0.85281215 0.92037215 1.18471888]
#  weights_push at the beginning
# [0.93231704 1.16119934 0.65770839 ... 0.79670475 0.88943302 1.2554258 ]
#  weights_push at the beginning
# [0.92614886 1.18341873 0.61615867 ... 0.77546559 0.87908453 1.28252302]
#  weights_push at the beginning
# [0.92488768 1.19476998 0.59543331 ... 0.7682605  0.87671068 1.29350849]
#
#
#  bootstrap 32 final push weights scaled:
# [0.09193124 0.11933951 0.05802829 ... 0.07621965 0.08717809 0.12905682]
#
#
#
#  ==== processing sample     33
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96332304 1.107445   0.75770716 ... 0.85899329 0.92684523 1.17570553]
#  weights_push at the beginning
# [0.95059334 1.15121519 0.66454777 ... 0.80378256 0.89929528 1.24423791]
#  weights_push at the beginning
# [0.94880037 1.1706076  0.62309003 ... 0.78148543 0.89075871 1.27268119]
#  weights_push at the beginning
# [0.95068643 1.17930003 0.60269412 ... 0.77246387 0.88944091 1.28679928]
#
#
#  bootstrap 33 final push weights scaled:
# [0.09418734 0.11685529 0.05848017 ... 0.07597702 0.08799114 0.12804584]
#
#
#
#  ==== processing sample     34
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96719492 1.09117946 0.77801557 ... 0.87260695 0.93721035 1.14393152]
#  weights_push at the beginning
# [0.95648511 1.12757871 0.69180783 ... 0.82237005 0.91356453 1.19189978]
#  weights_push at the beginning
# [0.9555087  1.14327105 0.65318126 ... 0.80161251 0.90603947 1.20480318]
#  weights_push at the beginning
# [0.95766626 1.15006823 0.63387731 ... 0.79256187 0.90441812 1.20554127]
#
#
#  bootstrap 34 final push weights scaled:
# [0.09510084 0.11414407 0.06172243 ... 0.07806235 0.08958617 0.11906654]
#
#
#
#  ==== processing sample     35
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96528523 1.10451774 0.76469886 ... 0.86453768 0.93369904 1.16113548]
#  weights_push at the beginning
# [0.95410284 1.14749091 0.67260707 ... 0.81143232 0.90922567 1.21948855]
#  weights_push at the beginning
# [0.95354989 1.16690008 0.63067768 ... 0.7900316  0.90220438 1.23981883]
#  weights_push at the beginning
# [0.95654312 1.17605095 0.60926718 ... 0.78142396 0.90170578 1.24671829]
#
#
#  bootstrap 35 final push weights scaled:
# [0.09610792 0.11813093 0.05977588 ... 0.07788566 0.09041496 0.1250227 ]
#
#
#
#  ==== processing sample     36
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95661403 1.12462138 0.74649906 ... 0.84564823 0.91923174 1.16976028]
#  weights_push at the beginning
# [0.93607417 1.1830494  0.65085091 ... 0.78157656 0.88252051 1.23437342]
#  weights_push at the beginning
# [0.92700441 1.21450742 0.60948503 ... 0.75295784 0.86539324 1.25891263]
#  weights_push at the beginning
# [0.92248637 1.23327254 0.59006342 ... 0.73923921 0.85643901 1.26857468]
#
#
#  bootstrap 36 final push weights scaled:
# [0.09214078 0.12477905 0.0581646  ... 0.07336696 0.0852601  0.12753535]
#
#
#
#  ==== processing sample     37
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97705197 1.1001979  0.77182264 ... 0.8777941  0.94544644 1.12315647]
#  weights_push at the beginning
# [0.97051327 1.14497387 0.68039695 ... 0.82690636 0.92476168 1.15873099]
#  weights_push at the beginning
# [0.97103001 1.16754906 0.63804262 ... 0.80436664 0.91808336 1.16413309]
#  weights_push at the beginning
# [0.97343073 1.18003195 0.61643779 ... 0.79369471 0.91651281 1.16011214]
#
#
#  bootstrap 37 final push weights scaled:
# [0.09798057 0.11924088 0.06072192 ... 0.07915396 0.09203391 0.11586304]
#
#
#
#  ==== processing sample     38
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9626953  1.10745724 0.74197819 ... 0.84726219 0.92473289 1.17043519]
#  weights_push at the beginning
# [0.95066593 1.1496808  0.64355503 ... 0.78702268 0.89669475 1.22498829]
#  weights_push at the beginning
# [0.95006799 1.16813159 0.59941234 ... 0.761684   0.88826345 1.23803868]
#  weights_push at the beginning
# [0.95301206 1.17654868 0.57720363 ... 0.75022326 0.88702403 1.23730397]
#
#
#  bootstrap 38 final push weights scaled:
# [0.09527276 0.11757506 0.05629116 ... 0.07417083 0.08846819 0.12279082]
#
#
#
#  ==== processing sample     39
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96747349 1.10227239 0.75782873 ... 0.85919536 0.93203799 1.15126229]
#  weights_push at the beginning
# [0.9566688  1.14438306 0.66408281 ... 0.80046304 0.90476781 1.20021195]
#  weights_push at the beginning
# [0.95583115 1.16367615 0.62184259 ... 0.77334898 0.89471357 1.21196484]
#  weights_push at the beginning
# [0.95824955 1.17304361 0.60054901 ... 0.75902781 0.89116943 1.21099043]
#
#
#  bootstrap 39 final push weights scaled:
# [0.09668867 0.1184523  0.05922595 ... 0.07545701 0.0895086  0.12131984]
#
#
#
#  ==== processing sample     40
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96450293 1.11412796 0.7480021  ... 0.85875014 0.92902852 1.15476029]
#  weights_push at the beginning
# [0.95114773 1.16518544 0.64815631 ... 0.80038094 0.89951588 1.20784536]
#  weights_push at the beginning
# [0.9482565  1.19102984 0.60144977 ... 0.77469914 0.88788244 1.22345568]
#  weights_push at the beginning
# [0.94908787 1.20530964 0.57670821 ... 0.76274224 0.88333584 1.22591506]
#
#
#  bootstrap 40 final push weights scaled:
# [0.0939329  0.11989687 0.05553933 ... 0.07477529 0.08707732 0.12092599]
#
#
#
#  ==== processing sample     41
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97891051 1.09378252 0.7714336  ... 0.88126854 0.94665905 1.13590587]
#  weights_push at the beginning
# [0.97554186 1.131774   0.67782729 ... 0.83413856 0.92959148 1.18057784]
#  weights_push at the beginning
# [0.97978013 1.14840909 0.63229131 ... 0.81485011 0.92732335 1.19309926]
#  weights_push at the beginning
# [0.98600778 1.15578542 0.60690181 ... 0.80684572 0.93030873 1.19512532]
#
#
#  bootstrap 41 final push weights scaled:
# [0.09913352 0.11579285 0.05906247 ... 0.08029939 0.09340922 0.11934026]
#
#
#
#  ==== processing sample     42
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96461556 1.11422151 0.75010455 ... 0.85770096 0.93217502 1.14977612]
#  weights_push at the beginning
# [0.95035432 1.16487351 0.65504971 ... 0.79997074 0.90441339 1.20014195]
#  weights_push at the beginning
# [0.94593102 1.19054247 0.61384564 ... 0.77511667 0.8937043  1.21473013]
#  weights_push at the beginning
# [0.94477671 1.20491537 0.59496464 ... 0.76383408 0.88950247 1.21700191]
#
#
#  bootstrap 42 final push weights scaled:
# [0.09398832 0.12079969 0.05838201 ... 0.07549503 0.0883452  0.12097588]
#
#
#
#  ==== processing sample     43
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96937707 1.09934348 0.76250317 ... 0.87015508 0.93818108 1.15549612]
#  weights_push at the beginning
# [0.96065614 1.13942367 0.66674541 ... 0.81888996 0.91615574 1.21121925]
#  weights_push at the beginning
# [0.96170914 1.1566386  0.62132349 ... 0.79839684 0.91089433 1.23042927]
#  weights_push at the beginning
# [0.96579622 1.16378305 0.59692664 ... 0.79051717 0.91187776 1.23704671]
#
#
#  bootstrap 43 final push weights scaled:
# [0.09714524 0.11675366 0.05831823 ... 0.07890151 0.09160134 0.12413138]
#
#
#
#  ==== processing sample     44
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9755203  1.10106406 0.74930338 ... 0.86495795 0.93891352 1.13909233]
#  weights_push at the beginning
# [0.96956984 1.14271729 0.64917548 ... 0.80879511 0.91608364 1.18156706]
#  weights_push at the beginning
# [0.97185875 1.16134299 0.60150431 ... 0.78331437 0.90922996 1.18996132]
#  weights_push at the beginning
# [0.97652667 1.16981964 0.57550541 ... 0.77047012 0.90832886 1.18727637]
#
#
#  bootstrap 44 final push weights scaled:
# [0.09948997 0.11896384 0.05673919 ... 0.07737411 0.092201   0.1197991 ]
#
#
#
#  ==== processing sample     45
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96709552 1.10300163 0.7425101  ... 0.85421577 0.93164613 1.14756069]
#  weights_push at the beginning
# [0.95634536 1.14640129 0.64066484 ... 0.79211815 0.90383757 1.19169201]
#  weights_push at the beginning
# [0.95561019 1.16679268 0.59236098 ... 0.76248664 0.89318046 1.19903554]
#  weights_push at the beginning
# [0.95811307 1.17690448 0.56585261 ... 0.74623319 0.88904634 1.19431031]
#
#
#  bootstrap 45 final push weights scaled:
# [0.09540321 0.11731104 0.05453063 ... 0.07304363 0.08806136 0.11774584]
#
#
#
#  ==== processing sample     46
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97137673 1.09507278 0.78825092 ... 0.87645332 0.94066275 1.12826534]
#  weights_push at the beginning
# [0.96198389 1.1358568  0.70702182 ... 0.82738126 0.91750473 1.16809499]
#  weights_push at the beginning
# [0.96077697 1.15553724 0.67215276 ... 0.80681653 0.90907229 1.17668508]
#  weights_push at the beginning
# [0.9619821  1.16595006 0.65647188 ... 0.79772394 0.90598278 1.17499302]
#
#
#  bootstrap 46 final push weights scaled:
# [0.09483317 0.11535565 0.06394924 ... 0.07810375 0.08904261 0.11520835]
#
#
#
#  ==== processing sample     47
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9646923  1.10141158 0.76894884 ... 0.8670725  0.9316783  1.15538244]
#  weights_push at the beginning
# [0.9520313  1.143866   0.67973717 ... 0.81518071 0.90508037 1.21072954]
#  weights_push at the beginning
# [0.94945799 1.16374956 0.64006593 ... 0.79441366 0.8957531  1.22950061]
#  weights_push at the beginning
# [0.95015769 1.17378508 0.62056999 ... 0.78614021 0.89283938 1.23554983]
#
#
#  bootstrap 47 final push weights scaled:
# [0.09469412 0.11734966 0.06073494 ... 0.07793537 0.0887815  0.12316056]
#
#
#
#  ==== processing sample     48
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97560378 1.10241383 0.7663902  ... 0.87380152 0.94000847 1.12653795]
#  weights_push at the beginning
# [0.96832563 1.14848391 0.67232734 ... 0.82104301 0.9160224  1.1631885 ]
#  weights_push at the beginning
# [0.96873676 1.17189078 0.6282932  ... 0.79736736 0.90722908 1.16818276]
#  weights_push at the beginning
# [0.97145126 1.184877   0.60531505 ... 0.78590277 0.90422317 1.16280808]
#
#
#  bootstrap 48 final push weights scaled:
# [0.09822144 0.1202182  0.05970827 ... 0.07862118 0.0910512  0.11638871]
#
#
#
#  ==== processing sample     49
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9548721  1.11155123 0.75703392 ... 0.86176209 0.92453303 1.17168888]
#  weights_push at the beginning
# [0.93676381 1.1591995  0.66662638 ... 0.80848383 0.89420376 1.23553003]
#  weights_push at the beginning
# [0.93103176 1.182276   0.62841229 ... 0.78784909 0.88289524 1.2591063 ]
#  weights_push at the beginning
# [0.92974161 1.19450859 0.61116202 ... 0.78031425 0.87887948 1.26825127]
#
#
#  bootstrap 49 final push weights scaled:
# [0.09280804 0.11993361 0.06022463 ... 0.07768725 0.08759418 0.12702195]
#
#
#
#  ==== processing sample     50
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96564102 1.10260024 0.77018908 ... 0.87072973 0.9363572  1.15599502]
#  weights_push at the beginning
# [0.95316279 1.14622023 0.67984478 ... 0.81951478 0.91187496 1.21619628]
#  weights_push at the beginning
# [0.95072096 1.16654489 0.63868786 ... 0.79882367 0.90407215 1.24024442]
#  weights_push at the beginning
# [0.9517972  1.17638943 0.61775639 ... 0.79070211 0.90275433 1.25107347]
#
#
#  bootstrap 50 final push weights scaled:
# [0.09518028 0.11786129 0.06048496 ... 0.07863977 0.0901941  0.12546584]
#
#
#
#  ==== processing sample     51
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97010681 1.09762392 0.76112627 ... 0.86909097 0.93513791 1.15273   ]
#  weights_push at the beginning
# [0.9618267  1.13634359 0.66695302 ... 0.81767892 0.91155632 1.20368964]
#  weights_push at the beginning
# [0.9631315  1.15271807 0.62318341 ... 0.79693217 0.90503776 1.21794209]
#  weights_push at the beginning
# [0.96737753 1.15940994 0.60010003 ... 0.78856984 0.90479689 1.21976294]
#
#
#  bootstrap 51 final push weights scaled:
# [0.09729816 0.1162736  0.0587223  ... 0.07862557 0.09075167 0.12191099]
#
#
#
#  ==== processing sample     52
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96100395 1.11424141 0.74588054 ... 0.8528884  0.92688443 1.16785065]
#  weights_push at the beginning
# [0.94455856 1.16559967 0.64460669 ... 0.79060017 0.89587527 1.23355004]
#  weights_push at the beginning
# [0.93908358 1.19155096 0.59674609 ... 0.76201066 0.88342529 1.25994875]
#  weights_push at the beginning
# [0.93783898 1.20571033 0.57071139 ... 0.74773779 0.8786651  1.27167001]
#
#
#  bootstrap 52 final push weights scaled:
# [0.09479081 0.12265794 0.05604957 ... 0.07478383 0.08863601 0.12915466]
#
#
#
#  ==== processing sample     53
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97247024 1.10105193 0.75846502 ... 0.86289259 0.93603506 1.15223467]
#  weights_push at the beginning
# [0.96558559 1.1420887  0.66171398 ... 0.806189   0.91230363 1.20500831]
#  weights_push at the beginning
# [0.96811448 1.16017976 0.61558584 ... 0.78064372 0.90548394 1.22120368]
#  weights_push at the beginning
# [0.97361802 1.16829824 0.59017392 ... 0.76776462 0.90500345 1.2246041 ]
#
#
#  bootstrap 53 final push weights scaled:
# [0.09775329 0.11692658 0.0573115  ... 0.07587478 0.09047888 0.12213836]
#
#
#
#  ==== processing sample     54
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97805363 1.10023903 0.77712977 ... 0.87885494 0.94473973 1.12649988]
#  weights_push at the beginning
# [0.97201969 1.14411502 0.68739392 ... 0.83028838 0.92390566 1.16548022]
#  weights_push at the beginning
# [0.97272215 1.16551901 0.6453195  ... 0.81007591 0.91721888 1.17403208]
#  weights_push at the beginning
# [0.9751258  1.17677016 0.62330586 ... 0.80157675 0.91568697 1.17279417]
#
#
#  bootstrap 54 final push weights scaled:
# [0.09577588 0.1159272  0.0598535  ... 0.07821669 0.08974098 0.11455048]
#
#
#
#  ==== processing sample     55
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97482434 1.09954318 0.76112526 ... 0.86902327 0.94009616 1.14403397]
#  weights_push at the beginning
# [0.96952476 1.13957628 0.66521343 ... 0.81609617 0.91887521 1.19068461]
#  weights_push at the beginning
# [0.97300341 1.15671495 0.61979263 ... 0.79346616 0.91363895 1.20289554]
#  weights_push at the beginning
# [0.97902476 1.163791   0.59543292 ... 0.78320526 0.91420031 1.20378227]
#
#
#  bootstrap 55 final push weights scaled:
# [0.09884644 0.11699229 0.05829782 ... 0.07808682 0.09196084 0.12055221]
#
#
#
#  ==== processing sample     56
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97227751 1.10411225 0.76527876 ... 0.87160873 0.9355726  1.14079696]
#  weights_push at the beginning
# [0.96389928 1.14844132 0.67231918 ... 0.82025021 0.91091533 1.18495432]
#  weights_push at the beginning
# [0.9640493  1.16927537 0.62990933 ... 0.79921174 0.90276209 1.19482964]
#  weights_push at the beginning
# [0.96669528 1.17960476 0.60876075 ... 0.79073129 0.90077678 1.19343923]
#
#
#  bootstrap 56 final push weights scaled:
# [0.09678018 0.11827064 0.05966977 ... 0.07863703 0.08992779 0.11868577]
#
#
#
#  ==== processing sample     57
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96247198 1.111031   0.74124565 ... 0.84819437 0.92784948 1.14755554]
#  weights_push at the beginning
# [0.94892525 1.159428   0.64014684 ... 0.78443491 0.89794898 1.19251869]
#  weights_push at the beginning
# [0.946305   1.18351824 0.59290624 ... 0.75463073 0.88599391 1.20086954]
#  weights_push at the beginning
# [0.9474339  1.19670814 0.56745216 ... 0.7388596  0.88101435 1.19699098]
#
#
#  bootstrap 57 final push weights scaled:
# [0.09581565 0.12154663 0.0557036  ... 0.07360522 0.08866959 0.12004949]
#
#
#
#  ==== processing sample     58
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97734184 1.09685488 0.76631491 ... 0.87379389 0.94246718 1.14354906]
#  weights_push at the beginning
# [0.97267618 1.13664866 0.67168618 ... 0.82313726 0.92157073 1.19427998]
#  weights_push at the beginning
# [0.9760045  1.15410334 0.62640211 ... 0.80195763 0.91605679 1.21116098]
#  weights_push at the beginning
# [0.98167014 1.16161553 0.60166137 ... 0.79286419 0.91628291 1.21625394]
#
#
#  bootstrap 58 final push weights scaled:
# [0.09933412 0.1171218  0.05900206 ... 0.07936499 0.09238513 0.12247986]
#
#
#
#  ==== processing sample     59
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97104597 1.10145639 0.76113886 ... 0.86509708 0.93604339 1.15166047]
#  weights_push at the beginning
# [0.96275825 1.14380579 0.66714532 ... 0.8107563  0.9123832  1.20466278]
#  weights_push at the beginning
# [0.96366004 1.16315623 0.62429136 ... 0.78783812 0.90562607 1.22216332]
#  weights_push at the beginning
# [0.9673677  1.17225711 0.60273494 ... 0.77786564 0.90523031 1.2277341 ]
#
#
#  bootstrap 59 final push weights scaled:
# [0.09812419 0.11882757 0.05971954 ... 0.07813714 0.09161843 0.12422978]
#
#
#
#  ==== processing sample     60
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96918427 1.10419611 0.75399915 ... 0.86429958 0.93536469 1.14856102]
#  weights_push at the beginning
# [0.9591275  1.14922428 0.65617612 ... 0.80832493 0.90955141 1.19846942]
#  weights_push at the beginning
# [0.95856857 1.17082173 0.61062179 ... 0.78357823 0.9002956  1.21248824]
#  weights_push at the beginning
# [0.96110988 1.18171729 0.58682863 ... 0.77174816 0.89738035 1.21422078]
#
#
#  bootstrap 60 final push weights scaled:
# [0.0953258  0.11737207 0.05667391 ... 0.07568757 0.08865125 0.11984497]
#
#
#
#  ==== processing sample     61
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96644332 1.10257632 0.7649981  ... 0.87082997 0.93417934 1.16020853]
#  weights_push at the beginning
# [0.9550925  1.14445105 0.67500188 ... 0.82202318 0.91016088 1.21949726]
#  weights_push at the beginning
# [0.95380497 1.16306935 0.63552611 ... 0.804309   0.90360251 1.24135855]
#  weights_push at the beginning
# [0.95578508 1.17153148 0.61677015 ... 0.79915079 0.90356659 1.24985555]
#
#
#  bootstrap 61 final push weights scaled:
# [0.09511924 0.11663856 0.06030318 ... 0.07932728 0.08989318 0.12444593]
#
#
#
#  ==== processing sample     62
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95548658 1.1011622  0.76718584 ... 0.85656733 0.92266352 1.18418837]
#  weights_push at the beginning
# [0.93876774 1.14095704 0.67904194 ... 0.8002368  0.89294441 1.25910151]
#  weights_push at the beginning
# [0.93483586 1.15775379 0.64039363 ... 0.77702987 0.88312791 1.29137992]
#  weights_push at the beginning
# [0.93563529 1.1646891  0.6213024  ... 0.76701223 0.881015   1.30744307]
#
#
#  bootstrap 62 final push weights scaled:
# [0.09402845 0.11699223 0.06123359 ... 0.07644218 0.08839898 0.13206902]
#
#
#
#  ==== processing sample     63
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97533366 1.09863886 0.76096586 ... 0.86690414 0.93961834 1.14192795]
#  weights_push at the beginning
# [0.96934716 1.13972837 0.66442568 ... 0.81137055 0.91689693 1.18969455]
#  weights_push at the beginning
# [0.97172529 1.15813487 0.61867942 ... 0.78622561 0.91006383 1.20349378]
#  weights_push at the beginning
# [0.9766182  1.16632232 0.59426692 ... 0.77368341 0.90924172 1.20578392]
#
#
#  bootstrap 63 final push weights scaled:
# [0.0983734  0.11718489 0.05811714 ... 0.07682492 0.09123243 0.12071179]
#
#
#
#  ==== processing sample     64
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96279841 1.09933667 0.77435071 ... 0.86439836 0.93356427 1.15249672]
#  weights_push at the beginning
# [0.94845968 1.14159468 0.68609519 ... 0.80862657 0.90725359 1.20745402]
#  weights_push at the beginning
# [0.944512   1.16151599 0.64624504 ... 0.78388807 0.89794511 1.22570418]
#  weights_push at the beginning
# [0.94423401 1.1714665  0.62613739 ... 0.77186681 0.89525095 1.23069551]
#
#
#  bootstrap 64 final push weights scaled:
# [0.09459175 0.11777273 0.0615607  ... 0.07661461 0.0895933  0.12324233]
#
#
#
#  ==== processing sample     65
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95634677 1.10500564 0.76958477 ... 0.8605456  0.92285592 1.16342274]
#  weights_push at the beginning
# [0.93830963 1.15008157 0.68303177 ... 0.80580828 0.89095596 1.22530785]
#  weights_push at the beginning
# [0.93204224 1.17207316 0.6462563  ... 0.78357748 0.87806305 1.24827981]
#  weights_push at the beginning
# [0.93010112 1.18392357 0.62939586 ... 0.77443235 0.87258239 1.2566918 ]
#
#
#  bootstrap 65 final push weights scaled:
# [0.09237637 0.11835167 0.06174949 ... 0.07660412 0.08645297 0.12519666]
#
#
#
#  ==== processing sample     66
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96957785 1.10372016 0.76882272 ... 0.8695272  0.93256149 1.14764314]
#  weights_push at the beginning
# [0.95874479 1.14909475 0.67555631 ... 0.8164108  0.90490824 1.20060857]
#  weights_push at the beginning
# [0.95688818 1.17116423 0.63132507 ... 0.79375274 0.89413205 1.21855306]
#  weights_push at the beginning
# [0.95806501 1.18258155 0.60741533 ... 0.78381308 0.88999713 1.22408308]
#
#
#  bootstrap 66 final push weights scaled:
# [0.0974828  0.1207091  0.06021261 ... 0.07916349 0.0902183  0.12445485]
#
#
#
#  ==== processing sample     67
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96739703 1.09860552 0.76414031 ... 0.8719727  0.93950199 1.15018997]
#  weights_push at the beginning
# [0.95743035 1.13965996 0.66793592 ... 0.82097596 0.91805291 1.20465271]
#  weights_push at the beginning
# [0.95745158 1.15816671 0.62093074 ... 0.79993767 0.91286102 1.22382092]
#  weights_push at the beginning
# [0.96077531 1.16661797 0.5941977  ... 0.79116104 0.91377739 1.23057699]
#
#
#  bootstrap 67 final push weights scaled:
# [0.09681821 0.11742922 0.05788976 ... 0.07904603 0.09200121 0.12376378]
#
#
#
#  ==== processing sample     68
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96311447 1.09727923 0.78249101 ... 0.87188646 0.93124069 1.14842613]
#  weights_push at the beginning
# [0.94914214 1.1384462  0.70072912 ... 0.8219913  0.90397113 1.19953589]
#  weights_push at the beginning
# [0.94516092 1.15800351 0.66632095 ... 0.80199862 0.89378131 1.21477324]
#  weights_push at the beginning
# [0.94450888 1.1681124  0.651043   ... 0.79402624 0.89005692 1.2174022 ]
#
#
#  bootstrap 68 final push weights scaled:
# [0.09527941 0.11838375 0.06500704 ... 0.07980311 0.08963425 0.12264002]
#
#
#
#  ==== processing sample     69
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97515134 1.11437734 0.74893278 ... 0.85633109 0.9370826  1.14233291]
#  weights_push at the beginning
# [0.96720008 1.1663603  0.64820414 ... 0.79516284 0.91092181 1.18846491]
#  weights_push at the beginning
# [0.96716326 1.19290495 0.60095046 ... 0.76684804 0.90067486 1.20011846]
#  weights_push at the beginning
# [0.96951173 1.20753165 0.57631729 ... 0.75257816 0.89661207 1.2001534 ]
#
#
#  bootstrap 69 final push weights scaled:
# [0.09807546 0.12268731 0.0567559  ... 0.07514381 0.09027875 0.12075175]
#
#
#
#  ==== processing sample     70
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9723875  1.10777207 0.73768127 ... 0.85921393 0.93366359 1.15385199]
#  weights_push at the beginning
# [0.96419341 1.15384096 0.63204669 ... 0.80034926 0.90779299 1.20669565]
#  weights_push at the beginning
# [0.96521102 1.17535272 0.58101533 ... 0.77380881 0.89929374 1.22269041]
#  weights_push at the beginning
# [0.96927939 1.18560276 0.55265994 ... 0.76087253 0.89759934 1.22600748]
#
#
#  bootstrap 70 final push weights scaled:
# [0.09734619 0.11896032 0.05347772 ... 0.07537512 0.08980188 0.12248849]
#
#
#
#  ==== processing sample     71
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95816818 1.11057873 0.76396398 ... 0.85622785 0.92788039 1.1515979 ]
#  weights_push at the beginning
# [0.94114369 1.16069208 0.67373759 ... 0.79742306 0.89756483 1.20118117]
#  weights_push at the beginning
# [0.93548831 1.18710783 0.6344718  ... 0.77142417 0.88496741 1.21339274]
#  weights_push at the beginning
# [0.93389204 1.20284503 0.6160175  ... 0.75885693 0.87922579 1.21267   ]
#
#
#  bootstrap 71 final push weights scaled:
# [0.0922082  0.11984886 0.05996737 ... 0.07429952 0.08653648 0.11932257]
#
#
#
#  ==== processing sample     72
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97187955 1.09187215 0.76538901 ... 0.87038311 0.94044338 1.14740715]
#  weights_push at the beginning
# [0.96423774 1.1275298  0.67297535 ... 0.81711685 0.91903611 1.19767526]
#  weights_push at the beginning
# [0.96559441 1.14169448 0.63019981 ... 0.7932481  0.91349371 1.2126789 ]
#  weights_push at the beginning
# [0.9697401  1.14649951 0.60774484 ... 0.78124495 0.91385495 1.21562309]
#
#
#  bootstrap 72 final push weights scaled:
# [0.09776244 0.1150788  0.05966831 ... 0.07769451 0.09193439 0.12190256]
#
#
#
#  ==== processing sample     73
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96147051 1.1195618  0.74645323 ... 0.85222529 0.92561593 1.17760159]
#  weights_push at the beginning
# [0.94643064 1.17090132 0.64896041 ... 0.79408102 0.89626454 1.24833844]
#  weights_push at the beginning
# [0.94270367 1.19512531 0.60531344 ... 0.77074902 0.88650682 1.27823189]
#  weights_push at the beginning
# [0.94308801 1.20705953 0.58360019 ... 0.76180538 0.88459438 1.29293332]
#
#
#  bootstrap 73 final push weights scaled:
# [0.09415412 0.12089084 0.05700601 ... 0.07566929 0.08828219 0.12978945]
#
#
#
#  ==== processing sample     74
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95746201 1.11073879 0.76615792 ... 0.85914679 0.92400564 1.154637  ]
#  weights_push at the beginning
# [0.93884417 1.16141801 0.67809604 ... 0.8020358  0.89117459 1.20668712]
#  weights_push at the beginning
# [0.93131265 1.18875334 0.64075951 ... 0.77725341 0.87667546 1.22068804]
#  weights_push at the beginning
# [0.92774966 1.20564134 0.62411796 ... 0.76566336 0.86934185 1.22120453]
#
#
#  bootstrap 74 final push weights scaled:
# [0.09285548 0.12216302 0.06190924 ... 0.07624427 0.08677476 0.12215913]
#
#
#
#  ==== processing sample     75
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96009009 1.11201139 0.75819461 ... 0.85805855 0.92537431 1.16042592]
#  weights_push at the beginning
# [0.94300075 1.16129613 0.66776619 ... 0.80065371 0.89453886 1.21799533]
#  weights_push at the beginning
# [0.93658046 1.18614404 0.6292597  ... 0.77588765 0.88223269 1.23736353]
#  weights_push at the beginning
# [0.93396496 1.20007011 0.61166834 ... 0.76444011 0.87718552 1.24306566]
#
#
#  bootstrap 75 final push weights scaled:
# [0.0933856  0.12104387 0.06044202 ... 0.07599303 0.08762588 0.12460599]
#
#
#
#  ==== processing sample     76
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97088923 1.10816195 0.74881959 ... 0.85628991 0.92958499 1.15751907]
#  weights_push at the beginning
# [0.96180287 1.15375755 0.64829535 ... 0.79714406 0.90163988 1.21270512]
#  weights_push at the beginning
# [0.96205173 1.1747386  0.60051431 ... 0.77112517 0.89183862 1.23034294]
#  weights_push at the beginning
# [0.96534858 1.18459341 0.57448678 ... 0.75891962 0.8891539  1.23488652]
#
#
#  bootstrap 76 final push weights scaled:
# [0.0969137  0.11888238 0.05585283 ... 0.07528205 0.08890825 0.12351711]
#
#
#
#  ==== processing sample     77
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96653128 1.11086303 0.7488351  ... 0.85299086 0.92855299 1.15229634]
#  weights_push at the beginning
# [0.95460986 1.15918639 0.65058904 ... 0.79018217 0.89892298 1.2005485 ]
#  weights_push at the beginning
# [0.9528262  1.18280608 0.60588113 ... 0.76037299 0.88722882 1.21130801]
#  weights_push at the beginning
# [0.95447778 1.19517694 0.58339845 ... 0.74428661 0.88252226 1.20944016]
#
#
#  bootstrap 77 final push weights scaled:
# ...
# [0.89518741 1.19766946 0.52520947 ... 0.82595278 0.85502467 1.19285353]
#  weights_push at the beginning
# [0.88904347 1.19805858 0.5138701  ... 0.83647802 0.84516563 1.20250867]
#  weights_push at the beginning
# [0.88713341 1.20207048 0.50633936 ... 0.8390172  0.84419626 1.21692741]
#  weights_push at the beginning
# [0.8852528  1.2047791  0.50113017 ... 0.84004552 0.84603053 1.22861266]
#
#
#  bootstrap 474 final push weights scaled:
# [0.08942796 0.12211805 0.05035286 ... 0.08507783 0.08593198 0.12534758]
#
#
#
#  ==== processing sample    475
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98723443 1.16149654 0.52712912 ... 0.79827716 0.86540941 1.29885515]
#  weights_push at the beginning
# [0.9946763  1.15301813 0.52119135 ... 0.81353873 0.86855434 1.33730411]
#  weights_push at the beginning
# [0.99315684 1.1504742  0.518574   ... 0.81863846 0.87206109 1.36072441]
#  weights_push at the beginning
# [0.99063288 1.1487583  0.51737694 ... 0.82140938 0.87455144 1.37538988]
#
#
#  bootstrap 475 final push weights scaled:
# [0.09778599 0.11347512 0.0510998  ... 0.08142542 0.08664469 0.13705849]
#  ==== processing sample    476
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91838309 1.21743275 0.55371795 ... 0.82703991 0.84674781 1.30072203]
#  weights_push at the beginning
# [0.92060374 1.22142681 0.55908247 ... 0.84560257 0.84397831 1.32478207]
#  weights_push at the beginning
# [0.92175035 1.21716481 0.56255246 ... 0.85162144 0.84752328 1.34686152]
#  weights_push at the beginning
# [0.9219991  1.21172984 0.56320578 ... 0.85491458 0.85192384 1.36417989]
#
#
#  bootstrap 476 final push weights scaled:
# [0.09237353 0.12089844 0.0563047  ... 0.08588597 0.08575139 0.13807014]
#
#
#
#  ==== processing sample    477
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97268891 1.23498664 0.57025453 ... 0.78787242 0.86262471 1.17646972]
#  weights_push at the beginning
# [0.98318877 1.23898314 0.57014132 ... 0.79763208 0.85423386 1.19028093]
#  weights_push at the beginning
# [0.98873828 1.23795693 0.56871908 ... 0.79986629 0.84903494 1.20602163]
#  weights_push at the beginning
# [0.99289916 1.2352129  0.56863978 ... 0.80018819 0.84544894 1.21847116]
#
#
#  bootstrap 477 final push weights scaled:
# [0.09954263 0.12307277 0.05689534 ... 0.07990816 0.08418732 0.12278183]
#
#
#
#  ==== processing sample    478
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96757171 1.24286601 0.57862236 ... 0.73087607 0.87060322 1.25128268]
#  weights_push at the beginning
# [0.97004789 1.25057532 0.58544238 ... 0.72400204 0.86987719 1.26580835]
#  weights_push at the beginning
# [0.96896357 1.25153923 0.59259985 ... 0.7210217  0.86755919 1.27091759]
#  weights_push at the beginning
# [0.96836027 1.25150866 0.59892774 ... 0.72080183 0.86548266 1.27077957]
#
#
#  bootstrap 478 final push weights scaled:
# [0.09721656 0.12564891 0.06068265 ... 0.07250254 0.08672342 0.12744796]
#
#
#
#  ==== processing sample    479
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98310128 1.23189008 0.57972806 ... 0.73613435 0.87115728 1.25258219]
#  weights_push at the beginning
# [0.99430257 1.24001613 0.58691915 ... 0.72622334 0.86559373 1.25435725]
#  weights_push at the beginning
# [0.99753943 1.24116406 0.59330377 ... 0.71645388 0.8599482  1.25077019]
#  weights_push at the beginning
# [0.99855663 1.24064566 0.59797692 ... 0.70821568 0.85589016 1.24664451]
#
#
#  bootstrap 479 final push weights scaled:
# [0.09803439 0.12177481 0.05904883 ... 0.06884555 0.08376913 0.12207735]
#
#
#
#  ==== processing sample    480
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96119256 1.21105544 0.52179511 ... 0.72003584 0.8618389  1.34952416]
#  weights_push at the beginning
# [0.96632089 1.22167104 0.51281194 ... 0.71637191 0.85672974 1.3461196 ]
#  weights_push at the beginning
# [0.96581911 1.2240746  0.51133854 ... 0.71193349 0.85259942 1.34336956]
#  weights_push at the beginning
# [0.96404228 1.22270138 0.51187859 ... 0.70846504 0.85020706 1.34347262]
#
#
#  bootstrap 480 final push weights scaled:
# [0.0982141  0.12455113 0.05234228 ... 0.07206635 0.08667282 0.13734549]
#
#
#
#  ==== processing sample    481
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.88890881 1.19643254 0.53145506 ... 0.78688108 0.83976109 1.26275775]
#  weights_push at the beginning
# [0.88314835 1.19708754 0.53231318 ... 0.78265774 0.828254   1.27986673]
#  weights_push at the beginning
# [0.88166028 1.19837775 0.53546128 ... 0.77757842 0.82357123 1.29075153]
#  weights_push at the beginning
# [0.88076043 1.19956721 0.53885745 ... 0.77508079 0.82147705 1.29631911]
#
#
#  bootstrap 481 final push weights scaled:
# [0.08875036 0.1211337  0.05468208 ... 0.0780956  0.08275464 0.13105324]
#
#
#
#  ==== processing sample    482
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.99168619 1.24050403 0.56807054 ... 0.77702044 0.87209321 1.19823011]
#  weights_push at the beginning
# [1.00315028 1.26427359 0.57718154 ... 0.78961766 0.86807618 1.20621458]
#  weights_push at the beginning
# [1.00645089 1.2733215  0.57981174 ... 0.79549662 0.86651493 1.21351487]
#  weights_push at the beginning
# [1.00749894 1.27574874 0.58072291 ... 0.7994454  0.86637246 1.2167869 ]
#
#
#  bootstrap 482 final push weights scaled:
# [0.09888088 0.12515378 0.05704105 ... 0.07875538 0.085052   0.11954022]
#
#
#
#  ==== processing sample    483
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98456559 1.22355837 0.53767405 ... 0.79333823 0.88266183 1.24887056]
#  weights_push at the beginning
# [0.9950689  1.22852618 0.54301443 ... 0.79288132 0.87417637 1.25223208]
#  weights_push at the beginning
# [0.99893623 1.22786873 0.54724735 ... 0.79103839 0.86821545 1.26241242]
#  weights_push at the beginning
# [1.00067962 1.22687003 0.54959692 ... 0.79043008 0.8639647  1.27113876]
#
#
#  bootstrap 483 final push weights scaled:
# [0.10057539 0.1231245  0.05530969 ... 0.07938982 0.0864476  0.12838641]
#
#
#
#  ==== processing sample    484
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95882014 1.23791159 0.54177927 ... 0.76119204 0.84884611 1.27244846]
#  weights_push at the beginning
# [0.96969991 1.24691608 0.53815864 ... 0.77166102 0.83895665 1.29721053]
#  weights_push at the beginning
# [0.97473565 1.25074722 0.5369297  ... 0.77521176 0.83266055 1.32031623]
#  weights_push at the beginning
# [0.97772356 1.25197457 0.53709673 ... 0.7779966  0.82859615 1.33687833]
#
#
#  bootstrap 484 final push weights scaled:
# [0.09724684 0.12431152 0.05340052 ... 0.07750916 0.0819638  0.13389243]
#
#
#
#  ==== processing sample    485
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.9558969  1.1831496  0.55363363 ... 0.84092713 0.86062235 1.24149382]
#  weights_push at the beginning
# [0.96346185 1.19208449 0.54388988 ... 0.85392542 0.84886267 1.24411658]
#  weights_push at the beginning
# [0.96525727 1.19752488 0.54228204 ... 0.85821772 0.84458259 1.24765912]
#  weights_push at the beginning
# [0.964092   1.1993588  0.54300092 ... 0.86189065 0.8429788  1.25159308]
#
#
#  bootstrap 485 final push weights scaled:
# [0.09674326 0.12068013 0.05471338 ... 0.08709305 0.08477224 0.12639125]
#
#
#
#  ==== processing sample    486
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.95524301 1.17108735 0.53589693 ... 0.71977157 0.95870453 1.23344076]
#  weights_push at the beginning
# [0.94480386 1.16944131 0.53599906 ... 0.7090357  0.96413518 1.23094294]
#  weights_push at the beginning
# [0.94170925 1.16533209 0.53638541 ... 0.70350505 0.96156803 1.22910229]
#  weights_push at the beginning
# [0.94161255 1.16067292 0.53565309 ... 0.70122092 0.95937854 1.22669579]
#
#
#  bootstrap 486 final push weights scaled:
# [0.09342809 0.11465816 0.05297158 ... 0.06947058 0.0950158  0.12142343]
#
#
#
#  ==== processing sample    487
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.93770397 1.27193114 0.56449116 ... 0.74770047 0.82441971 1.25015208]
#  weights_push at the beginning
# [0.94755595 1.28207028 0.56248374 ... 0.7289344  0.81033517 1.26334613]
#  weights_push at the beginning
# [0.95186447 1.28344845 0.56240727 ... 0.71642459 0.80531907 1.2720968 ]
#  weights_push at the beginning
# [0.95323107 1.28328792 0.5639554  ... 0.70944985 0.80462244 1.27618037]
#
#
#  bootstrap 487 final push weights scaled:
# [0.09494476 0.12779075 0.05637599 ... 0.07031751 0.08032251 0.12739818]
#
#
#
#  ==== processing sample    488
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97418194 1.19024185 0.56864666 ... 0.7545623  0.91893116 1.20325316]
#  weights_push at the beginning
# [0.97178324 1.19151308 0.55897074 ... 0.75511441 0.92220856 1.20071605]
#  weights_push at the beginning
# [0.9677009  1.19407087 0.55259861 ... 0.75583832 0.9206125  1.2054377 ]
#  weights_push at the beginning
# [0.9643366  1.19617642 0.54879076 ... 0.75655561 0.91882672 1.21107581]
#
#
#  bootstrap 488 final push weights scaled:
# [0.09472386 0.11803287 0.05382694 ... 0.0745866  0.09038256 0.11986337]
#
#
#
#  ==== processing sample    489
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.91196057 1.1588915  0.56732567 ... 0.7748959  0.8823333  1.31004531]
#  weights_push at the beginning
# [0.90411841 1.15009666 0.57828477 ... 0.77678806 0.8795979  1.34384044]
#  weights_push at the beginning
# [0.8992669  1.1455892  0.58455795 ... 0.77407181 0.87763745 1.37316698]
#  weights_push at the beginning
# [0.89524902 1.14167748 0.58881417 ... 0.77119439 0.87660102 1.39714616]
#
#
#  bootstrap 489 final push weights scaled:
# [0.08854995 0.1130619  0.0587936  ... 0.07634486 0.08700462 0.14074876]
#  ==== processing sample    490
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.98578993 1.19016826 0.5188474  ... 0.74608049 0.90879752 1.18189688]
#  weights_push at the beginning
# [0.98988892 1.17798665 0.53078226 ... 0.74288432 0.91389818 1.17461021]
#  weights_push at the beginning
# [0.99039602 1.17093326 0.54269143 ... 0.74086695 0.9136803  1.17858576]
#  weights_push at the beginning
# [0.99126301 1.16696383 0.55133033 ... 0.74090721 0.91264341 1.18378736]
#
#
#  bootstrap 490 final push weights scaled:
# [0.09946036 0.1166753  0.05586868 ... 0.07436438 0.09135582 0.11918481]
#
#
#
#  ==== processing sample    491
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96193481 1.21017072 0.58058442 ... 0.7771368  0.90814539 1.28126777]
#  weights_push at the beginning
# [0.95715959 1.21456926 0.60187944 ... 0.77569243 0.9158739  1.30146692]
#  weights_push at the beginning
# [0.95050223 1.22070422 0.61705537 ... 0.7737206  0.91881531 1.31848851]
#  weights_push at the beginning
# [0.94493861 1.22656511 0.62844402 ... 0.7736091  0.92047884 1.33251176]
#
#
#  bootstrap 491 final push weights scaled:
# [0.09365852 0.12264558 0.06346381 ... 0.07718133 0.09182204 0.13392733]
#
#
#
#  ==== processing sample    492
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96573758 1.24533855 0.54391385 ... 0.75636466 0.87331927 1.22351434]
#  weights_push at the beginning
# [0.98021219 1.26040888 0.53794994 ... 0.74890966 0.86527088 1.19624931]
#  weights_push at the beginning
# [0.98917782 1.26163791 0.53424495 ... 0.74503415 0.85667597 1.1761165 ]
#  weights_push at the beginning
# [0.99589528 1.2588601  0.53218819 ... 0.74316542 0.84927548 1.15931194]
#
#
#  bootstrap 492 final push weights scaled:
# [0.10053921 0.12604248 0.05333121 ... 0.07450798 0.08466261 0.11505912]
#
#
#
#  ==== processing sample    493
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97843754 1.22664003 0.55874548 ... 0.73011975 0.85510574 1.2394512 ]
#  weights_push at the beginning
# [0.99727484 1.23420149 0.57909996 ... 0.71645774 0.83647419 1.2516352 ]
#  weights_push at the beginning
# [1.00907785 1.23333008 0.59043611 ... 0.70607869 0.82333068 1.26757509]
#  weights_push at the beginning
# [1.01703389 1.23024744 0.59678017 ... 0.69868167 0.81481005 1.27993451]
#
#
#  bootstrap 493 final push weights scaled:
# [0.1044079  0.12528421 0.06131314 ... 0.07079907 0.08265484 0.13171166]
#
#
#
#  ==== processing sample    494
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96713585 1.21124437 0.57503544 ... 0.72826865 0.91030696 1.16257969]
#  weights_push at the beginning
# [0.96803989 1.22076151 0.5581741  ... 0.72245937 0.90960639 1.15871286]
#  weights_push at the beginning
# [0.96898653 1.22676084 0.54853135 ... 0.7177039  0.90679298 1.15658887]
#  weights_push at the beginning
# [0.9702122  1.23009099 0.54375565 ... 0.71444737 0.90557755 1.1528644 ]
#
#
#  bootstrap 494 final push weights scaled:
# [0.09739549 0.12354911 0.0543055  ... 0.0714252  0.09082025 0.1152721 ]
#
#
#
#  ==== processing sample    495
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.97738319 1.22468679 0.57537345 ... 0.79327203 0.89299925 1.17687329]
#  weights_push at the beginning
# [0.98138827 1.24547581 0.58177036 ... 0.79561995 0.89454929 1.16045394]
#  weights_push at the beginning
# [0.98026208 1.25569196 0.58689497 ... 0.79483162 0.89615745 1.15332079]
#  weights_push at the beginning
# [0.97791739 1.26199185 0.59152102 ... 0.79398825 0.89828116 1.14813299]
#
#
#  bootstrap 495 final push weights scaled:
# [0.10012643 0.13005949 0.06116343 ... 0.08146423 0.09251048 0.11745713]
#
#
#
#  ==== processing sample    496
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.96016602 1.24023697 0.54036288 ... 0.83535613 0.85849938 1.24302034]
#  weights_push at the beginning
# [0.96845519 1.25037035 0.53222073 ... 0.86334969 0.85411044 1.25364676]
#  weights_push at the beginning
# [0.96949061 1.25343043 0.529604   ... 0.87517306 0.85677883 1.26985583]
#  weights_push at the beginning
# [0.96780517 1.25437578 0.52882473 ... 0.88143316 0.8610474  1.28532826]
#
#
#  bootstrap 496 final push weights scaled:
# [0.09620301 0.12502884 0.05266576 ... 0.08818821 0.08621853 0.12953635]
#
#
#
#  ==== processing sample    497
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [1.01127512 1.18029356 0.5148162  ... 0.83181172 0.85053434 1.31621549]
#  weights_push at the beginning
# [1.03908588 1.18317491 0.52581589 ... 0.84203815 0.82655744 1.34507807]
#  weights_push at the beginning
# [1.05590712 1.18358857 0.53003954 ... 0.84281597 0.81260687 1.36002626]
#  weights_push at the beginning
# [1.06753258 1.18211489 0.53120648 ... 0.84227263 0.80294083 1.36844847]
#
#
#  bootstrap 497 final push weights scaled:
# [0.10610182 0.11627647 0.05232735 ... 0.08293565 0.07842139 0.13542945]
#
#
#
#  ==== processing sample    498
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.94598797 1.2463076  0.60766647 ... 0.74944925 0.89115622 1.24401244]
#  weights_push at the beginning
# [0.93867778 1.26317725 0.60399686 ... 0.75472485 0.90481051 1.25185993]
#  weights_push at the beginning
# [0.93019565 1.26980709 0.60072377 ... 0.75965109 0.91341167 1.25651615]
#  weights_push at the beginning
# [0.92348942 1.27239286 0.5991442  ... 0.76427168 0.92031357 1.26009341]
#
#
#  bootstrap 498 final push weights scaled:
# [0.0920381  0.1276266  0.06000252 ... 0.07705356 0.09285022 0.12666446]
#
#
#
#  ==== processing sample    499
#  weights_push at the beginning
# [1. 1. 1. ... 1. 1. 1.]
#  weights_push at the beginning
# [0.92814021 1.27808892 0.5684532  ... 0.77132114 0.88770582 1.24147554]
#  weights_push at the beginning
# [0.92014628 1.30250952 0.56998483 ... 0.77037846 0.88762718 1.24665378]
#  weights_push at the beginning
# [0.91455005 1.30963598 0.56527952 ... 0.76859639 0.88568827 1.24743925]
#  weights_push at the beginning
# [0.9103729  1.31090451 0.56042003 ... 0.7673346  0.88379751 1.24614858]
#
#
#  bootstrap 499 final push weights scaled:
# [0.09045346 0.13070525 0.05546216 ... 0.07644898 0.08800939 0.12419458]
# CPU times: user 60 s, sys: 741 ms, total: 1min
# Wall time: 1min

# %%
print('Done')
# Out:
# Done
